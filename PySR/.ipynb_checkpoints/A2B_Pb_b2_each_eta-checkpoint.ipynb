# %% [markdown]
# # TMD A12B for specific eta

# %%
pip install -U pysr
# Out:
# Requirement already satisfied: pysr in /opt/homebrew/anaconda3/lib/python3.11/site-packages (1.5.1)
# Requirement already satisfied: sympy<2.0.0,>=1.0.0 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from pysr) (1.11.1)
# Requirement already satisfied: pandas<3.0.0,>=0.21.0 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from pysr) (2.0.3)
# Requirement already satisfied: numpy<3.0.0,>=1.13.0 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from pysr) (1.26.4)
# Requirement already satisfied: scikit_learn<2.0.0,>=1.0.0 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from pysr) (1.2.2)
# Requirement already satisfied: juliacall==0.9.24 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from pysr) (0.9.24)
# Requirement already satisfied: click<9.0.0,>=7.0.0 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from pysr) (8.0.4)
# Requirement already satisfied: setuptools>=50.0.0 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from pysr) (68.0.0)
# Requirement already satisfied: juliapkg~=0.1.8 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from juliacall==0.9.24->pysr) (0.1.15)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from pandas<3.0.0,>=0.21.0->pysr) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from pandas<3.0.0,>=0.21.0->pysr) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from pandas<3.0.0,>=0.21.0->pysr) (2023.3)
# Requirement already satisfied: scipy>=1.3.2 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from scikit_learn<2.0.0,>=1.0.0->pysr) (1.11.1)
# Requirement already satisfied: joblib>=1.1.1 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from scikit_learn<2.0.0,>=1.0.0->pysr) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from scikit_learn<2.0.0,>=1.0.0->pysr) (2.2.0)
# Requirement already satisfied: mpmath>=0.19 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from sympy<2.0.0,>=1.0.0->pysr) (1.3.0)
# Requirement already satisfied: semver~=3.0 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from juliapkg~=0.1.8->juliacall==0.9.24->pysr) (3.0.2)
# Requirement already satisfied: six>=1.5 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas<3.0.0,>=0.21.0->pysr) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Julia and Julia dependencies are installed at first import:

# %%
import pysr
# Out:
# Detected IPython. Loading juliacall extension. See https://juliapy.github.io/PythonCall.jl/stable/compat/#IPython

# %% [markdown]
# Now, let's import everything else as well as the PySRRegressor:

# %%
import sympy
import numpy as np
from matplotlib import pyplot as plt
from pysr import PySRRegressor
from sklearn.model_selection import train_test_split
import h5py

# %% [markdown]
# # PySR for A12B eta = 8:

# %%
file_path = "/Users/hariprashadravikumar/sivers_TMD_PhD_project/save_h5_A12B_A2B/eta_Pb_bsquare_Amp_err_withb0.h5"
#with h5py.File(file_path, "r") as h5_file:
#    # Specify the dataset to extract
#    dataset_name = "Pl-2/eta_8_Pb_bsq_A12B_err"
#    data = np.array(h5_file[dataset_name])

P1 = 1
data_list = []
with h5py.File(file_path, "r") as h5_file:
    dataset_name = f"Pl-{P1}/eta_8_Pb_bsq_A2B_err"
    dataPl = np.array(h5_file[dataset_name])    
    data_list.append(dataPl)

data = np.vstack(data_list)
# Extract bLbT and A12B
PbbsqA2B = data[:, 1:3]  
A2B = data[:, 3]   
A2Berr = data[:, 4]
A2Bweight = [1/sigma**2 for sigma in A2Berr]


#print("bLbT =", bLbT)
#print("A12B =", A12B)
#print("A12Berr =", A12Berr)

# %%
# Extract unique bT values
unique_bsq = np.unique(PbbsqA2B[:, 1])

# Create the plot
plt.figure(figsize=(10, 6))

for i, bsq in enumerate(unique_bsq):
    #if bT<1 :
    #    continue
    # Filter data for the current bT value
    mask = PbbsqA2B[:, 1] == bsq
    Pb_values = PbbsqA2B[mask, 0]
    A2B_values = A2B[mask]
    A2B_errors = A2Berr[mask]

    # Plot with error bars
    plt.errorbar(
        Pb_values,
        A2B_values,
        yerr=A2B_errors,
        fmt='o',
        label=f"$b^2$ = {int(bsq)}",
        capsize=4
    )
# Add labels, legend, and grid
plt.xlabel("$P\cdot b$", fontsize=14)
plt.ylabel("$A_{2B}$", fontsize=14)
plt.title("Plot of $A_{2B}$ vs $P\cdot b$ for Different $b^2$ Values", fontsize=16)
plt.legend(fontsize=10)
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Extract unique bT values
unique_Pb = np.unique(PbbsqA2B[:, 0])

# Create the plot
plt.figure(figsize=(10, 6))

for i, Pb in enumerate(unique_Pb):
    #if bT<1 :
    #    continue
    # Filter data for the current bT value
    mask = PbbsqA2B[:, 0] == Pb
    Psq_values = PbbsqA2B[mask, 1]
    A2B_values = A2B[mask]
    A2B_errors = A2Berr[mask]

    # Plot with error bars
    plt.errorbar(
        Psq_values,
        A2B_values,
        yerr=A2B_errors,
        fmt='o',
        label=f"$P\cdot b$ = {Pb}",
        capsize=4
    )
# Add labels, legend, and grid
plt.xlabel("$b^2$", fontsize=14)
plt.ylabel("$A_{2B}$", fontsize=14)
plt.title("Plot of $A_{2B}$ vs $b^2$ for Different $P\cdot b$ Values", fontsize=16)
plt.legend(fontsize=10)
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# By default, we will set up 30 populations of expressions (which evolve independently except for migrations), use 4 threads, and use `"best"` for our model selection strategy:

# %%
default_pysr_params = dict(
    populations=50,
    model_selection="best",
)

# %%
from sympy import exp, symbols, Function

custom_loss_function = """
using Symbolics

function eval_loss(tree, dataset::Dataset{T,L}, options)::L where {T,L}
    prediction, flag = eval_tree_array(tree, dataset.X, options)
    if !flag
        return L(Inf)
    end
    
    wmse = sum(dataset.weights .* (prediction .- dataset.y) .^ 2) / (dataset.n * sum(dataset.weights))
    return wmse
end
"""

extra_sympy_mappings = {
    "Lorentzian": lambda x, y: 1 / (y + x**2),
    "gaussian": lambda x: exp(-x**2),
    "decay": lambda x: exp(-x)
}

model = PySRRegressor(
    niterations=50,
    unary_operators=["gaussian(x) = exp(-x^2)", "decay(x) = exp(-x)"],
    binary_operators=["*", "Lorentzian(x, y) = 1/(y + x^2)"],
    extra_sympy_mappings=extra_sympy_mappings,  # Include the custom mappings
    loss_function=custom_loss_function,  # Use the custom loss function
    nested_constraints = { "gaussian": {"gaussian": 0, "Lorentzian": 0, "decay": 0},"Lorentzian": {"Lorentzian": 0, "gaussian": 0, "decay": 0},  "decay": {"Lorentzian": 0, "gaussian": 0, "decay": 0}},
    constraints={'gaussian': (-1, 1), 'Lorentzian': (-1, 1), 'decay': (-1, 1)}

)

modelold = PySRRegressor(
    niterations=50,
    unary_operators=["gaussian(x) = exp(-x^2)"],
    binary_operators=["*","Lorentzian(x, y) = 1/(y + x^2)"],
    extra_sympy_mappings=extra_sympy_mappings,  # Include the custom mappings
    loss_function=custom_loss_function,  # Use the custom loss function
    nested_constraints = { "gaussian": {"gaussian": 0, "Lorentzian": 0},"Lorentzian": {"Lorentzian": 0, "gaussian": 0}},
    constraints={'gaussian': (-1, 1), 'Lorentzian': (-1, 1)}

)

model.fit(PbbsqA2B, A2B, weights=A2Bweight, variable_names=['Pb', 'bsq'])
# Out:
# /opt/homebrew/anaconda3/lib/python3.11/site-packages/pysr/sr.py:2774: UserWarning: Note: it looks like you are running in Jupyter. The progress bar will be turned off.
#   warnings.warn(
# Expressions evaluated per second: 1.450e+05
# Progress: 886 / 1550 total iterations (57.161%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.592e-05  1.594e+01  y = 0.010529
# 2           7.894e-06  7.014e-01  y = decay(bsq)
# 3           1.493e-06  1.665e+00  y = Lorentzian(bsq, 2.1028)
# 5           1.087e-06  1.586e-01  y = Lorentzian(bsq, 4.0092) * 1.4466
# 8           6.688e-07  1.620e-01  y = gaussian(Pb) * (Lorentzian(-0.69086, bsq) * 0.32158)
# 9           5.506e-08  2.497e+00  y = (Lorentzian(-2.6539, bsq) * 3.8023) * Lorentzian(-0.91...
#                                       613, bsq)
# 11          5.257e-08  2.316e-02  y = (Lorentzian(-2.6412, bsq) * 1.4646) * (Lorentzian(-0.9...
#                                       3282, bsq) * 2.6301)
# 16          3.553e-08  7.832e-02  y = decay((Pb * Pb) * -0.29652) * ((Lorentzian(0.94211, bs...
#                                       q) * 3.6251) * Lorentzian(-2.5425, bsq))
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.592e-05  1.594e+01  y = 0.010529
# 2           7.894e-06  7.014e-01  y = decay(bsq)
# 3           1.493e-06  1.665e+00  y = Lorentzian(bsq, 2.1028)
# 5           1.087e-06  1.586e-01  y = Lorentzian(bsq, 4.0092) * 1.4466
# 7           9.241e-07  8.133e-02  y = Lorentzian(0.65877, bsq) * Lorentzian(Pb, 3.3861)
# 8           6.688e-07  3.234e-01  y = 0.32133 * (Lorentzian(-0.68996, bsq) * gaussian(Pb))
# 9           5.267e-08  2.542e+00  y = Lorentzian(-2.5831, bsq) * (Lorentzian(-0.94602, bsq) ...
#                                       * 3.7705)
# 11          5.257e-08  9.471e-04  y = Lorentzian(-2.6412, bsq) * ((1.4646 * Lorentzian(-0.93...
#                                       282, bsq)) * 2.6301)
# 14          3.972e-08  9.339e-02  y = Lorentzian(-0.97236, bsq) * (decay(bsq * -0.010738) * ...
#                                       (Lorentzian(-2.2859, bsq) * 3.115))
# 16          3.126e-08  1.198e-01  y = decay((Pb * -0.40085) * Pb) * ((Lorentzian(-2.2945, bs...
#                                       q) * Lorentzian(-0.97449, bsq)) * 3.1674)
# 19          2.987e-08  1.513e-02  y = Lorentzian(-0.98202, bsq) * (3.1775 * (gaussian(Pb) * ...
#                                       (decay((Pb * -1.4201) * Pb) * Lorentzian(-2.2843, bsq))))
# 21          2.987e-08  4.768e-07  y = ((Lorentzian(-0.98202, bsq) * (decay(Pb * Pb) * 3.1775...
#                                       )) * Lorentzian(-2.2843, bsq)) * decay(Pb * (Pb * -1.4201)...
#                                       )
# 23          2.215e-08  1.494e-01  y = gaussian((Pb * Pb) * -0.47331) * ((Lorentzian(-0.9736,...
#                                        bsq) * (Lorentzian(-2.2937, bsq) * decay(Pb * (Pb * -0.61...
#                                       779)))) * 3.1596)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# [ Info: Started!
# [ Info: Final population:
# [ Info: Results saved to:
# PySRRegressor.equations_ = [
# 	    pick         score                                           equation  \
# 	0         0.000000e+00                                        0.010528938
# 	1         7.013835e-01                                         decay(bsq)
# 	2         1.665136e+00                         Lorentzian(bsq, 2.1027613)
# 	3         1.585934e-01             Lorentzian(bsq, 4.0092225) * 1.4466239
# 	4         8.133258e-02  Lorentzian(0.65876645, bsq) * Lorentzian(Pb, 3...
# 	5         3.233883e-01  0.32133126 * (Lorentzian(-0.68996185, bsq) * g...
# 	6         2.541502e+00  Lorentzian(-2.5830884, bsq) * (Lorentzian(-0.9...
# 	7         9.471385e-04  Lorentzian(-2.6412265, bsq) * ((1.4645598 * Lo...
# 	8         9.338929e-02  Lorentzian(-0.9723632, bsq) * (decay(bsq * -0....
# 	9         1.198491e-01  decay((Pb * -0.40084708) * Pb) * ((Lorentzian(...
# 	10        1.513263e-02  Lorentzian(-0.9820153, bsq) * (3.1774893 * (ga...
# 	11        5.691665e-07  ((Lorentzian(-0.9820153, bsq) * (decay(Pb * Pb...
# 	12  >>>>  1.493829e-01  gaussian((Pb * Pb) * -0.4733089) * ((Lorentzia...
#
# 	            loss  complexity
# 	0   1.591817e-05           1
# 	1   7.893799e-06           2
# 	2   1.493230e-06           3
# 	3   1.087362e-06           5
# 	4   9.241229e-07           7
# 	5   6.687811e-07           8
# 	6   5.266517e-08           9
# 	7   5.256550e-08          11
# 	8   3.972149e-08          14
# 	9   3.125546e-08          16
# 	10  2.986825e-08          19
# 	11  2.986822e-08          21
# 	12  2.215425e-08          23
# ]
#   - outputs/20250304_173311_ZkLnxV/hall_of_fame.csv

# %%
model.sympy(2)
# Out:
# 1/(bsq**2 + 2.1027613)

# %%
pick = 12


Pb_plot = np.linspace(-max(unique_Pb),max(unique_Pb), 100)
plt.figure(figsize=(10, 6))

for bsq in unique_bsq:
    Pbbsq_plot = np.array([[Pb, bsq] for Pb in Pb_plot])
    predictions = model.predict(Pbbsq_plot, pick)
    plt.plot(Pb_plot, predictions)
for i, bsq in enumerate(unique_bsq):
    #if bT<1 :
    #    continue
    # Filter data for the current bT value
    mask = PbbsqA2B[:, 1] == bsq
    Pb_values = PbbsqA2B[mask, 0]
    A2B_values = A2B[mask]
    A2B_errors = A2Berr[mask]

    # Plot with error bars
    plt.errorbar(
        Pb_values,
        A2B_values,
        yerr=A2B_errors,
        fmt='o',
        capsize=4
    )
# Add labels, legend, and grid
plt.xlabel("Pb", fontsize=14)
plt.ylabel("$A_{2B}$", fontsize=14)
plt.title("Plot of $A_{2B}$ vs $P\cdot b$ for Different $b^2$ Values", fontsize=16)
plt.grid(True)
plt.tight_layout()
plt.show()



model.sympy(pick)
# Out:
# exp(-0.22402131481921*Pb**4)*exp(-1*Pb*Pb*(-0.61778986))*3.1596062/((bsq + 0.947888664946148)*(bsq + 5.261142263524))

# %%
b2_plot = np.linspace(0,max(unique_bsq), 100)
plt.figure(figsize=(10, 6))

for Pb in unique_Pb:
    Pbbsq_plott = np.array([[Pb, bsq] for bsq in b2_plot])
    predictions = model.predict(Pbbsq_plott, pick)
    plt.plot(b2_plot, predictions)

for i, Pb in enumerate(unique_Pb):
    #if bT<1 :
    #    continue
    # Filter data for the current bT value
    mask = PbbsqA2B[:, 0] == Pb
    Psq_values = PbbsqA2B[mask, 1]
    A2B_values = A2B[mask]
    A2B_errors = A2Berr[mask]

    # Plot with error bars
    plt.errorbar(
        Psq_values,
        A2B_values,
        yerr=A2B_errors,
        fmt='o',
        label=f"$P\cdot b$ = {Pb}",
        capsize=4
    )
# Add labels, legend, and grid
plt.xlabel("$b^2$", fontsize=14)
plt.ylabel("$A_{2B}$", fontsize=14)
plt.title("Plot of $A_{2B}$ vs $b^2$ for Different $P\cdot b$ Values", fontsize=16)
plt.legend(fontsize=10)
plt.grid(True)
plt.tight_layout()
plt.show()

model.sympy(pick)
# Out:
# exp(-0.22402131481921*Pb**4)*exp(-1*Pb*Pb*(-0.61778986))*3.1596062/((bsq + 0.947888664946148)*(bsq + 5.261142263524))

# %%
model.equations_[["complexity", "loss", "equation"]]
# Out:
#     complexity          loss  \
# 0            1  1.687147e-07
# 1            3  2.357845e-08
# 2            5  1.460552e-08
# 3            7  5.461252e-09
# 4            9  5.329660e-09
# 5           10  5.260704e-09
# 6           11  4.486938e-09
# 7           13  4.435568e-09
# 8           20  4.383033e-09
# 9           22  4.328969e-09
# 10          24  4.323697e-09
# 11          26  4.299432e-09
#
#                                              equation
# 0                                        0.0013935398
# 1                           Lorentzian(bsq, 38.60062)
# 2                    Lorentzian(Pb, bsq) * 0.05487445
# 3       Lorentzian(bsq * 0.1501782, bsq) * 0.06752086
# 4   Lorentzian((Pb * 0.2466956) * bsq, bsq) * 0.06...
# 5   gaussian(Pb) * (Lorentzian(bsq * 0.0866972, bs...
# 6   (Lorentzian(Pb, 0.9245338) * Lorentzian(bsq * ...
# 7   (Lorentzian(Pb, 1.4719245) * 1.0686985) * (Lor...
# 8   (gaussian((bsq * -0.00015773368) * bsq) * (Lor...
# 9   (gaussian((bsq * (bsq * bsq)) * -3.177368e-6) ...
# 10  ((gaussian(((bsq * bsq) * (bsq * bsq)) * -7.54...
# 11  (Lorentzian(bsq * 0.094320945, bsq) * gaussian...
