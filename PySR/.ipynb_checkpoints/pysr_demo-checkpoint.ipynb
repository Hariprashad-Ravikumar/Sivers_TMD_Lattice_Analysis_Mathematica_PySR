# %% [markdown]
# # Setup

# %% [markdown]
# ## Instructions
# 1. Work on a copy of this notebook: _File_ > _Save a copy in Drive_ (you will need a Google account).
# 2. (Optional) If you would like to do the deep learning component of this tutorial, turn on the GPU with Edit->Notebook settings->Hardware accelerator->GPU

# %%
pip install -U pysr
# Out:
# Requirement already satisfied: pysr in /opt/homebrew/anaconda3/lib/python3.11/site-packages (1.3.1)
# Requirement already satisfied: sympy<2.0.0,>=1.0.0 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from pysr) (1.11.1)
# Requirement already satisfied: pandas<3.0.0,>=0.21.0 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from pysr) (2.0.3)
# Requirement already satisfied: numpy<3.0.0,>=1.13.0 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from pysr) (1.26.4)
# Requirement already satisfied: scikit_learn<2.0.0,>=1.0.0 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from pysr) (1.2.2)
# Requirement already satisfied: juliacall==0.9.23 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from pysr) (0.9.23)
# Requirement already satisfied: click<9.0.0,>=7.0.0 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from pysr) (8.0.4)
# Requirement already satisfied: setuptools>=50.0.0 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from pysr) (68.0.0)
# Requirement already satisfied: juliapkg~=0.1.8 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from juliacall==0.9.23->pysr) (0.1.15)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from pandas<3.0.0,>=0.21.0->pysr) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from pandas<3.0.0,>=0.21.0->pysr) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from pandas<3.0.0,>=0.21.0->pysr) (2023.3)
# Requirement already satisfied: scipy>=1.3.2 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from scikit_learn<2.0.0,>=1.0.0->pysr) (1.11.1)
# Requirement already satisfied: joblib>=1.1.1 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from scikit_learn<2.0.0,>=1.0.0->pysr) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from scikit_learn<2.0.0,>=1.0.0->pysr) (2.2.0)
# Requirement already satisfied: mpmath>=0.19 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from sympy<2.0.0,>=1.0.0->pysr) (1.3.0)
# Requirement already satisfied: semver~=3.0 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from juliapkg~=0.1.8->juliacall==0.9.23->pysr) (3.0.2)
# Requirement already satisfied: six>=1.5 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas<3.0.0,>=0.21.0->pysr) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Julia and Julia dependencies are installed at first import:

# %%
import pysr

# %% [markdown]
# Now, let's import everything else as well as the PySRRegressor:

# %%
import sympy
import numpy as np
from matplotlib import pyplot as plt
from pysr import PySRRegressor
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Simple PySR example:

# %% [markdown]
# First, let's learn a simple function
#
# $$2.5382 \cos(x3) + x0^2 - 2$$

# %%
# Dataset
np.random.seed(0)
X = 2 * np.random.randn(100, 5)
y = 2.5382 * np.cos(X[:, 3]) + X[:, 0] ** 2 - 2

# %%
print("X length ", len(X))
print("y length ", len(y))
# Out:
# X length  100
# y length  100

# %% [markdown]
# By default, we will set up 30 populations of expressions (which evolve independently except for migrations), use 4 threads, and use `"best"` for our model selection strategy:

# %%
default_pysr_params = dict(
    populations=30,
    model_selection="best",
)

# %% [markdown]
# PySR can run for arbitrarily long, and continue to find more and more accurate expressions. You can set the total number of cycles of evolution with `niterations`, although there are also a [few more ways](https://github.com/MilesCranmer/PySR/pull/134) to stop execution.
#
# **This first execution will take a bit longer to startup, as the library is JIT-compiled. The next execution will be much faster.**

# %%
# Learn equations
model = PySRRegressor(
    niterations=30,
    binary_operators=["+", "*"],
    unary_operators=["cos", "sq(x) = x^2"],
    extra_sympy_mappings={"sq": lambda x: x**2},
)

model.fit(X, y)
# Out:
# /opt/homebrew/anaconda3/lib/python3.11/site-packages/pysr/sr.py:2766: UserWarning: Note: it looks like you are running in Jupyter. The progress bar will be turned off.
#   warnings.warn(
# Compiling Julia backend...
# [ Info: Started!
# Expressions evaluated per second: 1.140e+05
# Progress: 664 / 930 total iterations (71.398%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           3.360e+01  1.594e+01  y = 2.3552
# 2           6.128e+00  1.702e+00  y = sq(x₀)
# 4           3.045e+00  3.496e-01  y = sq(x₀) + -1.7558
# 6           3.030e+00  2.620e-03  y = (sq(x₀) + -1.702) * 0.97769
# 7           1.118e+00  9.964e-01  y = sq(x₀) + (cos(x₃) + -1.852)
# 9           1.850e-13  7.971e+00  y = ((cos(x₃) * 2.5382) + sq(x₀)) + -2
# 12          1.484e-13  7.356e-02  y = cos(x₃) + ((sq(x₀) + (cos(x₃) * 1.5382)) + -2)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           3.360e+01  1.594e+01  y = 2.3552
# 2           6.128e+00  1.702e+00  y = sq(x₀)
# 4           3.045e+00  3.496e-01  y = sq(x₀) + -1.7558
# 6           3.030e+00  2.620e-03  y = (sq(x₀) + -1.702) * 0.97769
# 7           1.118e+00  9.964e-01  y = sq(x₀) + (cos(x₃) + -1.852)
# 9           1.850e-13  7.971e+00  y = ((cos(x₃) * 2.5382) + sq(x₀)) + -2
# 12          1.484e-13  7.356e-02  y = cos(x₃) + ((sq(x₀) + (cos(x₃) * 1.5382)) + -2)
# 16          1.467e-13  2.787e-03  y = (((cos(x₃) * 1.4219) + (sq(x₀) + -0.22233)) + -1.7777)...
#                                        + (cos(x₃) * 1.1163)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# [ Info: Final population:
# [ Info: Results saved to:
# PySRRegressor.equations_ = [
# 	   pick      score                                           equation  \
# 	0         0.000000                                           2.355163
# 	1         1.701709                                             sq(x0)
# 	2         0.349618                                sq(x0) + -1.7557681
# 	3         0.002620                 (sq(x0) + -1.7020099) * 0.97769016
# 	4         0.996444                    sq(x0) + (cos(x3) + -1.8519864)
# 	5  >>>>  14.715181               ((cos(x3) * 2.5382) + sq(x0)) + -2.0
# 	6         0.073565   cos(x3) + ((sq(x0) + (cos(x3) * 1.5382)) + -2.0)
# 	7         0.002787  (((cos(x3) * 1.4219375) + (sq(x0) + -0.2223347...
#
# 	           loss  complexity
# 	0  3.360272e+01           1
# 	1  6.128180e+00           2
# 	2  3.045492e+00           4
# 	3  3.029573e+00           6
# 	4  1.118488e+00           7
# 	5  1.850068e-13           9
# 	6  1.483683e-13          12
# 	7  1.467235e-13          16
# ]
#   - outputs/20250122_104213_eOtdRn/hall_of_fame.csv

# %% [markdown]
# We can print the model, which will print out all the discovered expressions:

# %%
model.equations_[["complexity", "loss", "equation"]]
# Out:
#    complexity          loss                                           equation
# 0           1  3.360272e+01                                           2.355163
# 1           2  6.128180e+00                                             sq(x0)
# 2           4  3.045492e+00                                sq(x0) + -1.7557681
# 3           6  3.029573e+00                 (sq(x0) + -1.7020099) * 0.97769016
# 4           7  1.118488e+00                    sq(x0) + (cos(x3) + -1.8519864)
# 5           9  1.850068e-13               ((cos(x3) * 2.5382) + sq(x0)) + -2.0
# 6          12  1.483683e-13   cos(x3) + ((sq(x0) + (cos(x3) * 1.5382)) + -2.0)
# 7          16  1.467235e-13  (((cos(x3) * 1.4219375) + (sq(x0) + -0.2223347...

# %% [markdown]
# We can also view the SymPy format of the best expression:

# %%
model.sympy()
# Out:
# x0**2 + cos(x3)*2.5382 - 2.0

# %% [markdown]
# We can also view the SymPy of any other expression in the list, using the index of it in `model.equations_`.

# %%
model.sympy(2)
# Out:
# x0**2 - 1.7557681

# %% [markdown]
# ## Output

# %% [markdown]
# `model.equations_` is a Pandas DataFrame. We can export the results in various ways:

# %%
model.latex()
# Out:
# 'x_{0} x_{0} + \\cos{\\left(x_{3} \\right)} 2.54 - 2.00'

# %% [markdown]
# These is also `model.sympy(), model.jax(), model.pytorch()`. All of these can take an index as input, to get the result for an arbitrary equation in the list.
#
# We can also use `model.predict` for arbitrary equations, with the default equation being the one chosen by `model_selection`:

# %%
ypredict = model.predict(X)
ypredict_simpler = model.predict(X, 2)

print("Default selection MSE:", np.power(ypredict - y, 2).mean())
print("Manual selection MSE for index 2:", np.power(ypredict_simpler - y, 2).mean())
# Out:
# Default selection MSE: 0.0
# Manual selection MSE for index 2: 3.045492014017809

# %% [markdown]
# # Custom operators

# %% [markdown]
# A full list of operators is given here: https://ai.damtp.cam.ac.uk/pysr/operators,
# but we can also use any binary or unary operator in `julia`, or define our own as arbitrary functions.
#
# Say that we want a command to do quartic powers:
#
# $$ y = x_0^4 - 2 $$

# %%
y = X[:, 0] ** 4 - 2

# %% [markdown]
# We can do this by passing a string in Julia syntax.
#
# We also define the operator in sympy, with `extra_sympy_mappings`, to enable its use in `predict`, and other export functions.

# %%
model = PySRRegressor(
    niterations=5,
    populations=40,
    binary_operators=["+", "*"],
    unary_operators=["cos", "exp", "sin", "quart(x) = x^4"],
    extra_sympy_mappings={"quart": lambda x: x**4},
)
model.fit(X, y)
# Out:
# /opt/homebrew/anaconda3/envs/notebook/lib/python3.12/site-packages/pysr/sr.py:2766: UserWarning: Note: it looks like you are running in Jupyter. The progress bar will be turned off.
#   warnings.warn(
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.590e+04  1.594e+01  y = 46.885
# 2           4.000e+00  8.288e+00  y = quart(x₀)
# 4           9.195e-11  7.971e+00  y = quart(x₀) + -2
# 11          8.732e-11  7.386e-03  y = ((exp(x₄ + x₁) * 9.4984e-08) + -2) + quart(x₀)
# 13          8.687e-11  2.557e-03  y = (-2 + ((1.6743 + exp(x₄ + x₁)) * 9.644e-08)) + quart(x...
#                                       ₀)
# 14          7.920e-11  9.239e-02  y = ((exp((x₁ + x₄) + cos(x₀)) * 6.2393e-08) + -2) + quart...
#                                       (x₀)
# 15          7.761e-11  2.036e-02  y = (-2 + (exp((x₄ + sin(x₀)) + cos(x₀)) * 9.644e-08)) + q...
#                                       uart(x₀)
# 17          7.642e-11  7.711e-03  y = (-2 + (exp(x₄ + (sin(x₀) + cos(x₄ + x₀))) * 9.644e-08)...
#                                       ) + quart(x₀)
# 18          7.367e-11  3.665e-02  y = (quart(x₀) + ((((x₀ + ((x₂ * x₀) * x₄)) * 0.24155) * -...
#                                       7.4828e-07) + -1.8952)) + -0.10476
# 19          7.283e-11  1.142e-02  y = ((cos(x₄) * 8.3214e-05) + -1.2217) + ((sin((cos(x₄) * ...
#                                       -8.4278e-05) + 0.0030122) + quart(x₀)) + -0.78132)
# 20          7.243e-11  5.561e-03  y = (-2 + (exp(x₄ + (sin(x₀) + cos((x₄ + sin(x₀)) + x₀))) ...
#                                       * 9.644e-08)) + quart(x₀)
# 21          7.211e-11  4.360e-03  y = quart(x₀) + (-2 + (exp(x₄ + (sin(x₀) + cos(sin(x₄ + (x...
#                                       ₀ + cos(1.2932)))))) * 9.644e-08))
# 23          7.177e-11  2.359e-03  y = quart(x₀) + ((exp((x₄ + sin(x₀)) + cos(cos(1.2932 + qu...
#                                       art(x₀ + (x₄ + x₀))))) * 9.644e-08) + -2)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# [ Info: Started!
# [ Info: Final population:
# [ Info: Results saved to:
# PySRRegressor.equations_ = [
# 	    pick      score                                           equation  \
# 	0          0.000000                                           46.88486
# 	1          8.288017                                          quart(x0)
# 	2   >>>>  12.248043                             quart(x0) + -1.9999999
# 	3          0.007386  ((exp(x4 + x1) * 9.498383e-8) + -2.0000024) + ...
# 	4          0.002557  (-2.0000024 + ((1.6742617 + exp(x4 + x1)) * 9....
# 	5          0.092395  ((exp((x1 + x4) + cos(x0)) * 6.239345e-8) + -2...
# 	6          0.020359  (-2.0000024 + (exp((x4 + sin(x0)) + cos(x0)) *...
# 	7          0.007711  (-2.0000024 + (exp(x4 + (sin(x0) + cos(x4 + x0...
# 	8          0.036649  (quart(x0) + ((((x0 + ((x2 * x0) * x4)) * 0.24...
# 	9          0.011415  ((cos(x4) * 8.3214e-5) + -1.2216889) + ((sin((...
# 	10         0.005561  (-2.0000024 + (exp(x4 + (sin(x0) + cos((x4 + s...
# 	11         0.004360  quart(x0) + (-2.0000024 + (exp(x4 + (sin(x0) +...
# 	12         0.002359  quart(x0) + ((exp((x4 + sin(x0)) + cos(cos(1.2...
#
# 	            loss  complexity
# 	0   1.590376e+04           1
# 	1   3.999999e+00           2
# 	2   9.194854e-11           4
# 	3   8.731516e-11          11
# 	4   8.686985e-11          13
# 	5   7.920316e-11          14
# 	6   7.760698e-11          15
# 	7   7.641927e-11          17
# 	8   7.366932e-11          18
# 	9   7.283314e-11          19
# 	10  7.242926e-11          20
# 	11  7.211416e-11          21
# 	12  7.177467e-11          23
# ]
#   - outputs/20250114_101807_9Z8JQK/hall_of_fame.csv

# %%
model.sympy()
# Out:
# x0**4 - 1.9999999

# %% [markdown]
# Since `quart` is arguably more complex than the other operators, you can also give it a different complexity, using, e.g., `complexity_of_operators={"quart": 2}` to give it a complexity of 2 (instead of the default 1). You can also define custom complexities for variables and constants (`complexity_of_variables` and `complexity_of_constants`, respectively - both take a single number).
#
#
# One can also add a binary operator, with, e.g., `"myoperator(x, y) = x^2 * y"`. All Julia operators that work on scalar 32-bit floating point values are available.
#
# Make sure that any operator you add is valid over the real line. So, e.g., you will need to define `"mysqrt(x) = sqrt(abs(x))"` to enable it for negative numbers,
# or, simply have it return a very large number for bad inputs (to prevent negative input in a soft way):
# `"mysqrt(x::T) where {T} = (x >= 0) ? x : T(-1e9)"` (Julia syntax for a template function of input type `T`), which will make `mysqrt(x)` return -10^9 for negative x–hurting the loss of the equation.

# %% [markdown]
# ## Scoring

# %% [markdown]
# Using `model_selection="best"`selects the equation with the max score and prints it. But in practice it is best to look through all the equations manually, select an equation above some MSE threshold, and then use the score to select among that loss threshold.
#
# Here, "score" is defined by:
# $$ \text{score} = - \log(\text{loss}_i/\text{loss}_{i-1})/
# (\text{complexity}_i - \text{complexity}_{i-1})$$

# %% [markdown]
# This scoring is motivated by the common strategy of looking for drops in the loss-complexity curve.
#
# From Schmidt & Lipson (2009) -

# %% [markdown]
# ![F4.large.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # Noise example

# %% [markdown]
# Here is an example with noise. Known Gaussian noise with $\sigma$ between 0.1 and 5.0. We record samples of $y$:
#
# $$ \sigma \sim U(0.1, 5.0) $$
# $$ \epsilon \sim \mathcal{N}(0, \sigma^2)$$
# $$ y = 5\;\cos(3.5 x_0) - 1.3 + \epsilon.$$
# We have 5 features, say. The weights change the loss function to be:
# $$MSE = \sum [(y - f(x))^2*w],$$
#
# so in this example, we can set:
# $$w = 1/\sigma^2.$$

# %%
np.random.seed(0)
N = 3000
upper_sigma = 5
X = 2 * np.random.rand(N, 5)
sigma = np.random.rand(N) * (5 - 0.1) + 0.1
eps = sigma * np.random.randn(N)
y = 5 * np.cos(3.5 * X[:, 0]) - 1.3 + eps

# %% [markdown]
# Let's look at this dataset:

# %%
plt.scatter(X[:, 0], y, alpha=0.2)
plt.xlabel("$x_0$")
plt.ylabel("$y$")
# Out:
# Text(0, 0.5, '$y$')

# %% [markdown]
# Define some weights to use:

# %%
weights = 1 / sigma**2

# %%
weights[:5]
# Out:
# array([0.25199296, 0.0775419 , 0.11515701, 0.1781281 , 0.0448131 ])

# %% [markdown]
# Let's run PySR again:

# %%
model = PySRRegressor(
    elementwise_loss="myloss(x, y, w) = w * abs(x - y)",  # Custom loss function with weights.
    niterations=20,
    populations=20,  # Use more populations
    binary_operators=["+", "*"],
    unary_operators=["cos"],
)
model.fit(X, y, weights=weights)
# Out:
# /opt/homebrew/anaconda3/envs/notebook/lib/python3.12/site-packages/pysr/sr.py:2766: UserWarning: Note: it looks like you are running in Jupyter. The progress bar will be turned off.
#   warnings.warn(
# [ Info: Started!
# Expressions evaluated per second: 2.420e+04
# Progress: 137 / 400 total iterations (34.250%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           3.304e+00  1.594e+01  y = -1.1849
# 3           3.183e+00  1.860e-02  y = x₀ + -2.087
# 4           2.743e+00  1.488e-01  y = cos(x₀ * 3.3338)
# 6           1.089e+00  4.618e-01  y = cos(x₀ * 3.2923) * 5.0103
# 8           3.126e-01  6.242e-01  y = (cos(x₀ * 3.4946) * 5.0319) + -1.2825
# 10          3.126e-01  7.606e-05  y = (cos(x₀ * 3.4949) * (4.3992 * 1.1427)) + -1.2838
# 15          3.122e-01  2.355e-04  y = ((cos((cos(x₁) * 0.004346) + (x₀ * 3.4949)) * 1.1427) ...
#                                       * 4.3992) + -1.2838
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.070e+04
# Progress: 236 / 400 total iterations (59.000%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           3.304e+00  1.594e+01  y = -1.1849
# 3           3.183e+00  1.860e-02  y = x₀ + -2.087
# 4           2.743e+00  1.488e-01  y = cos(x₀ * 3.3338)
# 6           1.089e+00  4.618e-01  y = cos(x₀ * 3.2923) * 5.0103
# 8           3.126e-01  6.242e-01  y = (cos(x₀ * 3.4946) * 5.0319) + -1.2825
# 10          3.126e-01  7.606e-05  y = (cos(x₀ * 3.4949) * (4.3992 * 1.1427)) + -1.2838
# 12          3.121e-01  8.193e-04  y = (cos(((x₂ * 0.004346) + 3.4949) * x₀) * 5.027) + -1.28...
#                                       38
# 16          3.118e-01  1.874e-04  y = ((1.1427 * cos(((x₂ * (0.004346 * x₀)) + 3.4949) * x₀)...
#                                       ) * 4.3992) + -1.2838
# 17          3.118e-01  1.340e-04  y = (1.1427 * (4.3992 * cos(((cos(x₁) * (x₂ * 0.004346)) +...
#                                        3.4949) * x₀))) + -1.2838
# 19          3.115e-01  4.013e-04  y = ((1.1427 * cos(((x₄ + -0.15241) * (cos(x₁) * 0.004346)...
#                                       ) + (x₀ * 3.4949))) * 4.3992) + -1.2838
# 23          3.114e-01  1.135e-04  y = (cos(3.4949 * x₀) * ((4.3992 * 1.1427) + ((-0.14348 * ...
#                                       0.53908) * (x₄ * cos((x₀ * 3.4949) + 4.3992))))) + -1.2838
# 26          3.090e-01  2.613e-03  y = (((cos((x₀ * 3.4945) + ((x₂ * (x₁ + 1.0002)) * 1.1429)...
#                                       ) * (cos(x₁) * 0.01558)) + cos(x₀ * 3.4924)) * 5.0282) + -...
#                                       1.2842
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.840e+04
# Progress: 299 / 400 total iterations (74.750%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           3.304e+00  1.594e+01  y = -1.1849
# 3           3.183e+00  1.860e-02  y = x₀ + -2.087
# 4           2.743e+00  1.488e-01  y = cos(x₀ * 3.3338)
# 6           1.089e+00  4.618e-01  y = cos(x₀ * 3.2909) * 4.9865
# 8           3.126e-01  6.242e-01  y = (cos(x₀ * 3.4965) * 5.0277) + -1.2902
# 10          3.126e-01  1.538e-05  y = ((cos(x₀ * 3.495) + 0.010797) * 5.026) + -1.3424
# 12          3.121e-01  8.173e-04  y = (cos(((x₂ * 0.004346) + 3.4949) * x₀) * 5.027) + -1.28...
#                                       38
# 14          3.075e-01  7.386e-03  y = (cos(x₀ * (((x₂ * 0.013387) * x₄) + 3.4836)) * 5.0275)...
#                                        + -1.2862
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           3.304e+00  1.594e+01  y = -1.1849
# 3           3.183e+00  1.860e-02  y = x₀ + -2.087
# 4           2.743e+00  1.488e-01  y = cos(x₀ * 3.3338)
# 6           1.089e+00  4.618e-01  y = cos(x₀ * 3.2909) * 4.9865
# 8           3.126e-01  6.242e-01  y = (cos(x₀ * 3.4965) * 5.0277) + -1.2902
# 10          3.126e-01  1.538e-05  y = ((cos(x₀ * 3.495) + 0.010797) * 5.026) + -1.3424
# 12          3.102e-01  3.813e-03  y = (cos(((x₂ * 0.013137) + 3.4834) * x₀) * 5.043) + -1.29...
#                                       4
# 14          3.075e-01  4.391e-03  y = (cos(x₀ * (((x₂ * 0.013387) * x₄) + 3.4836)) * 5.0275)...
#                                        + -1.2862
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# [ Info: Final population:
# [ Info: Results saved to:
# PySRRegressor.equations_ = [
# 	   pick     score                                           equation  \
# 	0        0.000000                                         -1.1848665
# 	1        0.018599                                     x0 + -2.086953
# 	2        0.148813                                cos(x0 * 3.3338242)
# 	3        0.461797                     cos(x0 * 3.2909038) * 4.986466
# 	4  >>>>  0.624200      (cos(x0 * 3.496467) * 5.0276823) + -1.2902131
# 	5        0.000015  ((cos(x0 * 3.4949968) + 0.01079657) * 5.025972...
# 	6        0.003813  (cos(((x2 * 0.013137442) + 3.48337) * x0) * 5....
# 	7        0.004391  (cos(x0 * (((x2 * 0.013386733) * x4) + 3.48362...
#
# 	       loss  complexity
# 	0  3.304065           1
# 	1  3.183421           3
# 	2  2.743251           4
# 	3  1.089317           6
# 	4  0.312594           8
# 	5  0.312585          10
# 	6  0.310210          12
# 	7  0.307498          14
# ]
#   - outputs/20250114_101811_AGN7Qz/hall_of_fame.csv

# %% [markdown]
# Let's see if we get similar results to the true equation

# %%
model
# Out:
# PySRRegressor.equations_ = [
# 	   pick     score                                           equation  \
# 	0        0.000000                                         -1.1848665
# 	1        0.018599                                     x0 + -2.086953
# 	2        0.148813                                cos(x0 * 3.3338242)
# 	3        0.461797                     cos(x0 * 3.2909038) * 4.986466
# 	4  >>>>  0.624200      (cos(x0 * 3.496467) * 5.0276823) + -1.2902131
# 	5        0.000015  ((cos(x0 * 3.4949968) + 0.01079657) * 5.025972...
# 	6        0.003813  (cos(((x2 * 0.013137442) + 3.48337) * x0) * 5....
# 	7        0.004391  (cos(x0 * (((x2 * 0.013386733) * x4) + 3.48362...
#
# 	       loss  complexity
# 	0  3.304065           1
# 	1  3.183421           3
# 	2  2.743251           4
# 	3  1.089317           6
# 	4  0.312594           8
# 	5  0.312585          10
# 	6  0.310210          12
# 	7  0.307498          14
# ]

# %% [markdown]
# We can also filter all equations up to 2x the most accurate equation, then select the best score from that list:

# %%
best_idx = model.equations_.query(
    f"loss < {2 * model.equations_.loss.min()}"
).score.idxmax()
model.sympy(best_idx)
# Out:
# cos(x0*3.496467)*5.0276823 - 1.2902131

# %% [markdown]
# We can also use `denoise=True`, which will run the input through a Gaussian process to denoise the dataset, before fitting on it.

# %% [markdown]
# Let's look at the fit:

# %%
plt.scatter(X[:, 0], y, alpha=0.1)
y_prediction = model.predict(X, index=best_idx)
plt.scatter(X[:, 0], y_prediction)

# %% [markdown]
# # Multiple outputs

# %% [markdown]
# For multiple outputs, multiple equations are returned:

# %%
X = 2 * np.random.randn(100, 5)
y = 1 / X[:, [0, 1, 2]]

# %%
model = PySRRegressor(
    binary_operators=["+", "*"],
    unary_operators=["inv(x) = 1/x"],
    extra_sympy_mappings={"inv": lambda x: 1 / x},
)
model.fit(X, y)
# Out:
# /opt/homebrew/anaconda3/envs/notebook/lib/python3.12/site-packages/pysr/sr.py:2766: UserWarning: Note: it looks like you are running in Jupyter. The progress bar will be turned off.
#   warnings.warn(
# [ Info: Started!
# Expressions evaluated per second: 7.400e+04
# Progress: 461 / 9300 total iterations (4.957%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Best equations for output 1
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.969e+01  1.594e+01  y₀ = -1.3211
# 2           3.991e-14  1.594e+01  y₀ = inv(x₀)
# 8           3.989e-14  1.113e-04  y₀ = ((x₂ * x₂) * 8.1397e-10) + inv(x₀)
# 9           3.334e-14  1.793e-01  y₀ = (inv(x₀ * 0.25312) + inv(x₀)) * 0.20199
# 11          3.111e-14  3.460e-02  y₀ = inv(x₀) + (inv(x₂ + (x₀ * -0.45429)) * 2.7487e-09)
# 13          3.079e-14  5.165e-03  y₀ = inv(x₀) + ((inv(x₄ * x₀) * (x₂ * -1.7914e-09)) * 0.8...
#                                        9119)
# 17          3.071e-14  6.498e-04  y₀ = (((x₂ * (x₄ * 1.6651)) * 6.6258e-10) * (inv(x₀ * x₃)...
#                                         + 1.4897)) + inv(x₀)
# 19          3.007e-14  1.056e-02  y₀ = ((inv(x₀) * -1.2108e-08) * ((-0.73237 * (-1.0311 + x...
#                                        ₄)) + ((0.89119 * 0.93754) + 0.99323))) + inv(x₀)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Best equations for output 2
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           6.356e+02  1.594e+01  y₁ = -0.22132
# 2           2.336e-12  1.594e+01  y₁ = inv(x₁)
# 6           2.336e-12  1.878e-06  y₁ = (x₂ * -5.5897e-09) + inv(x₁)
# 7           1.344e-14  5.158e+00  y₁ = (inv(x₁) * -4.0121e-08) + inv(x₁)
# 13          1.038e-14  4.310e-02  y₁ = (((x₄ + 3.2027) * 1.4769e-09) + (inv(x₁) * -4.0121e-...
#                                        08)) + inv(x₁)
# 15          1.012e-14  1.246e-02  y₁ = inv(x₁) + ((((x₄ + x₁) + 1.1082) * 3.25e-09) + (inv(...
#                                        x₁) * -4.0121e-08))
# 16          9.861e-15  2.600e-02  y₁ = ((inv(x₁) * -4.0121e-08) + (((inv(x₄) + 2.7778) * 1....
#                                        4769e-09) * x₄)) + inv(x₁)
# 17          8.189e-15  1.858e-01  y₁ = inv(x₁) + (((((x₄ + x₁) * 9.7236) + 1.1082) * 1.0423...
#                                        e-09) + (inv(x₁) * -4.0121e-08))
# 21          8.122e-15  2.042e-03  y₁ = inv(x₁) + ((inv(x₁) * -4.0121e-08) + ((inv(inv(x₃)) ...
#                                        + (3.1183 + 4.4247e-08)) * (x₄ * (-1.4059e-09 * -1.0505))...
#                                        ))
# 22          7.705e-15  5.276e-02  y₁ = ((-4.0121e-08 * inv(x₁)) + (-1.0505 * (-1.4059e-09 *...
#                                         (((3.1183 + (x₃ + 0.0057366)) + inv(x₄)) * x₄)))) + inv(...
#                                        x₁)
# 23          7.545e-15  2.097e-02  y₁ = inv(x₁) + ((1.4769e-09 * (x₄ * (x₃ + 3.0113))) + (((...
#                                        (x₄ + x₁) + x₁) * 1.4769e-09) + (inv(x₁) * -4.0121e-08)))
# 29          7.512e-15  7.373e-04  y₁ = inv(x₁) + ((((x₄ * (x₃ + 3.0113)) * 1.4769e-09) + (1...
#                                        .4769e-09 * (((x₄ + x₁) * (1.4769e-09 * x₄)) + (0.059077 ...
#                                        + x₁)))) + (inv(x₁) * -4.0121e-08))
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Best equations for output 3
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.910e+04  1.594e+01  y₂ = 13.14
# 2           1.490e-10  1.594e+01  y₂ = inv(x₂)
# 4           6.788e-15  4.997e+00  y₂ = inv(x₂ + 5.3213e-11)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.180e+05
# Progress: 1144 / 9300 total iterations (12.301%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Best equations for output 1
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.969e+01  1.594e+01  y₀ = -1.3211
# 2           3.991e-14  1.594e+01  y₀ = inv(x₀)
# 6           3.991e-14  5.560e-05  y₀ = (x₂ * 4.9903e-09) + inv(x₀)
# 8           3.989e-14  2.226e-04  y₀ = ((x₂ * x₂) * 8.1397e-10) + inv(x₀)
# 9           3.082e-14  2.579e-01  y₀ = inv(x₀ + (inv(x₃ + -1.9784) * 8.1397e-10))
# 11          3.078e-14  5.766e-04  y₀ = inv((inv(1.2422 + (x₃ * -0.52177)) * 8.1397e-10) + x...
#                                        ₀)
# 12          2.276e-14  3.021e-01  y₀ = (((x₂ + inv(x₃)) * 1.006e-08) * inv(x₀)) + inv(x₀)
# 14          1.403e-14  2.417e-01  y₀ = inv(x₀) + (9.9764e-09 * (((x₂ + inv(x₃)) + x₂) * inv...
#                                        (x₀)))
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Best equations for output 2
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           6.356e+02  1.594e+01  y₁ = -0.22132
# 2           2.336e-12  1.594e+01  y₁ = inv(x₁)
# 6           2.336e-12  1.878e-06  y₁ = (x₂ * -5.5897e-09) + inv(x₁)
# 7           1.344e-14  5.158e+00  y₁ = (inv(x₁) * -4.0121e-08) + inv(x₁)
# 9           8.948e-15  2.033e-01  y₁ = ((x₂ * 1.8462e-08) * inv(x₁)) + inv(x₁)
# 11          7.609e-15  8.104e-02  y₁ = inv(x₁) + (-1.7607e-10 * inv((x₁ * -0.66398) * x₁))
# 17          7.321e-15  6.445e-03  y₁ = (((x₄ + x₁) * ((x₃ + 3.0113) * 1.4769e-09)) + (inv(x...
#                                        ₁) * -4.0121e-08)) + inv(x₁)
# 19          7.228e-15  6.410e-03  y₁ = (((((x₄ + x₁) + x₁) * (x₃ + 3.0113)) * 1.4769e-09) +...
#                                         (inv(x₁) * -4.0121e-08)) + inv(x₁)
# 21          7.201e-15  1.847e-03  y₁ = (((((x₄ + (x₁ + -0.20125)) + x₁) * (x₃ + 3.0113)) * ...
#                                        1.4769e-09) + (inv(x₁) * -4.0121e-08)) + inv(x₁)
# 25          7.192e-15  3.085e-04  y₁ = inv(x₁) + ((inv(x₁) * -4.0121e-08) + ((((x₁ * 1.4769...
#                                        e-09) + ((x₁ + 0.33377) * 1.4769e-09)) + (x₄ * 1.4769e-09...
#                                        )) * (x₃ + 3.0113)))
# 29          7.188e-15  1.544e-04  y₁ = ((inv(x₁) * -4.0121e-08) + ((1.4769e-09 * ((-1.5667 ...
#                                        + x₁) + ((x₁ + x₁) + x₁))) + (1.4769e-09 * (x₄ * (3.0113 ...
#                                        + (x₀ + x₃)))))) + inv(x₁)
# 30          6.668e-15  7.504e-02  y₁ = ((((x₄ + x₁) + ((((inv(x₂) * x₁) + 1.1071) * 0.14355...
#                                        ) + (x₁ + -0.20125))) * ((x₃ + 3.0113) * 1.4769e-09)) + (...
#                                        inv(x₁) * -4.0121e-08)) + inv(x₁)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Best equations for output 3
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.910e+04  1.594e+01  y₂ = 13.14
# 2           1.490e-10  1.594e+01  y₂ = inv(x₂)
# 4           6.788e-15  4.997e+00  y₂ = inv(x₂ + 5.3213e-11)
# 16          4.514e-15  3.399e-02  y₂ = inv((inv(inv(x₀ * ((x₄ * x₀) * (x₀ + x₁)))) * 2.2436...
#                                        e-11) + x₂)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.540e+05
# Progress: 2113 / 9300 total iterations (22.720%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Best equations for output 1
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.969e+01  1.594e+01  y₀ = -1.3211
# 2           3.991e-14  1.594e+01  y₀ = inv(x₀)
# 6           3.825e-14  1.067e-02  y₀ = -0.14036 + (inv(x₀) + 0.14036)
# 7           3.139e-14  1.976e-01  y₀ = inv(x₀ + (inv(x₁) * 3.1767e-10))
# 9           2.172e-14  1.840e-01  y₀ = inv((inv(x₂ + -0.043553) * -4.9349e-10) + x₀)
# 14          1.403e-14  8.741e-02  y₀ = inv(x₀) + (9.9764e-09 * (((x₂ + inv(x₃)) + x₂) * inv...
#                                        (x₀)))
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Best equations for output 2
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           6.356e+02  1.594e+01  y₁ = -0.22132
# 2           2.336e-12  1.594e+01  y₁ = inv(x₁)
# 6           2.336e-12  1.878e-06  y₁ = (x₂ * -5.5897e-09) + inv(x₁)
# 7           1.344e-14  5.158e+00  y₁ = (inv(x₁) * -4.0121e-08) + inv(x₁)
# 9           7.609e-15  2.844e-01  y₁ = (inv(x₁ * x₁) * 2.3308e-10) + inv(x₁)
# 16          7.121e-15  9.478e-03  y₁ = inv(x₁) + (((x₀ + -0.82134) * 1.1011e-08) * (inv(x₁)...
#                                         + (0.017562 * inv(x₂))))
# 18          7.083e-15  2.657e-03  y₁ = inv(x₁) + ((1.1011e-08 * (x₀ + -0.82134)) * (inv(x₁)...
#                                         + ((0.017562 * inv(x₂)) + 0.17265)))
# 25          6.548e-15  1.122e-02  y₁ = inv(x₁) + ((((inv(inv((x₃ * 0.16798) * x₃)) + 3.0113...
#                                        ) * 1.4769e-09) * ((x₁ + x₄) + -0.39203)) + (inv(x₁) * -4...
#                                        .0121e-08))
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Best equations for output 3
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.910e+04  1.594e+01  y₂ = 13.14
# 2           1.490e-10  1.594e+01  y₂ = inv(x₂)
# 4           6.788e-15  4.997e+00  y₂ = inv(x₂ + 5.3213e-11)
# 14          4.514e-15  4.079e-02  y₂ = inv((((x₀ * x₀) * x₄) * ((x₀ + -0.43541) * 2.2436e-1...
#                                        1)) + x₂)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.750e+05
# Progress: 3143 / 9300 total iterations (33.796%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Best equations for output 1
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.969e+01  1.594e+01  y₀ = -1.3211
# 2           3.991e-14  1.594e+01  y₀ = inv(x₀)
# 4           3.825e-14  2.134e-02  y₀ = inv(x₀) + 0
# 7           3.139e-14  6.588e-02  y₀ = inv(x₀ + (inv(x₁) * 3.1767e-10))
# 9           2.172e-14  1.840e-01  y₀ = inv((inv(x₂ + -0.043553) * -4.9349e-10) + x₀)
# 14          1.389e-14  8.944e-02  y₀ = (inv(x₀) * ((x₂ + (inv(x₃) + x₂)) * 9.9357e-09)) + i...
#                                        nv(x₀)
# 20          1.387e-14  2.133e-04  y₀ = inv(x₀) + ((inv(x₀) * (inv(inv((x₀ * 0.08065) + x₂))...
#                                         + (inv(x₃) + x₂))) * 9.9764e-09)
# 21          1.293e-14  7.027e-02  y₀ = inv(x₀) + ((inv(x₀ * inv(((x₂ + inv(inv(x₀))) + x₂) ...
#                                        + inv(x₃))) + 2.0351) * 9.3567e-09)
# 27          4.852e-15  1.634e-01  y₀ = ((inv(inv((x₂ + inv(x₃)) + inv(inv(-0.5601) + (x₀ + ...
#                                        inv(inv(x₃ + x₂))))) * x₀) + x₂) * 9.9764e-09) + inv(x₀)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Best equations for output 2
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           6.356e+02  1.594e+01  y₁ = -0.22132
# 2           2.336e-12  1.594e+01  y₁ = inv(x₁)
# 6           2.336e-12  1.878e-06  y₁ = (x₂ * -5.5897e-09) + inv(x₁)
# 7           1.344e-14  5.158e+00  y₁ = (inv(x₁) * -4.0121e-08) + inv(x₁)
# 9           7.609e-15  2.844e-01  y₁ = (inv(x₁ * x₁) * 2.3308e-10) + inv(x₁)
# 13          7.598e-15  3.650e-04  y₁ = (((x₂ + -1.5418) * (inv(x₁) + -0.34907)) * 1.1011e-0...
#                                        8) + inv(x₁)
# 14          5.904e-15  2.523e-01  y₁ = (inv(x₃ + (x₁ * -17.831)) * (inv(x₁) * -1.5925e-08))...
#                                         + inv(x₁)
# 16          5.336e-15  5.062e-02  y₁ = ((inv(x₃ + (x₁ * -17.831)) * (x₂ + inv(x₁))) * -1.59...
#                                        25e-08) + inv(x₁)
# 21          4.767e-15  2.253e-02  y₁ = ((inv(x₃ + (x₁ * -17.831)) * (((inv(x₂) * 0.055713) ...
#                                        + inv(x₁)) + x₂)) * -1.5925e-08) + inv(x₁)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Best equations for output 3
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.910e+04  1.594e+01  y₂ = 13.14
# 2           1.490e-10  1.594e+01  y₂ = inv(x₂)
# 4           6.788e-15  4.997e+00  y₂ = inv(x₂ + 5.3213e-11)
# 14          4.514e-15  4.079e-02  y₂ = inv((((x₀ * x₀) * x₄) * ((x₀ + -0.43541) * 2.2436e-1...
#                                        1)) + x₂)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.020e+05
# Progress: 3991 / 9300 total iterations (42.914%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Best equations for output 1
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.969e+01  1.594e+01  y₀ = -1.3211
# 2           3.991e-14  1.594e+01  y₀ = inv(x₀)
# 4           3.825e-14  2.134e-02  y₀ = inv(x₀) + 0
# 7           3.139e-14  6.588e-02  y₀ = inv(x₀ + (inv(x₁) * 3.1767e-10))
# 9           2.172e-14  1.840e-01  y₀ = inv((inv(x₂ + -0.043553) * -4.9349e-10) + x₀)
# 14          1.389e-14  8.944e-02  y₀ = (inv(x₀) * ((x₂ + (inv(x₃) + x₂)) * 9.9357e-09)) + i...
#                                        nv(x₀)
# 18          1.369e-14  3.704e-03  y₀ = inv(x₀) + ((9.9357e-09 * inv(x₀)) * ((x₂ + (inv(x₃) ...
#                                        + (x₁ * 0.17082))) + x₂))
# 19          7.141e-15  6.506e-01  y₀ = inv(x₀) + (9.9357e-09 * (inv(x₀) * ((x₂ + ((inv(x₁) ...
#                                        * 0.17082) + x₂)) + inv(x₃))))
# 22          6.308e-15  4.133e-02  y₀ = (inv(inv((x₂ + inv(x₃)) + inv((x₂ + -1.7854) + (x₃ +...
#                                         x₀))) * x₀) * 9.9764e-09) + inv(x₀)
# 24          4.581e-15  1.600e-01  y₀ = ((x₄ + inv(inv(inv(x₃ + ((x₂ + -1.7854) + x₀)) + (in...
#                                        v(x₃) + x₂)) * x₀)) * 9.9764e-09) + inv(x₀)
# 26          4.288e-15  3.306e-02  y₀ = inv(x₀) + (((x₄ + -0.23461) + inv(x₀ * inv(inv((x₀ +...
#                                         -1.7854) + (x₃ + x₂)) + (x₂ + inv(x₃))))) * 9.9764e-09)
# 29          4.279e-15  6.912e-04  y₀ = inv(x₀) + ((-0.23461 + (inv(x₀ * inv(inv((inv(-0.560...
#                                        1) + x₀) + (x₃ + x₂)) + (x₂ + inv(x₃)))) + (x₄ * 0.71193)...
#                                        )) * 9.9764e-09)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Best equations for output 2
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           6.356e+02  1.594e+01  y₁ = -0.22132
# 2           2.336e-12  1.594e+01  y₁ = inv(x₁)
# 6           2.336e-12  1.878e-06  y₁ = (x₂ * -5.5897e-09) + inv(x₁)
# 7           1.344e-14  5.158e+00  y₁ = (inv(x₁) * -4.0121e-08) + inv(x₁)
# 9           7.609e-15  2.844e-01  y₁ = (inv(x₁ * x₁) * 2.3308e-10) + inv(x₁)
# 13          7.598e-15  3.650e-04  y₁ = (((x₂ + -1.5418) * (inv(x₁) + -0.34907)) * 1.1011e-0...
#                                        8) + inv(x₁)
# 14          5.904e-15  2.523e-01  y₁ = (inv(x₃ + (x₁ * -17.831)) * (inv(x₁) * -1.5925e-08))...
#                                         + inv(x₁)
# 16          5.336e-15  5.062e-02  y₁ = ((inv(x₃ + (x₁ * -17.831)) * (x₂ + inv(x₁))) * -1.59...
#                                        25e-08) + inv(x₁)
# 21          4.767e-15  2.253e-02  y₁ = ((inv(x₃ + (x₁ * -17.831)) * (((inv(x₂) * 0.055713) ...
#                                        + inv(x₁)) + x₂)) * -1.5925e-08) + inv(x₁)
# 23          3.666e-15  1.313e-01  y₁ = ((inv((x₁ * -17.831) + x₃) * -1.5925e-08) * (inv(x₁)...
#                                         + inv(x₀ * (-1.1273 * (1.2731 + x₃))))) + inv(x₁)
# 26          3.630e-15  3.246e-03  y₁ = ((inv(x₁) + (inv(x₄) * ((-1.1336 * -1.1273) * inv(1....
#                                        2731 + x₃)))) * (inv((x₁ * -17.831) + x₃) * -1.5925e-08))...
#                                         + inv(x₁)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Best equations for output 3
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.910e+04  1.594e+01  y₂ = 13.14
# 2           1.490e-10  1.594e+01  y₂ = inv(x₂)
# 4           6.788e-15  4.997e+00  y₂ = inv(x₂ + 5.3213e-11)
# 11          6.752e-15  7.496e-04  y₂ = (-8.8707e-11 * inv(x₃ * x₃)) + inv(x₂ + 7.3353e-11)
# 12          4.514e-15  4.027e-01  y₂ = inv(x₂ + (((x₄ + x₀) * -4.0973e-11) * (x₀ * x₀)))
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.140e+05
# Progress: 4916 / 9300 total iterations (52.860%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Best equations for output 1
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.969e+01  1.594e+01  y₀ = -1.3211
# 2           3.991e-14  1.594e+01  y₀ = inv(x₀)
# 4           3.825e-14  2.134e-02  y₀ = inv(x₀) + 0
# 7           3.139e-14  6.588e-02  y₀ = inv(x₀ + (inv(x₁) * 3.1767e-10))
# 9           2.172e-14  1.840e-01  y₀ = inv((inv(x₂ + -0.043553) * -4.9349e-10) + x₀)
# 14          1.389e-14  8.944e-02  y₀ = (inv(x₀) * ((x₂ + (inv(x₃) + x₂)) * 9.9357e-09)) + i...
#                                        nv(x₀)
# 16          1.375e-14  5.141e-03  y₀ = ((inv(x₀) * 9.8449e-09) * (x₂ + ((x₂ + 0.11739) + in...
#                                        v(x₃)))) + inv(x₀)
# 18          1.358e-14  6.175e-03  y₀ = inv(x₀) + (inv(x₀) * (((x₂ + x₂) + inv(x₃ + (x₀ * 0....
#                                        054162))) * 9.9357e-09))
# 19          7.079e-15  6.515e-01  y₀ = inv(x₀) + (inv(x₀) * ((x₂ + ((x₂ + (inv(x₁) * 0.1708...
#                                        2)) + inv(x₃))) * 9.6998e-09))
# 21          6.308e-15  5.762e-02  y₀ = inv(x₀) + ((((inv(x₃) + x₂) + inv((x₀ + x₂) + (x₃ + ...
#                                        -1.7854))) * 9.9764e-09) * inv(x₀))
# 23          4.636e-15  1.540e-01  y₀ = inv(x₀) + (inv(x₀) * (((x₂ + ((inv(x₁ + (x₂ * 0.5159...
#                                        9)) * 0.17082) + inv(x₃))) + x₂) * 9.9357e-09))
# 24          4.041e-15  1.374e-01  y₀ = inv(x₀) + ((inv(inv((inv(((x₂ + x₀) + -1.7774) + x₃)...
#                                         + inv(x₃)) + x₂) * x₀) + -0.345) * 1.0925e-08)
# 28          2.329e-15  1.377e-01  y₀ = ((9.6488e-09 * ((x₂ + ((x₂ + (x₃ * 0.17082)) * inv((...
#                                        (inv(x₃) + -1.4443) * x₂) + x₁))) + inv(x₃))) * inv(x₀)) ...
#                                        + inv(x₀)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Best equations for output 2
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           6.356e+02  1.594e+01  y₁ = -0.22132
# 2           2.336e-12  1.594e+01  y₁ = inv(x₁)
# 6           2.336e-12  1.878e-06  y₁ = (x₂ * -5.5897e-09) + inv(x₁)
# 7           1.344e-14  5.158e+00  y₁ = (inv(x₁) * -4.0121e-08) + inv(x₁)
# 9           7.609e-15  2.844e-01  y₁ = (inv(x₁ * x₁) * 2.3308e-10) + inv(x₁)
# 13          5.904e-15  6.343e-02  y₁ = (inv(x₁ * (x₃ + (x₁ * -17.831))) * -1.5925e-08) + in...
#                                        v(x₁)
# 16          5.336e-15  3.374e-02  y₁ = ((inv(x₃ + (x₁ * -17.831)) * (x₂ + inv(x₁))) * -1.59...
#                                        25e-08) + inv(x₁)
# 21          4.767e-15  2.253e-02  y₁ = ((inv(x₃ + (x₁ * -17.831)) * (((inv(x₂) * 0.055713) ...
#                                        + inv(x₁)) + x₂)) * -1.5925e-08) + inv(x₁)
# 23          3.666e-15  1.313e-01  y₁ = ((inv((x₁ * -17.831) + x₃) * -1.5925e-08) * (inv(x₁)...
#                                         + inv(x₀ * (-1.1273 * (1.2731 + x₃))))) + inv(x₁)
# 24          3.630e-15  9.738e-03  y₁ = ((((inv(x₄) * 1.2779) * inv(x₃ + 1.2731)) + inv(x₁))...
#                                         * (inv((x₁ * -17.831) + x₃) * -1.5925e-08)) + inv(x₁)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Best equations for output 3
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.910e+04  1.594e+01  y₂ = 13.14
# 2           1.490e-10  1.594e+01  y₂ = inv(x₂)
# 4           6.788e-15  4.997e+00  y₂ = inv(x₂ + 5.3213e-11)
# 6           6.202e-15  4.516e-02  y₂ = inv(x₂ + 7.3353e-11) * 1
# 12          4.514e-15  5.293e-02  y₂ = inv(x₂ + (((x₄ + x₀) * -4.0973e-11) * (x₀ * x₀)))
# 28          3.946e-15  8.412e-03  y₂ = inv((x₂ + (x₂ * (((x₀ + 0.28344) + inv(x₀ + x₃)) * (...
#                                        x₄ * (x₀ * (inv((x₂ * x₂) + -0.13342) * 1.0599e-10)))))) ...
#                                        + 7.3353e-11)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.120e+05
# Progress: 5833 / 9300 total iterations (62.720%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Best equations for output 1
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.969e+01  1.594e+01  y₀ = -1.3211
# 2           3.991e-14  1.594e+01  y₀ = inv(x₀)
# 4           3.825e-14  2.134e-02  y₀ = inv(x₀) + 0
# 7           3.139e-14  6.588e-02  y₀ = inv(x₀ + (inv(x₁) * 3.1767e-10))
# 9           2.172e-14  1.840e-01  y₀ = inv((inv(x₂ + -0.043553) * -4.9349e-10) + x₀)
# 14          1.389e-14  8.944e-02  y₀ = (inv(x₀) * ((x₂ + (inv(x₃) + x₂)) * 9.9357e-09)) + i...
#                                        nv(x₀)
# 16          1.375e-14  5.141e-03  y₀ = ((inv(x₀) * 9.8449e-09) * (x₂ + ((x₂ + 0.11739) + in...
#                                        v(x₃)))) + inv(x₀)
# 17          1.203e-14  1.339e-01  y₀ = ((x₂ + (inv(x₃ + -1.923) + inv(x₃))) * (inv(x₀) * 1....
#                                        1139e-08)) + inv(x₀)
# 19          6.182e-15  3.327e-01  y₀ = ((((inv(x₃) + x₂) + inv((x₂ + x₃) + -1.8132)) * inv(...
#                                        x₀)) * 1.1139e-08) + inv(x₀)
# 21          4.592e-15  1.487e-01  y₀ = (((x₂ + (inv(x₃ + ((x₀ + x₂) + -1.923)) + inv(x₃))) ...
#                                        * inv(x₀)) * 1.1139e-08) + inv(x₀)
# 23          2.798e-15  2.477e-01  y₀ = inv(x₀) + ((inv(x₃) + (x₂ + inv(((x₃ + x₂) + -1.7559...
#                                        ) + (x₄ * -0.68337)))) * (inv(x₀) * 1.0496e-08))
# 25          2.578e-15  4.091e-02  y₀ = (((inv(x₃ * 1.6326) + x₂) + inv((x₂ + x₃) + ((x₄ * -...
#                                        0.68337) + -1.7559))) * (inv(x₀) * 1.1139e-08)) + inv(x₀)
# 28          2.329e-15  3.381e-02  y₀ = ((9.6488e-09 * ((x₂ + ((x₂ + (x₃ * 0.17082)) * inv((...
#                                        (inv(x₃) + -1.4443) * x₂) + x₁))) + inv(x₃))) * inv(x₀)) ...
#                                        + inv(x₀)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Best equations for output 2
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           6.356e+02  1.594e+01  y₁ = -0.22132
# 2           2.336e-12  1.594e+01  y₁ = inv(x₁)
# 6           2.336e-12  1.878e-06  y₁ = (x₂ * -5.5897e-09) + inv(x₁)
# 7           1.344e-14  5.158e+00  y₁ = (inv(x₁) * -4.0121e-08) + inv(x₁)
# 9           7.609e-15  2.844e-01  y₁ = (inv(x₁ * x₁) * 2.3308e-10) + inv(x₁)
# 13          5.904e-15  6.343e-02  y₁ = (inv(x₁ * (x₃ + (x₁ * -17.831))) * -1.5925e-08) + in...
#                                        v(x₁)
# 16          5.336e-15  3.374e-02  y₁ = ((inv(x₃ + (x₁ * -17.831)) * (x₂ + inv(x₁))) * -1.59...
#                                        25e-08) + inv(x₁)
# 21          4.767e-15  2.253e-02  y₁ = ((inv(x₃ + (x₁ * -17.831)) * (((inv(x₂) * 0.055713) ...
#                                        + inv(x₁)) + x₂)) * -1.5925e-08) + inv(x₁)
# 23          3.630e-15  1.362e-01  y₁ = inv(x₁) + (inv((x₁ * -17.831) + x₃) * ((inv(x₁) + in...
#                                        v((x₁ + (1.3076 * x₀)) * -2.1602)) * -1.5925e-08))
# 25          3.062e-15  8.514e-02  y₁ = inv(x₁) + (inv((x₁ * -17.831) + x₃) * ((inv(x₁) + (x...
#                                        ₂ + inv((x₁ + (1.3076 * x₀)) * -2.1602))) * -1.5925e-08))
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Best equations for output 3
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.910e+04  1.594e+01  y₂ = 13.14
# 2           1.490e-10  1.594e+01  y₂ = inv(x₂)
# 4           6.788e-15  4.997e+00  y₂ = inv(x₂ + 5.3213e-11)
# 6           6.202e-15  4.516e-02  y₂ = inv(x₂ + 7.3353e-11) * 1
# 12          4.514e-15  5.293e-02  y₂ = inv(x₂ + (((x₄ + x₀) * -4.0973e-11) * (x₀ * x₀)))
# 20          4.372e-15  3.998e-03  y₂ = inv((x₂ + ((x₂ * x₄) * ((x₀ * (x₄ + x₀)) * ((x₀ + x₄...
#                                        ) * 1.0599e-10)))) + 7.3353e-11)
# 23          3.946e-15  3.420e-02  y₂ = inv((x₂ + (((x₂ * x₀) * x₄) * (inv((x₂ * x₂) + -0.13...
#                                        342) * ((x₄ + -2.073) * 1.0599e-10)))) + 7.3353e-11)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.080e+05
# Progress: 6798 / 9300 total iterations (73.097%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Best equations for output 1
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.969e+01  1.594e+01  y₀ = -1.3211
# 2           3.991e-14  1.594e+01  y₀ = inv(x₀)
# 4           3.825e-14  2.134e-02  y₀ = inv(x₀) + 0
# 7           3.139e-14  6.588e-02  y₀ = inv(x₀ + (inv(x₁) * 3.1767e-10))
# 9           2.172e-14  1.840e-01  y₀ = inv((inv(x₂ + -0.043553) * -4.9349e-10) + x₀)
# 14          1.389e-14  8.944e-02  y₀ = (inv(x₀) * ((x₂ + (inv(x₃) + x₂)) * 9.9357e-09)) + i...
#                                        nv(x₀)
# 16          1.375e-14  5.141e-03  y₀ = ((inv(x₀) * 9.8449e-09) * (x₂ + ((x₂ + 0.11739) + in...
#                                        v(x₃)))) + inv(x₀)
# 17          1.203e-14  1.339e-01  y₀ = ((x₂ + (inv(x₃ + -1.923) + inv(x₃))) * (inv(x₀) * 1....
#                                        1139e-08)) + inv(x₀)
# 19          6.182e-15  3.327e-01  y₀ = ((((inv(x₃) + x₂) + inv((x₂ + x₃) + -1.8132)) * inv(...
#                                        x₀)) * 1.1139e-08) + inv(x₀)
# 21          4.228e-15  1.900e-01  y₀ = (((inv(x₃) + (x₂ + inv((x₂ + (x₃ + x₀)) + -1.8132)))...
#                                         * inv(x₀)) * 1.1139e-08) + inv(x₀)
# 23          2.798e-15  2.064e-01  y₀ = inv(x₀) + ((inv(x₃) + (x₂ + inv(((x₃ + x₂) + -1.7559...
#                                        ) + (x₄ * -0.68337)))) * (inv(x₀) * 1.0496e-08))
# 25          2.578e-15  4.091e-02  y₀ = (((inv(x₃ * 1.6326) + x₂) + inv((x₂ + x₃) + ((x₄ * -...
#                                        0.68337) + -1.7559))) * (inv(x₀) * 1.1139e-08)) + inv(x₀)
# 27          2.454e-15  2.472e-02  y₀ = inv(x₀) + ((inv(((x₄ * -0.68337) + (x₂ + -1.7559)) +...
#                                         x₃) + (inv(x₃ * 1.1619) + (x₂ * 1.3723))) * (inv(x₀) * 8...
#                                        .8181e-09))
# 28          2.294e-15  6.738e-02  y₀ = ((9.6488e-09 * (x₂ + (inv(x₃) + (((x₃ * 0.16198) + x...
#                                        ₂) * inv(((inv(x₃) + -1.4443) * x₂) + x₁))))) * inv(x₀)) ...
#                                        + inv(x₀)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Best equations for output 2
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           6.356e+02  1.594e+01  y₁ = -0.22132
# 2           2.336e-12  1.594e+01  y₁ = inv(x₁)
# 6           2.336e-12  1.878e-06  y₁ = (x₂ * -5.5897e-09) + inv(x₁)
# 7           1.344e-14  5.158e+00  y₁ = (inv(x₁) * -4.0121e-08) + inv(x₁)
# 9           7.609e-15  2.844e-01  y₁ = (inv(x₁ * x₁) * 2.3308e-10) + inv(x₁)
# 13          5.904e-15  6.343e-02  y₁ = (inv(x₁ * (x₃ + (x₁ * -17.831))) * -1.5925e-08) + in...
#                                        v(x₁)
# 16          5.336e-15  3.374e-02  y₁ = ((inv(x₃ + (x₁ * -17.831)) * (x₂ + inv(x₁))) * -1.59...
#                                        25e-08) + inv(x₁)
# 19          3.941e-15  1.010e-01  y₁ = inv(x₁) + (inv((x₁ * -17.831) + x₃) * ((inv(x₁) + in...
#                                        v(x₂ + -1.6058)) * -1.5925e-08))
# 21          3.346e-15  8.184e-02  y₁ = inv(x₁) + (inv((x₁ * -17.831) + x₃) * (-1.5925e-08 *...
#                                         ((inv(x₁) + x₂) + inv(-1.6058 + x₂))))
# 24          3.206e-15  1.423e-02  y₁ = inv(x₁) + (((inv((x₁ * -17.831) + x₃) * ((inv(x₁) + ...
#                                        inv(x₂ + -1.6058)) + x₂)) + inv(-1.6058)) * -1.5925e-08)
# 25          3.062e-15  4.606e-02  y₁ = inv(x₁) + (inv((x₁ * -17.831) + x₃) * ((inv(x₁) + (x...
#                                        ₂ + inv((x₁ + (1.3076 * x₀)) * -2.1602))) * -1.5925e-08))
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Best equations for output 3
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.910e+04  1.594e+01  y₂ = 13.14
# 2           1.490e-10  1.594e+01  y₂ = inv(x₂)
# 4           6.788e-15  4.997e+00  y₂ = inv(x₂ + 5.3213e-11)
# 6           6.202e-15  4.516e-02  y₂ = inv(x₂ + 7.3353e-11) * 1
# 12          4.514e-15  5.293e-02  y₂ = inv(x₂ + (((x₄ + x₀) * -4.0973e-11) * (x₀ * x₀)))
# 20          4.372e-15  3.998e-03  y₂ = inv((x₂ + ((x₂ * x₄) * ((x₀ * (x₄ + x₀)) * ((x₀ + x₄...
#                                        ) * 1.0599e-10)))) + 7.3353e-11)
# 23          3.946e-15  3.420e-02  y₂ = inv((x₂ + (((x₂ * x₀) * x₄) * (inv((x₂ * x₂) + -0.13...
#                                        342) * ((x₄ + -2.073) * 1.0599e-10)))) + 7.3353e-11)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.110e+05
# Progress: 7751 / 9300 total iterations (83.344%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Best equations for output 1
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.969e+01  1.594e+01  y₀ = -1.3211
# 2           3.991e-14  1.594e+01  y₀ = inv(x₀)
# 4           3.825e-14  2.134e-02  y₀ = inv(x₀) + 0
# 7           3.139e-14  6.588e-02  y₀ = inv(x₀ + (inv(x₁) * 3.1767e-10))
# 9           2.172e-14  1.840e-01  y₀ = inv((inv(x₂ + -0.043553) * -4.9349e-10) + x₀)
# 14          1.389e-14  8.944e-02  y₀ = (inv(x₀) * ((x₂ + (inv(x₃) + x₂)) * 9.9357e-09)) + i...
#                                        nv(x₀)
# 16          1.375e-14  5.141e-03  y₀ = ((inv(x₀) * 9.8449e-09) * (x₂ + ((x₂ + 0.11739) + in...
#                                        v(x₃)))) + inv(x₀)
# 17          1.135e-14  1.915e-01  y₀ = inv(x₀) + ((inv(x₀) * 8.7966e-09) * (x₂ + (inv(x₃) +...
#                                         inv(x₃ + -1.9667))))
# 19          5.516e-15  3.610e-01  y₀ = inv(x₀) + (((inv((x₂ + -1.8271) + x₃) + inv(x₃)) + x...
#                                        ₂) * (1.1139e-08 * inv(x₀)))
# 21          4.192e-15  1.372e-01  y₀ = inv(x₀) + (((inv(((x₂ + x₀) + -1.8271) + x₃) + (inv(...
#                                        x₃) + x₂)) * 1.1139e-08) * inv(x₀))
# 23          2.780e-15  2.054e-01  y₀ = ((((inv(x₃) + x₂) + inv((x₃ + x₂) + ((x₄ * -0.47364)...
#                                         + -1.7559))) * inv(x₀)) * 1.0469e-08) + inv(x₀)
# 25          2.578e-15  3.773e-02  y₀ = (((inv(x₃ * 1.6326) + x₂) + inv((x₂ + x₃) + ((x₄ * -...
#                                        0.68337) + -1.7559))) * (inv(x₀) * 1.1139e-08)) + inv(x₀)
# 27          2.445e-15  2.653e-02  y₀ = inv(x₀) + (inv(x₀) * ((inv(((x₃ + x₂) + (x₄ * -0.683...
#                                        37)) + -1.7559) + (inv(x₃ * 1.1619) + (x₂ * 1.3723))) * 8...
#                                        .61e-09))
# 28          2.294e-15  6.375e-02  y₀ = ((9.6488e-09 * (x₂ + (inv(x₃) + (((x₃ * 0.16198) + x...
#                                        ₂) * inv(((inv(x₃) + -1.4443) * x₂) + x₁))))) * inv(x₀)) ...
#                                        + inv(x₀)
# 30          2.285e-15  1.940e-03  y₀ = ((inv(x₀) * (((((x₃ * 0.16198) + x₂) * inv((x₂ * (in...
#                                        v(x₃) + -1.4443)) + x₁)) + x₂) + (inv(x₃) + 0.068448))) *...
#                                         9.6488e-09) + inv(x₀)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Best equations for output 2
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           6.356e+02  1.594e+01  y₁ = -0.22132
# 2           2.336e-12  1.594e+01  y₁ = inv(x₁)
# 6           2.336e-12  1.878e-06  y₁ = (x₂ * -5.5897e-09) + inv(x₁)
# 7           1.344e-14  5.158e+00  y₁ = (inv(x₁) * -4.0121e-08) + inv(x₁)
# 9           7.609e-15  2.844e-01  y₁ = (inv(x₁ * x₁) * 2.3308e-10) + inv(x₁)
# 13          5.904e-15  6.343e-02  y₁ = (inv(x₁ * (x₃ + (x₁ * -17.831))) * -1.5925e-08) + in...
#                                        v(x₁)
# 16          5.336e-15  3.374e-02  y₁ = ((inv(x₃ + (x₁ * -17.831)) * (x₂ + inv(x₁))) * -1.59...
#                                        25e-08) + inv(x₁)
# 19          3.941e-15  1.010e-01  y₁ = inv(x₁) + (inv((x₁ * -17.831) + x₃) * ((inv(x₁) + in...
#                                        v(x₂ + -1.6058)) * -1.5925e-08))
# 21          3.346e-15  8.184e-02  y₁ = inv(x₁) + (inv((x₁ * -17.831) + x₃) * (-1.5925e-08 *...
#                                         ((inv(x₁) + x₂) + inv(-1.6058 + x₂))))
# 24          3.204e-15  1.447e-02  y₁ = inv(x₁) + ((((inv(x₁) + inv(x₂ + -1.6058)) + inv(x₀ ...
#                                        + x₁)) * -1.3459e-08) * inv((-17.831 * x₁) + x₃))
# 25          3.062e-15  4.537e-02  y₁ = inv(x₁) + (inv((x₁ * -17.831) + x₃) * ((inv(x₁) + (x...
#                                        ₂ + inv((x₁ + (1.3076 * x₀)) * -2.1602))) * -1.5925e-08))
# 27          2.778e-15  4.871e-02  y₁ = ((((inv(x₁) + (inv(-1.6058 + x₂) + inv(inv(x₀) + x₁)...
#                                        )) + 0.3004) * -1.5925e-08) * inv(x₃ + (-17.831 * x₁))) +...
#                                         inv(x₁)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Best equations for output 3
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.910e+04  1.594e+01  y₂ = 13.14
# 2           1.490e-10  1.594e+01  y₂ = inv(x₂)
# 4           6.788e-15  4.997e+00  y₂ = inv(x₂ + 5.3213e-11)
# 6           6.202e-15  4.516e-02  y₂ = inv(x₂ + 7.3353e-11) * 1
# 12          4.514e-15  5.293e-02  y₂ = inv(x₂ + (((x₄ + x₀) * -4.0973e-11) * (x₀ * x₀)))
# 20          4.372e-15  3.998e-03  y₂ = inv((x₂ + ((x₂ * x₄) * ((x₀ * (x₄ + x₀)) * ((x₀ + x₄...
#                                        ) * 1.0599e-10)))) + 7.3353e-11)
# 23          3.946e-15  3.420e-02  y₂ = inv((x₂ + (((x₂ * x₀) * x₄) * (inv((x₂ * x₂) + -0.13...
#                                        342) * ((x₄ + -2.073) * 1.0599e-10)))) + 7.3353e-11)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.160e+05
# Progress: 8717 / 9300 total iterations (93.731%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Best equations for output 1
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.969e+01  1.594e+01  y₀ = -1.3211
# 2           3.991e-14  1.594e+01  y₀ = inv(x₀)
# 4           3.825e-14  2.134e-02  y₀ = inv(x₀) + 0
# 7           3.139e-14  6.588e-02  y₀ = inv(x₀ + (inv(x₁) * 3.1767e-10))
# 9           2.172e-14  1.840e-01  y₀ = inv((inv(x₂ + -0.043553) * -4.9349e-10) + x₀)
# 14          1.389e-14  8.944e-02  y₀ = (inv(x₀) * ((x₂ + (inv(x₃) + x₂)) * 9.9357e-09)) + i...
#                                        nv(x₀)
# 16          1.375e-14  5.141e-03  y₀ = ((inv(x₀) * 9.8449e-09) * (x₂ + ((x₂ + 0.11739) + in...
#                                        v(x₃)))) + inv(x₀)
# 17          1.125e-14  2.009e-01  y₀ = inv(x₀) + (((inv(x₃) + x₂) + inv(x₃ + -2.079)) * (in...
#                                        v(x₀) * 8.7966e-09))
# 19          5.516e-15  3.562e-01  y₀ = inv(x₀) + (((inv((x₂ + -1.8271) + x₃) + inv(x₃)) + x...
#                                        ₂) * (1.1139e-08 * inv(x₀)))
# 21          4.192e-15  1.372e-01  y₀ = inv(x₀) + (((inv(((x₂ + x₀) + -1.8271) + x₃) + (inv(...
#                                        x₃) + x₂)) * 1.1139e-08) * inv(x₀))
# 23          2.780e-15  2.054e-01  y₀ = ((((inv(x₃) + x₂) + inv((x₃ + x₂) + ((x₄ * -0.47364)...
#                                         + -1.7559))) * inv(x₀)) * 1.0469e-08) + inv(x₀)
# 25          2.454e-15  6.245e-02  y₀ = inv(x₀) + ((inv(x₀) * 8.2931e-09) * ((x₂ * 1.3723) +...
#                                         (inv(x₃) + inv((x₃ + (x₂ + -1.7559)) + (x₄ * -0.68337)))...
#                                        ))
# 26          2.356e-15  4.063e-02  y₀ = ((((((x₂ + 0.34883) * inv(x₁ + ((inv(x₃) + -1.4443) ...
#                                        * x₂))) + x₂) + inv(x₃)) * inv(x₀)) * 9.6488e-09) + inv(x...
#                                        ₀)
# 28          2.294e-15  1.337e-02  y₀ = ((9.6488e-09 * (x₂ + (inv(x₃) + (((x₃ * 0.16198) + x...
#                                        ₂) * inv(((inv(x₃) + -1.4443) * x₂) + x₁))))) * inv(x₀)) ...
#                                        + inv(x₀)
# 30          2.285e-15  1.940e-03  y₀ = ((inv(x₀) * (((((x₃ * 0.16198) + x₂) * inv((x₂ * (in...
#                                        v(x₃) + -1.4443)) + x₁)) + x₂) + (inv(x₃) + 0.068448))) *...
#                                         9.6488e-09) + inv(x₀)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Best equations for output 2
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           6.356e+02  1.594e+01  y₁ = -0.22132
# 2           2.336e-12  1.594e+01  y₁ = inv(x₁)
# 6           2.336e-12  1.878e-06  y₁ = (x₂ * -5.5897e-09) + inv(x₁)
# 7           1.344e-14  5.158e+00  y₁ = (inv(x₁) * -4.0121e-08) + inv(x₁)
# 9           7.609e-15  2.844e-01  y₁ = (inv(x₁ * x₁) * 2.3308e-10) + inv(x₁)
# 13          5.904e-15  6.343e-02  y₁ = (inv(x₁ * (x₃ + (x₁ * -17.831))) * -1.5925e-08) + in...
#                                        v(x₁)
# 15          5.345e-15  4.978e-02  y₁ = inv(x₁) + ((inv((inv(x₄) * x₁) + x₃) * -6.2912e-09) ...
#                                        * inv(x₁))
# 16          5.336e-15  1.663e-03  y₁ = ((inv(x₃ + (x₁ * -17.831)) * (x₂ + inv(x₁))) * -1.59...
#                                        25e-08) + inv(x₁)
# 19          3.941e-15  1.010e-01  y₁ = inv(x₁) + (inv((x₁ * -17.831) + x₃) * ((inv(x₁) + in...
#                                        v(x₂ + -1.6058)) * -1.5925e-08))
# 21          3.346e-15  8.184e-02  y₁ = inv(x₁) + (inv((x₁ * -17.831) + x₃) * (-1.5925e-08 *...
#                                         ((inv(x₁) + x₂) + inv(-1.6058 + x₂))))
# 24          3.204e-15  1.447e-02  y₁ = inv(x₁) + ((((inv(x₁) + inv(x₂ + -1.6058)) + inv(x₀ ...
#                                        + x₁)) * -1.3459e-08) * inv((-17.831 * x₁) + x₃))
# 25          3.062e-15  4.537e-02  y₁ = inv(x₁) + (inv((x₁ * -17.831) + x₃) * ((inv(x₁) + (x...
#                                        ₂ + inv((x₁ + (1.3076 * x₀)) * -2.1602))) * -1.5925e-08))
# 27          2.778e-15  4.871e-02  y₁ = ((((inv(x₁) + (inv(-1.6058 + x₂) + inv(inv(x₀) + x₁)...
#                                        )) + 0.3004) * -1.5925e-08) * inv(x₃ + (-17.831 * x₁))) +...
#                                         inv(x₁)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Best equations for output 3
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.910e+04  1.594e+01  y₂ = 13.14
# 2           1.490e-10  1.594e+01  y₂ = inv(x₂)
# 4           6.788e-15  4.997e+00  y₂ = inv(x₂ + 5.3213e-11)
# 6           6.202e-15  4.516e-02  y₂ = inv(x₂ + 7.3353e-11) * 1
# 12          4.514e-15  5.293e-02  y₂ = inv(x₂ + (((x₄ + x₀) * -4.0973e-11) * (x₀ * x₀)))
# 16          4.408e-15  5.973e-03  y₂ = inv((x₂ + 7.3353e-11) + (((x₁ * 56.173) * x₂) * (1.0...
#                                        599e-10 * (x₀ + -1.3806))))
# 20          4.372e-15  2.023e-03  y₂ = inv((x₂ + ((x₂ * x₄) * ((x₀ * (x₄ + x₀)) * ((x₀ + x₄...
#                                        ) * 1.0599e-10)))) + 7.3353e-11)
# 23          3.946e-15  3.420e-02  y₂ = inv((x₂ + (((x₂ * x₀) * x₄) * (inv((x₂ * x₂) + -0.13...
#                                        342) * ((x₄ + -2.073) * 1.0599e-10)))) + 7.3353e-11)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.969e+01  1.594e+01  y₀ = -1.3211
# 2           3.991e-14  1.594e+01  y₀ = inv(x₀)
# 4           3.825e-14  2.134e-02  y₀ = inv(x₀) + 0
# 6           3.759e-14  8.667e-03  y₀ = -0.20598 + (inv(x₀) + 0.20598)
# 7           3.139e-14  1.803e-01  y₀ = inv(x₀ + (inv(x₁) * 3.1767e-10))
# 9           2.172e-14  1.840e-01  y₀ = inv((inv(x₂ + -0.043553) * -4.9349e-10) + x₀)
# 14          1.389e-14  8.944e-02  y₀ = (inv(x₀) * ((x₂ + (inv(x₃) + x₂)) * 9.9357e-09)) + i...
#                                        nv(x₀)
# 16          1.375e-14  5.141e-03  y₀ = ((inv(x₀) * 9.8449e-09) * (x₂ + ((x₂ + 0.11739) + in...
#                                        v(x₃)))) + inv(x₀)
# 17          1.125e-14  2.009e-01  y₀ = inv(x₀) + (((inv(x₃) + x₂) + inv(x₃ + -2.079)) * (in...
#                                        v(x₀) * 8.7966e-09))
# 19          5.516e-15  3.562e-01  y₀ = inv(x₀) + (((inv((x₂ + -1.8271) + x₃) + inv(x₃)) + x...
#                                        ₂) * (1.1139e-08 * inv(x₀)))
# 21          4.192e-15  1.372e-01  y₀ = inv(x₀) + (((inv(((x₂ + x₀) + -1.8271) + x₃) + (inv(...
#                                        x₃) + x₂)) * 1.1139e-08) * inv(x₀))
# 23          2.780e-15  2.054e-01  y₀ = ((((inv(x₃) + x₂) + inv((x₃ + x₂) + ((x₄ * -0.47364)...
#                                         + -1.7559))) * inv(x₀)) * 1.0469e-08) + inv(x₀)
# 25          2.427e-15  6.791e-02  y₀ = inv(x₀) + (((((x₂ * 1.3723) + inv(x₃)) + inv((x₃ + x...
#                                        ₂) + ((x₄ * -0.53095) + -1.7559))) * inv(x₀)) * 8.2931e-0...
#                                        9)
# 26          2.356e-15  2.971e-02  y₀ = ((((((x₂ + 0.34883) * inv(x₁ + ((inv(x₃) + -1.4443) ...
#                                        * x₂))) + x₂) + inv(x₃)) * inv(x₀)) * 9.6488e-09) + inv(x...
#                                        ₀)
# 28          2.294e-15  1.337e-02  y₀ = ((9.6488e-09 * (x₂ + (inv(x₃) + (((x₃ * 0.16198) + x...
#                                        ₂) * inv(((inv(x₃) + -1.4443) * x₂) + x₁))))) * inv(x₀)) ...
#                                        + inv(x₀)
# 30          2.285e-15  1.940e-03  y₀ = ((inv(x₀) * (((((x₃ * 0.16198) + x₂) * inv((x₂ * (in...
#                                        v(x₃) + -1.4443)) + x₁)) + x₂) + (inv(x₃) + 0.068448))) *...
#                                         9.6488e-09) + inv(x₀)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           6.279e+02  1.594e+01  y₁ = x₀
# 2           2.336e-12  1.594e+01  y₁ = inv(x₁)
# 6           2.336e-12  1.878e-06  y₁ = (x₂ * -5.5897e-09) + inv(x₁)
# 7           1.344e-14  5.158e+00  y₁ = (inv(x₁) * -4.0121e-08) + inv(x₁)
# 9           7.609e-15  2.844e-01  y₁ = (inv(x₁ * x₁) * 2.3308e-10) + inv(x₁)
# 13          5.904e-15  6.343e-02  y₁ = (inv(x₁ * (x₃ + (x₁ * -17.831))) * -1.5925e-08) + in...
#                                        v(x₁)
# 15          5.345e-15  4.978e-02  y₁ = inv(x₁) + ((inv((inv(x₄) * x₁) + x₃) * -6.2912e-09) ...
#                                        * inv(x₁))
# 16          5.336e-15  1.663e-03  y₁ = ((inv(x₃ + (x₁ * -17.831)) * (x₂ + inv(x₁))) * -1.59...
#                                        25e-08) + inv(x₁)
# 19          3.941e-15  1.010e-01  y₁ = inv(x₁) + (inv((x₁ * -17.831) + x₃) * ((inv(x₁) + in...
#                                        v(x₂ + -1.6058)) * -1.5925e-08))
# 21          3.204e-15  1.035e-01  y₁ = inv(x₁) + (((x₂ + (inv(x₃ + 1.1891) + inv(x₁))) * in...
#                                        v(x₃ + (x₁ * -17.831))) * -1.3459e-08)
# 25          3.062e-15  1.134e-02  y₁ = inv(x₁) + (inv((x₁ * -17.831) + x₃) * ((inv(x₁) + (x...
#                                        ₂ + inv((x₁ + (1.3076 * x₀)) * -2.1602))) * -1.5925e-08))
# 27          2.778e-15  4.871e-02  y₁ = ((((inv(x₁) + (inv(-1.6058 + x₂) + inv(inv(x₀) + x₁)...
#                                        )) + 0.3004) * -1.5925e-08) * inv(x₃ + (-17.831 * x₁))) +...
#                                         inv(x₁)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.910e+04  1.594e+01  y₂ = 13.14
# 2           1.490e-10  1.594e+01  y₂ = inv(x₂)
# 4           6.788e-15  4.997e+00  y₂ = inv(x₂ + 5.3213e-11)
# 6           6.202e-15  4.516e-02  y₂ = inv(x₂ + 7.3353e-11) * 1
# 12          4.514e-15  5.293e-02  y₂ = inv(x₂ + (((x₄ + x₀) * -4.0973e-11) * (x₀ * x₀)))
# 16          4.390e-15  6.983e-03  y₂ = inv(x₂ + (7.3353e-11 + (((x₁ * 56.173) * (x₂ * 1.059...
#                                        9e-10)) * (x₀ + x₃))))
# 18          4.374e-15  1.773e-03  y₂ = inv((((x₂ * ((x₂ + (x₀ + -1.378)) * 33.309)) * x₁) *...
#                                         1.2537e-10) + (x₂ + 3.8153e-11))
# 20          4.259e-15  1.338e-02  y₂ = inv(x₂ + (7.3353e-11 + ((x₁ * (56.173 * (x₂ * 1.0599...
#                                        e-10))) * ((x₀ + (x₂ * 1.1175)) + x₃))))
# 23          3.946e-15  2.545e-02  y₂ = inv((x₂ + (((x₂ * x₀) * x₄) * (inv((x₂ * x₂) + -0.13...
#                                        342) * ((x₄ + -2.073) * 1.0599e-10)))) + 7.3353e-11)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
#   - outputs/20250114_101834_X9fhD3/hall_of_fame_output1.csv
#   - outputs/20250114_101834_X9fhD3/hall_of_fame_output2.csv
# [ Info: Final populations:
# [ Info: Output 1:
# [ Info: Output 2:
# [ Info: Output 3:
# [ Info: Results saved to:
# PySRRegressor.equations_ = [
# [
# 	    pick      score                                           equation  \
# 	0          0.000000                                         -1.3210777
# 	1         34.757929                                            inv(x0)
# 	2          0.021338                                      inv(x0) + 0.0
# 	3          0.008667               -0.20597835 + (inv(x0) + 0.20597835)
# 	4          0.180303                inv(x0 + (inv(x1) * 3.1766723e-10))
# 	5          0.183988  inv((inv(x2 + -0.04355286) * -4.934909e-10) + x0)
# 	6          0.089441  (inv(x0) * ((x2 + (inv(x3) + x2)) * 9.935737e-...
# 	7          0.005141  ((inv(x0) * 9.844916e-9) * (x2 + ((x2 + 0.1173...
# 	8          0.200904  inv(x0) + (((inv(x3) + x2) + inv(x3 + -2.07897...
# 	9          0.356242  inv(x0) + (((inv((x2 + -1.827135) + x3) + inv(...
# 	10         0.137176  inv(x0) + (((inv(((x2 + x0) + -1.827135) + x3)...
# 	11  >>>>   0.205388  ((((inv(x3) + x2) + inv((x3 + x2) + ((x4 * -0....
# 	12         0.067908  inv(x0) + (((((x2 * 1.3722835) + inv(x3)) + in...
# 	13         0.029714  ((((((x2 + 0.34882584) * inv(x1 + ((inv(x3) + ...
# 	14         0.013372  ((9.648832e-9 * (x2 + (inv(x3) + (((x3 * 0.161...
# 	15         0.001940  ((inv(x0) * (((((x3 * 0.1619846) + x2) * inv((...
#
# 	            loss  complexity
# 	0   4.969471e+01           1
# 	1   3.991474e-14           2
# 	2   3.824718e-14           4
# 	3   3.758993e-14           6
# 	4   3.138822e-14           7
# 	5   2.172484e-14           9
# 	6   1.389111e-14          14
# 	7   1.374900e-14          16
# 	8   1.124656e-14          17
# 	9   5.515588e-15          19
# 	10  4.192202e-15          21
# 	11  2.779999e-15          23
# 	12  2.426948e-15          25
# 	13  2.355893e-15          26
# 	14  2.293721e-15          28
# 	15  2.284839e-15          30
# ], [
# 	    pick      score                                           equation  \
# 	0          0.000000                                                 x0
# 	1         33.224942                                            inv(x1)
# 	2          0.000002                      (x2 * -5.589664e-9) + inv(x1)
# 	3          5.158055                (inv(x1) * -4.0120543e-8) + inv(x1)
# 	4          0.284352           (inv(x1 * x1) * 2.3308486e-10) + inv(x1)
# 	5          0.063434  (inv(x1 * (x3 + (x1 * -17.83139))) * -1.592474...
# 	6          0.049784  inv(x1) + ((inv((inv(x4) * x1) + x3) * -6.2912...
# 	7          0.001663  ((inv(x3 + (x1 * -17.83139)) * (x2 + inv(x1)))...
# 	8          0.100973  inv(x1) + (inv((x1 * -17.83139) + x3) * ((inv(...
# 	9   >>>>   0.103538  inv(x1) + (((x2 + (inv(x3 + 1.1890541) + inv(x...
# 	10         0.011341  inv(x1) + (inv((x1 * -17.83139) + x3) * ((inv(...
# 	11         0.048708  ((((inv(x1) + (inv(-1.6058086 + x2) + inv(inv(...
#
# 	            loss  complexity
# 	0   6.278647e+02           1
# 	1   2.335916e-12           2
# 	2   2.335898e-12           6
# 	3   1.343814e-14           7
# 	4   7.609469e-15           9
# 	5   5.904166e-15          13
# 	6   5.344614e-15          15
# 	7   5.335732e-15          16
# 	8   3.941292e-15          19
# 	9   3.204104e-15          21
# 	10  3.061995e-15          25
# 	11  2.777778e-15          27
# ], [
# 	   pick      score                                           equation  \
# 	0         0.000000                                          13.139839
# 	1        32.484459                                            inv(x2)
# 	2         4.998341                             inv(x2 + 5.321256e-11)
# 	3         0.045159                      inv(x2 + 7.3353476e-11) * 1.0
# 	4  >>>>   0.052934  inv(x2 + (((x4 + x0) * -4.097259e-11) * (x0 * ...
# 	5         0.006983  inv(x2 + (7.3353476e-11 + (((x1 * 56.17303) * ...
# 	6         0.001773  inv((((x2 * ((x2 + (x0 + -1.377994)) * 33.3090...
# 	7         0.013375  inv(x2 + (7.3353476e-11 + ((x1 * (56.17303 * (...
# 	8         0.025452  inv((x2 + (((x2 * x0) * x4) * (inv((x2 * x2) +...
#
# 	           loss  complexity
# 	0  1.910123e+04           1
# 	1  1.490184e-10           2
# 	2  6.787903e-15           4
# 	3  6.201706e-15           6
# 	4  4.514167e-15          12
# 	5  4.389822e-15          16
# 	6  4.374279e-15          18
# 	7  4.258816e-15          20
# 	8  3.945733e-15          23
# ]]
#   - outputs/20250114_101834_X9fhD3/hall_of_fame_output3.csv

# %%
model
# Out:
# PySRRegressor.equations_ = [
# [
# 	    pick      score                                           equation  \
# 	0          0.000000                                         -1.3210777
# 	1         34.757929                                            inv(x0)
# 	2          0.021338                                      inv(x0) + 0.0
# 	3          0.008667               -0.20597835 + (inv(x0) + 0.20597835)
# 	4          0.180303                inv(x0 + (inv(x1) * 3.1766723e-10))
# 	5          0.183988  inv((inv(x2 + -0.04355286) * -4.934909e-10) + x0)
# 	6          0.089441  (inv(x0) * ((x2 + (inv(x3) + x2)) * 9.935737e-...
# 	7          0.005141  ((inv(x0) * 9.844916e-9) * (x2 + ((x2 + 0.1173...
# 	8          0.200904  inv(x0) + (((inv(x3) + x2) + inv(x3 + -2.07897...
# 	9          0.356242  inv(x0) + (((inv((x2 + -1.827135) + x3) + inv(...
# 	10         0.137176  inv(x0) + (((inv(((x2 + x0) + -1.827135) + x3)...
# 	11  >>>>   0.205388  ((((inv(x3) + x2) + inv((x3 + x2) + ((x4 * -0....
# 	12         0.067908  inv(x0) + (((((x2 * 1.3722835) + inv(x3)) + in...
# 	13         0.029714  ((((((x2 + 0.34882584) * inv(x1 + ((inv(x3) + ...
# 	14         0.013372  ((9.648832e-9 * (x2 + (inv(x3) + (((x3 * 0.161...
# 	15         0.001940  ((inv(x0) * (((((x3 * 0.1619846) + x2) * inv((...
#
# 	            loss  complexity
# 	0   4.969471e+01           1
# 	1   3.991474e-14           2
# 	2   3.824718e-14           4
# 	3   3.758993e-14           6
# 	4   3.138822e-14           7
# 	5   2.172484e-14           9
# 	6   1.389111e-14          14
# 	7   1.374900e-14          16
# 	8   1.124656e-14          17
# 	9   5.515588e-15          19
# 	10  4.192202e-15          21
# 	11  2.779999e-15          23
# 	12  2.426948e-15          25
# 	13  2.355893e-15          26
# 	14  2.293721e-15          28
# 	15  2.284839e-15          30
# ], [
# 	    pick      score                                           equation  \
# 	0          0.000000                                                 x0
# 	1         33.224942                                            inv(x1)
# 	2          0.000002                      (x2 * -5.589664e-9) + inv(x1)
# 	3          5.158055                (inv(x1) * -4.0120543e-8) + inv(x1)
# 	4          0.284352           (inv(x1 * x1) * 2.3308486e-10) + inv(x1)
# 	5          0.063434  (inv(x1 * (x3 + (x1 * -17.83139))) * -1.592474...
# 	6          0.049784  inv(x1) + ((inv((inv(x4) * x1) + x3) * -6.2912...
# 	7          0.001663  ((inv(x3 + (x1 * -17.83139)) * (x2 + inv(x1)))...
# 	8          0.100973  inv(x1) + (inv((x1 * -17.83139) + x3) * ((inv(...
# 	9   >>>>   0.103538  inv(x1) + (((x2 + (inv(x3 + 1.1890541) + inv(x...
# 	10         0.011341  inv(x1) + (inv((x1 * -17.83139) + x3) * ((inv(...
# 	11         0.048708  ((((inv(x1) + (inv(-1.6058086 + x2) + inv(inv(...
#
# 	            loss  complexity
# 	0   6.278647e+02           1
# 	1   2.335916e-12           2
# 	2   2.335898e-12           6
# 	3   1.343814e-14           7
# 	4   7.609469e-15           9
# 	5   5.904166e-15          13
# 	6   5.344614e-15          15
# 	7   5.335732e-15          16
# 	8   3.941292e-15          19
# 	9   3.204104e-15          21
# 	10  3.061995e-15          25
# 	11  2.777778e-15          27
# ], [
# 	   pick      score                                           equation  \
# 	0         0.000000                                          13.139839
# 	1        32.484459                                            inv(x2)
# 	2         4.998341                             inv(x2 + 5.321256e-11)
# 	3         0.045159                      inv(x2 + 7.3353476e-11) * 1.0
# 	4  >>>>   0.052934  inv(x2 + (((x4 + x0) * -4.097259e-11) * (x0 * ...
# 	5         0.006983  inv(x2 + (7.3353476e-11 + (((x1 * 56.17303) * ...
# 	6         0.001773  inv((((x2 * ((x2 + (x0 + -1.377994)) * 33.3090...
# 	7         0.013375  inv(x2 + (7.3353476e-11 + ((x1 * (56.17303 * (...
# 	8         0.025452  inv((x2 + (((x2 * x0) * x4) * (inv((x2 * x2) +...
#
# 	           loss  complexity
# 	0  1.910123e+04           1
# 	1  1.490184e-10           2
# 	2  6.787903e-15           4
# 	3  6.201706e-15           6
# 	4  4.514167e-15          12
# 	5  4.389822e-15          16
# 	6  4.374279e-15          18
# 	7  4.258816e-15          20
# 	8  3.945733e-15          23
# ]]

# %% [markdown]
# # Julia packages and types

# %% [markdown]
# PySR uses [SymbolicRegression.jl](https://github.com/MilesCranmer/SymbolicRegression.jl)
# as its search backend. This is a pure Julia package, and so can interface easily with any other
# Julia package.
# For some tasks, it may be necessary to load such a package.
#
# For example, let's say we wish to discovery the following relationship:
#
# $$ y = p_{3x + 1} - 5, $$
#
# where $p_i$ is the $i$th prime number, and $x$ is the input feature.
#
# Let's see if we can discover this using
# the [Primes.jl](https://github.com/JuliaMath/Primes.jl) package.

# %% [markdown]
# `jl` stores the Julia runtime.
#
# Now, let's run some Julia code to add the Primes.jl
# package to the PySR environment:

# %%
from pysr import jl

jl.seval(
    """
import Pkg
Pkg.add("Primes")
"""
)
# Out:
#    Resolving package versions...
#    Installed IntegerMathUtils ─ v0.1.2
#    Installed Primes ─────────── v0.5.6
#     Updating `~/.julia/environments/pyjuliapkg/Project.toml`
#   [27ebfcd6] + Primes v0.5.6
#     Updating `~/.julia/environments/pyjuliapkg/Manifest.toml`
#   [18e54dd8] + IntegerMathUtils v0.1.2
#   [27ebfcd6] + Primes v0.5.6
# Precompiling project...
#     809.2 ms  ✓ IntegerMathUtils
#     945.4 ms  ✓ Primes
#   2 dependencies successfully precompiled in 3 seconds. 129 already precompiled.

# %% [markdown]
# This imports the Julia package manager, and uses it to install
# `Primes.jl`. Now let's import `Primes.jl`:

# %%
jl.seval("using Primes: prime")

# %% [markdown]
# Note that PySR should automatically load the `juliacall.ipython` extension for you,
# which means that you can also execute Julia code in the notebook using the `%%julia` magic:

# %%
# %julia using Primes: prime

# %% [markdown]
# Now, we define a custom operator:

# %%
jl.seval(
    """
function p(i::T) where T
    if 0.5 < i < 1000
        return T(prime(round(Int, i)))
    else
        return T(NaN)
    end
end
"""
)
# Out:
# p (generic function with 1 method)

# %% [markdown]
# Or, equivalently:

# %%
# %%julia
# function p(i::T) where T
#     if 0.5 < i < 1000
#         return T(prime(round(Int, i)))
#     else
#         return T(NaN)
#     end
# end
# Out:
# p (generic function with 1 method)

# %% [markdown]
# We have created a function `p`, which takes a number `i` of type `T` (e.g., `T=Float64`).
# `p` first checks whether the input is between 0.5 and 1000.
# If out-of-bounds, it returns `NaN`.
# If in-bounds, it rounds it to the nearest integer, computes the corresponding prime number, and then
# converts it to the same type as input.
#
# The equivalent function in Python would be:
#
# ```python
# import sympy
#
# def p(i):
#     if 0.5 < i < 1000:
#         return float(sympy.prime(int(round(i))))
#     else:
#         return float("nan")
# ```
#
# (However, note that this version assumes 64-bit float input, rather than any input type `T`)
#
# Next, let's generate a list of primes for our test dataset.
# Since we are using juliacall, we can just call `p` directly to do this:

# %%
primes = {i: jl.p(i * 1.0) for i in range(1, 999)}

# %% [markdown]
# Next, let's use this list of primes to create a dataset of $x, y$ pairs:

# %%
import numpy as np

X = np.random.randint(0, 100, 100)[:, None]
y = [primes[3 * X[i, 0] + 1] - 5 + np.random.randn() * 0.001 for i in range(100)]

# %% [markdown]
# Note that we have also added a tiny bit of noise to the dataset.
#
# Finally, let's create a PySR model, and pass the custom operator. We also need to define the sympy equivalent, which we can leave as a placeholder for now:

# %%
from pysr import PySRRegressor
import sympy


class sympy_p(sympy.Function):
    pass


model = PySRRegressor(
    binary_operators=["+", "-", "*", "/"],
    unary_operators=["p"],
    niterations=20,
    extra_sympy_mappings={"p": sympy_p},
)

# %% [markdown]
# We are all set to go! Let's see if we can find the true relation:

# %%
model.fit(X, y)
# Out:
# /opt/homebrew/anaconda3/envs/notebook/lib/python3.12/site-packages/pysr/sr.py:2766: UserWarning: Note: it looks like you are running in Jupyter. The progress bar will be turned off.
#   warnings.warn(
# [ Info: Started!
# Expressions evaluated per second: 2.580e+04
# Progress: 130 / 620 total iterations (20.968%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           2.827e+05  1.594e+01  y = 890.47
# 3           3.145e+03  2.249e+00  y = x₀ * 18.386
# 5           7.682e+02  7.048e-01  y = (x₀ * 20.007) + -103.47
# 7           2.646e+02  5.329e-01  y = ((x₀ * 0.055842) + 14.438) * x₀
# 8           2.500e+01  2.359e+00  y = p(x₀ + (x₀ + (x₀ + 0.63872)))
# 10          1.104e-06  7.814e+00  y = p(((x₀ + x₀) + x₀) + 0.73631) + -5
# 12          1.085e-06  8.466e-03  y = (p(x₀ + ((x₀ + x₀) - -0.71544)) + -4.9998) * 1
# 14          1.084e-06  6.728e-04  y = ((p(x₀ + ((x₀ + x₀) - -0.71544)) + -4.4921) - 0.50768)...
#                                        * 1
# 16          1.084e-06  1.830e-05  y = (((p(x₀ + ((x₀ + x₀) - -0.71544)) + -0.015518) - 0.507...
#                                       68) + -4.4766) * 1
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.470e+04
# Progress: 252 / 620 total iterations (40.645%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           2.827e+05  1.594e+01  y = 890.47
# 3           3.145e+03  2.249e+00  y = x₀ * 18.386
# 5           7.682e+02  7.048e-01  y = (x₀ + -5.1717) * 20.007
# 6           1.890e+02  1.403e+00  y = p(x₀ + 1.7637) * 3.6102
# 8           2.252e+01  1.064e+00  y = p(((x₀ - 3.6244) / 0.33401) + 11.79)
# 10          1.104e-06  7.799e+00  y = p(((x₀ + x₀) + x₀) + 0.73631) + -5
# 12          1.085e-06  8.675e-03  y = (p(((x₀ + x₀) + x₀) - -0.76543) + -4.9998) * 1
# 14          1.084e-06  4.630e-04  y = ((p(x₀ + ((x₀ + x₀) - -0.71544)) + -4.4921) - 0.50768)...
#                                        * 1
# 16          1.084e-06  1.396e-04  y = (((p(x₀ + ((x₀ + x₀) - -0.71154)) + 0.97704) - -0.8841...
#                                       3) + -6.8609) * 1
# 22          1.083e-06  7.121e-05  y = ((p(((x₀ - -0.26114) + x₀) + (x₀ + 1.1236)) + -2.9672)...
#                                        - ((x₀ * x₀) * (x₀ * 5.3924e-10))) - 2.0327
# 30          1.082e-06  1.352e-04  y = ((p((x₀ + ((x₀ - -0.25857) + x₀)) + 0.51671) + -3.8507...
#                                       ) + ((1.2821 - ((x₀ + -0.21322) * (((x₀ * 0.32026) + -1.53...
#                                       21) * 1.8072))) * 1.1698e-07)) - 1.1491
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.170e+04
# Progress: 333 / 620 total iterations (53.710%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           2.827e+05  1.594e+01  y = 890.47
# 3           3.145e+03  2.249e+00  y = x₀ * 18.386
# 5           7.682e+02  7.048e-01  y = (x₀ + -5.1717) * 20.007
# 6           1.890e+02  1.403e+00  y = p(x₀ + 1.7637) * 3.6102
# 8           2.252e+01  1.064e+00  y = p(((x₀ - 3.6244) / 0.33401) + 11.79)
# 10          1.104e-06  7.799e+00  y = p(((x₀ + x₀) + x₀) + 0.73631) + -5
# 12          1.085e-06  8.769e-03  y = (p(((x₀ + x₀) + x₀) - -0.9551) + -4.9998) * 1
# 14          1.083e-06  5.852e-04  y = ((p(x₀ + ((x₀ + x₀) - -1.284)) + -5.8839) - -0.88413) ...
#                                       * 1
# 16          1.080e-06  1.497e-03  y = (((p((x₀ + x₀) + (x₀ + 0.67783)) + -2.4805) * 1) - -0....
#                                       21669) + -2.736
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.040e+04
# Progress: 422 / 620 total iterations (68.065%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           2.827e+05  1.594e+01  y = 890.47
# 3           3.145e+03  2.249e+00  y = x₀ * 18.386
# 5           7.682e+02  7.048e-01  y = (x₀ + -5.1717) * 20.007
# 6           2.156e+01  3.573e+00  y = p((x₀ + 0.39888) * 2.9902)
# 10          1.104e-06  3.896e+00  y = p(((x₀ + x₀) + x₀) + 0.73631) + -5
# 12          1.085e-06  8.769e-03  y = (p(((x₀ + x₀) + x₀) - -0.9551) + -4.9998) * 1
# 14          1.083e-06  5.852e-04  y = ((p(x₀ + ((x₀ + x₀) - -1.284)) + -5.8839) - -0.88413) ...
#                                       * 1
# 16          1.080e-06  1.497e-03  y = (((p((x₀ + x₀) + (x₀ + 0.67783)) + -2.4805) * 1) - -0....
#                                       21669) + -2.736
# 24          1.080e-06  6.221e-06  y = (p(((x₀ + x₀) + ((x₀ + (x₀ - x₀)) + 0.55286)) - -0.701...
#                                       22) + -2.0908) + ((x₀ - 2.909) - (x₀ * 1))
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.930e+04
# Progress: 526 / 620 total iterations (84.839%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           2.827e+05  1.594e+01  y = 890.47
# 3           3.145e+03  2.249e+00  y = x₀ * 18.386
# 5           7.682e+02  7.048e-01  y = (x₀ + -5.1717) * 20.007
# 6           2.076e+01  3.611e+00  y = p((x₀ + 0.38593) * 2.9902)
# 8           2.046e+00  1.159e+00  y = p((x₀ * 3.0044) + 0.50251) + -3.5695
# 10          1.104e-06  7.116e+00  y = p(((x₀ + x₀) + x₀) + 0.73631) + -5
# 12          1.085e-06  8.769e-03  y = (p(((x₀ + x₀) + x₀) - -0.9551) + -4.9998) * 1
# 14          1.083e-06  5.852e-04  y = ((p(x₀ + ((x₀ + x₀) - -1.284)) + -5.8839) - -0.88413) ...
#                                       * 1
# 16          1.080e-06  1.497e-03  y = (((p((x₀ + x₀) + (x₀ + 0.67783)) + -2.4805) * 1) - -0....
#                                       21669) + -2.736
# 18          1.080e-06  2.489e-05  y = (p(x₀ + ((x₀ + x₀) + 0.55286)) + -2.0908) + ((x₀ - 2.9...
#                                       09) - (x₀ * 1))
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           2.827e+05  1.594e+01  y = 890.47
# 3           3.145e+03  2.249e+00  y = x₀ * 18.386
# 5           7.682e+02  7.048e-01  y = (x₀ + -5.1717) * 20.007
# 6           2.076e+01  3.611e+00  y = p((x₀ + 0.38593) * 2.9902)
# 8           1.775e-04  5.828e+00  y = p((x₀ * 3.0014) + 1.0347) + -4.9867
# 10          1.104e-06  2.540e+00  y = p(((x₀ + x₀) + x₀) + 0.73631) + -5
# 12          1.085e-06  8.769e-03  y = (p(((x₀ + x₀) + x₀) - -0.9551) + -4.9998) * 1
# 14          1.082e-06  1.389e-03  y = ((p(x₀ + ((x₀ + x₀) + 1.4668)) + -2.2638) * 1) + -2.73...
#                                       6
# 16          1.080e-06  6.935e-04  y = (((p((x₀ + x₀) + (x₀ + 0.67783)) + -2.4805) * 1) - -0....
#                                       21669) + -2.736
# 18          1.080e-06  2.489e-05  y = (p(x₀ + ((x₀ + x₀) + 0.55286)) + -2.0908) + ((x₀ - 2.9...
#                                       09) - (x₀ * 1))
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# [ Info: Final population:
# [ Info: Results saved to:
# PySRRegressor.equations_ = [
# 	   pick     score                                           equation  \
# 	0        0.000000                                           890.4695
# 	1        2.249288                                     x0 * 18.386473
# 	2        0.704811                       (x0 + -5.1716948) * 20.00683
# 	3        3.611090                   p((x0 + 0.38592833) * 2.9902048)
# 	4        5.834621        p((x0 * 3.001438) + 1.0346894) + -4.9866996
# 	5  >>>>  2.540206      p(((x0 + x0) + x0) + 0.73630655) + -4.9999614
# 	6        0.008769  (p(((x0 + x0) + x0) - -0.95510125) + -4.999765...
# 	7        0.001389  ((p(x0 + ((x0 + x0) + 1.4668288)) + -2.2638087...
# 	8        0.000694  (((p((x0 + x0) + (x0 + 0.6778278)) + -2.480498...
# 	9        0.000025  (p(x0 + ((x0 + x0) + 0.5528596)) + -2.090782) ...
#
# 	            loss  complexity
# 	0  282735.880000           1
# 	1    3145.388400           3
# 	2     768.216430           5
# 	3      20.759024           6
# 	4       0.000178           8
# 	5       0.000001          10
# 	6       0.000001          12
# 	7       0.000001          14
# 	8       0.000001          16
# 	9       0.000001          18
# ]
#   - outputs/20250114_101940_016dvF/hall_of_fame.csv

# %% [markdown]
# if all works out, you should be able to see the true relation (note that the constant offset might not be exactly 1, since it is allowed to round to the nearest integer).
#
# You can get the sympy version of the best equation with:

# %%
model.sympy()
# Out:
# sympy_p(x0 + x0 + x0 + 0.73630655) - 4.9999614

# %% [markdown]
# # High-dimensional input: Neural Nets + Symbolic Regression

# %% [markdown]
# In this example, let's learn a high-dimensional problem. **This will use the method proposed in our NeurIPS paper: https://arxiv.org/abs/2006.11287.**
#
# Let's consider a time series problem:
#
# $$ z = y^2,\quad y = \frac{1}{10} \sum(y_i),\quad y_i = x_{i0}^2 + 6 \cos(2*x_{i2})$$
#
# Imagine our time series is 10 timesteps. That is very hard for symbolic regression, even if we impose the inductive bias of $$z=f(\sum g(x_i))$$ - it is the square of the number of possible equations!
#
# But, as in our paper, **we can break this problem down into parts with a neural network. Then approximate the neural network with the symbolic regression!**
#
# Then, instead of, say, $(10^9)^2=10^{18}$ equations, we only have to consider $2\times 10^9$ equations.

# %%
import numpy as np

rstate = np.random.RandomState(0)

N = 100000
Nt = 10
X = 6 * rstate.rand(N, Nt, 5) - 3
y_i = X[..., 0] ** 2 + 6 * np.cos(2 * X[..., 2])
y = np.sum(y_i, axis=1) / y_i.shape[1]
z = y**2
X.shape, y.shape
# Out:
# ((100000, 10, 5), (100000,))

# %% [markdown]
# ## Neural Network definition

# %% [markdown]
# So, as described above, let's first use a neural network with the sum inductive bias to solve this problem.
#
# Essentially, we will learn two neural networks:
# - `f`
# - `g`
#
# each defined as a multi-layer perceptron. We will sum over `g` the same way as in our equation, but we won't define the summed part beforehand.
#
# Then, we will fit `g` and `f` **separately** using symbolic regression.

# %% [markdown]
# > **Warning**
# >
# > We import torch *after* already starting PyJulia. This is required due to interference between their C bindings. If you use torch, and then run PyJulia, you will likely hit a segfault. So keep this in mind for mixed deep learning + PyJulia/PySR workflows.

# %%
# !pip install pytorch_lightning
# Out:
# zsh:1: command not found: pip

# %%
import torch
from torch import nn, optim
from torch.nn import functional as F
from torch.utils.data import DataLoader, TensorDataset
import pytorch_lightning as pl

hidden = 128
total_steps = 50_000


def mlp(size_in, size_out, act=nn.ReLU):
    return nn.Sequential(
        nn.Linear(size_in, hidden),
        act(),
        nn.Linear(hidden, hidden),
        act(),
        nn.Linear(hidden, hidden),
        act(),
        nn.Linear(hidden, size_out),
    )


class SumNet(pl.LightningModule):
    def __init__(self):
        super().__init__()

        ########################################################
        # The same inductive bias as above!
        self.g = mlp(5, 1)
        self.f = mlp(1, 1)

    def forward(self, x):
        y_i = self.g(x)[:, :, 0]
        y = torch.sum(y_i, dim=1, keepdim=True) / y_i.shape[1]
        z = self.f(y)
        return z[:, 0]

    ########################################################

    # PyTorch Lightning bookkeeping:
    def training_step(self, batch, batch_idx):
        x, z = batch
        predicted_z = self(x)
        loss = F.mse_loss(predicted_z, z)
        return loss

    def validation_step(self, batch, batch_idx):
        return self.training_step(batch, batch_idx)

    def configure_optimizers(self):
        optimizer = torch.optim.Adam(self.parameters(), lr=self.max_lr)
        scheduler = {
            "scheduler": torch.optim.lr_scheduler.OneCycleLR(
                optimizer,
                max_lr=self.max_lr,
                total_steps=self.trainer.estimated_stepping_batches,
                final_div_factor=1e4,
            ),
            "interval": "step",
        }
        return [optimizer], [scheduler]
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 import torch
#       2 from torch import nn, optim
#       3 from torch.nn import functional as F
#
# ModuleNotFoundError: No module named 'torch'

# %% [markdown]
# ## Data bookkeeping

# %% [markdown]
# Put everything into PyTorch and do a train/test split:

# %%
from multiprocessing import cpu_count

Xt = torch.tensor(X).float()
zt = torch.tensor(z).float()
X_train, X_test, z_train, z_test = train_test_split(Xt, zt, random_state=0)
train_set = TensorDataset(X_train, z_train)
train = DataLoader(
    train_set, batch_size=128, num_workers=cpu_count(), shuffle=True, pin_memory=True
)
test_set = TensorDataset(X_test, z_test)
test = DataLoader(test_set, batch_size=256, num_workers=cpu_count(), pin_memory=True)

# %% [markdown]
# ## Train the model with PyTorch Lightning on GPUs:

# %% [markdown]
# Start the model:

# %%
pl.seed_everything(0)
model = SumNet()
model.total_steps = total_steps
model.max_lr = 1e-2

# %% [markdown]
# PyTorch Lightning trainer object:

# %%
trainer = pl.Trainer(max_steps=total_steps, accelerator="gpu", devices=1)

# %% [markdown]
# Here, we fit the neural network:

# %%
trainer.fit(model, train_dataloaders=train, val_dataloaders=test)

# %% [markdown]
# ## Latent vectors of network
#
# Let's get the input and output of the learned `g` function from the network over some random data:

# %%
np.random.seed(0)
idx = np.random.randint(0, 10000, size=1000)

X_for_pysr = Xt[idx]
y_i_for_pysr = model.g(X_for_pysr)[:, :, 0]
y_for_pysr = torch.sum(y_i_for_pysr, dim=1) / y_i_for_pysr.shape[1]
z_for_pysr = zt[idx]  # Use true values.

X_for_pysr.shape, y_i_for_pysr.shape

# %% [markdown]
# ## Learning over the network:
#
# Now, let's fit `g` using PySR.
#
# > **Warning**
# >
# > First, let's save the data, because sometimes PyTorch and juliacall's C bindings interfere and cause the colab kernel to crash. If we need to restart, we can just load the data without having to retrain the network:

# %%
nnet_recordings = {
    "g_input": X_for_pysr.detach().cpu().numpy().reshape(-1, 5),
    "g_output": y_i_for_pysr.detach().cpu().numpy().reshape(-1),
    "f_input": y_for_pysr.detach().cpu().numpy().reshape(-1, 1),
    "f_output": z_for_pysr.detach().cpu().numpy().reshape(-1),
}

# Save the data for later use:
import pickle as pkl

with open("nnet_recordings.pkl", "wb") as f:
    pkl.dump(nnet_recordings, f)

# %% [markdown]
# We can now load the data, including after a crash (be sure to re-run the import cells at the top of this notebook, including the one that starts juliacall).

# %%
import pickle as pkl

nnet_recordings = pkl.load(open("nnet_recordings.pkl", "rb"))
f_input = nnet_recordings["f_input"]
f_output = nnet_recordings["f_output"]
g_input = nnet_recordings["g_input"]
g_output = nnet_recordings["g_output"]

# %% [markdown]
# And now fit using a subsample of the data (symbolic regression only needs a small sample to find the best equation):

# %%
rstate = np.random.RandomState(0)
f_sample_idx = rstate.choice(f_input.shape[0], size=500, replace=False)

model = PySRRegressor(
    niterations=50,
    binary_operators=["+", "-", "*"],
    unary_operators=["cos", "square"],
)
model.fit(g_input[f_sample_idx], g_output[f_sample_idx])

# %% [markdown]
# If this segfaults, restart the notebook, and run the initial imports and juliacall part, but skip the PyTorch training. This is because PyTorch's C binding tends to interefere with juliacall. You can then re-run the `pkl.load` cell to import the data.

# %% [markdown]
# ## Validation

# %% [markdown]
# Recall we are searching for $f$ and $g$ such that:
# $$z=f(\sum g(x_i))$$
# which approximates the true relation:
# $$ z = y^2,\quad y = \frac{1}{10} \sum(y_i),\quad y_i = x_{i0}^2 + 6 \cos(2 x_{i2})$$
#
# Let's see how well we did in recovering $g$:

# %%
model.equations_[["complexity", "loss", "equation"]]

# %% [markdown]
# A neural network can easily undo a linear transform (which commutes with the summation), so any affine transform in $g$ is to be expected. The network for $f$ has learned to undo the linear transform.
#
# This likely won't find the exact result, but it should find something similar. You may wish to try again but with many more `total_steps` for the neural network (10,000 is quite small!).
#
# Then, we can learn another analytic equation for $f$.

# %% [markdown]
# **Now, we can compose these together to get the time series model!**
#
# Think about what we just did: we found an analytical equation for $z$ in terms of $500$ datapoints, under the assumption that $z$ is a function of a sum of another function over an axis:
#
# $$ z = f(\sum_i g(x_i)) $$
#
# And we pulled out analytical copies for $g$ using symbolic regression.

# %% [markdown]
# # Other PySR Options

# %% [markdown]
# The full list of PySR parameters can be found here: https://ai.damtp.cam.ac.uk/pysr/api
