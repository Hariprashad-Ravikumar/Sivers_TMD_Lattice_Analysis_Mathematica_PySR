# %% [markdown]
# # TMD A12B for specific eta

# %%
pip install -U pysr
# Out:
# Requirement already satisfied: pysr in /opt/homebrew/anaconda3/lib/python3.11/site-packages (1.5.9)
# Requirement already satisfied: click<9.0.0,>=7.0.0 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from pysr) (8.0.4)
# Requirement already satisfied: juliacall<0.9.27,>=0.9.24 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from pysr) (0.9.24)
# Requirement already satisfied: numpy<3.0.0,>=1.13.0 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from pysr) (1.26.4)
# Requirement already satisfied: pandas<3.0.0,>=0.21.0 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from pysr) (2.0.3)
# Requirement already satisfied: scikit-learn<2.0.0,>=1.0.0 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from pysr) (1.2.2)
# Requirement already satisfied: sympy<2.0.0,>=1.0.0 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from pysr) (1.11.1)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.0.0 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from pysr) (4.7.1)
# Requirement already satisfied: juliapkg~=0.1.8 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from juliacall<0.9.27,>=0.9.24->pysr) (0.1.15)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from pandas<3.0.0,>=0.21.0->pysr) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from pandas<3.0.0,>=0.21.0->pysr) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from pandas<3.0.0,>=0.21.0->pysr) (2023.3)
# Requirement already satisfied: scipy>=1.3.2 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from scikit-learn<2.0.0,>=1.0.0->pysr) (1.11.1)
# Requirement already satisfied: joblib>=1.1.1 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from scikit-learn<2.0.0,>=1.0.0->pysr) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from scikit-learn<2.0.0,>=1.0.0->pysr) (2.2.0)
# Requirement already satisfied: mpmath>=0.19 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from sympy<2.0.0,>=1.0.0->pysr) (1.3.0)
# Requirement already satisfied: semver~=3.0 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from juliapkg~=0.1.8->juliacall<0.9.27,>=0.9.24->pysr) (3.0.2)
# Requirement already satisfied: six>=1.5 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas<3.0.0,>=0.21.0->pysr) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Julia and Julia dependencies are installed at first import:

# %%
import pysr
# Out:
# Detected IPython. Loading juliacall extension. See https://juliapy.github.io/PythonCall.jl/stable/compat/#IPython

# %% [markdown]
# Now, let's import everything else as well as the PySRRegressor:

# %%
import sympy
import numpy as np
from matplotlib import pyplot as plt
from pysr import PySRRegressor
from sklearn.model_selection import train_test_split
import h5py

# %% [markdown]
# # PySR for A12B eta = 8:

# %%
file_path = "/Users/hariprashadravikumar/sivers_TMD_PhD_project/save_h5_A12B_A2B/allPL_eta_bP_bsq_mean_err_forReImAmps.h5"
P1 = 1
data_list = []
with h5py.File(file_path, "r") as h5_file:
    dataset_name = f"Pl-{P1}/eta_8_bP_bsq_ReA2B_err" #typo in bL : this is not PL
    dataPl = np.array(h5_file[dataset_name])    
    data_list.append(dataPl)

data = np.vstack(data_list)

# Remove rows where bL=0 and bT=0
#mask =  ~((data[:, 1] >= -3) & (data[:, 1] <= 3))
#data = data[mask]

# Extract bLbT and A12B
bLbT = data[:, 1:3]  
A2B = data[:, 3]   
A2Berr = data[:, 4]
A2Bweight = [1/sigma**2 for sigma in A2Berr]


print(data)
#print("A12B =", A12B)
#print("A12Berr =", A12Berr)
# Out:
# [[ 8.00000000e+00  0.00000000e+00  0.00000000e+00  6.28153624e-01
#    3.33112847e-03]
#  [ 8.00000000e+00  0.00000000e+00  1.00000000e+00  2.61209537e-01
#    1.43643635e-03]
#  [ 8.00000000e+00  0.00000000e+00  4.00000000e+00  6.57581804e-02
#    5.66755850e-04]
#  [ 8.00000000e+00  0.00000000e+00  9.00000000e+00  2.28603913e-02
#    4.61190206e-04]
#  [ 8.00000000e+00  0.00000000e+00  1.60000000e+01  1.10455765e-02
#    4.37154849e-04]
#  [ 8.00000000e+00  0.00000000e+00  2.50000000e+01  5.65817564e-03
#    3.88171083e-04]
#  [ 8.00000000e+00  0.00000000e+00  3.60000000e+01  2.98949333e-03
#    3.70887394e-04]
#  [ 8.00000000e+00  0.00000000e+00  4.90000000e+01  1.78943998e-03
#    3.49795026e-04]
#  [ 8.00000000e+00 -1.00000000e+00  2.00000000e+00  1.54689921e-01
#    8.85503088e-04]
#  [ 8.00000000e+00 -2.00000000e+00  8.00000000e+00  2.82273136e-02
#    3.49390873e-04]
#  [ 8.00000000e+00 -3.00000000e+00  1.80000000e+01  9.06878609e-03
#    2.88949902e-04]
#  [ 8.00000000e+00 -4.00000000e+00  3.20000000e+01  3.48740776e-03
#    2.49332383e-04]
#  [ 8.00000000e+00 -5.00000000e+00  5.00000000e+01  1.74643865e-03
#    2.18757826e-04]
#  [ 8.00000000e+00 -1.00000000e+00  5.00000000e+00  5.06734256e-02
#    4.46623151e-04]
#  [ 8.00000000e+00 -2.00000000e+00  2.00000000e+01  7.88882659e-03
#    2.82568733e-04]
#  [ 8.00000000e+00 -3.00000000e+00  4.50000000e+01  2.01312943e-03
#    2.47051575e-04]
#  [ 8.00000000e+00 -2.00000000e+00  5.00000000e+00  5.73069083e-02
#    4.77542111e-04]
#  [ 8.00000000e+00 -4.00000000e+00  2.00000000e+01  8.11110352e-03
#    3.26554656e-04]
#  [ 8.00000000e+00 -6.00000000e+00  4.50000000e+01  1.77703882e-03
#    2.33919682e-04]
#  [ 8.00000000e+00 -4.00000000e+00  1.70000000e+01  1.07166904e-02
#    3.61379410e-04]
#  [ 8.00000000e+00 -8.00000000e+00  6.80000000e+01  8.21812964e-04
#    2.24048479e-04]
#  [ 8.00000000e+00  1.00000000e+00  2.00000000e+00  1.54689921e-01
#    8.85503088e-04]
#  [ 8.00000000e+00  2.00000000e+00  8.00000000e+00  2.82273136e-02
#    3.49390873e-04]
#  [ 8.00000000e+00  3.00000000e+00  1.80000000e+01  9.06878609e-03
#    2.88949902e-04]
#  [ 8.00000000e+00  4.00000000e+00  3.20000000e+01  3.48740776e-03
#    2.49332383e-04]
#  [ 8.00000000e+00  5.00000000e+00  5.00000000e+01  1.74643865e-03
#    2.18757826e-04]
#  [ 8.00000000e+00  1.00000000e+00  5.00000000e+00  5.06734256e-02
#    4.46623151e-04]
#  [ 8.00000000e+00  2.00000000e+00  2.00000000e+01  7.88882659e-03
#    2.82568733e-04]
#  [ 8.00000000e+00  3.00000000e+00  4.50000000e+01  2.01312943e-03
#    2.47051575e-04]
#  [ 8.00000000e+00  2.00000000e+00  5.00000000e+00  5.73069083e-02
#    4.77542111e-04]
#  [ 8.00000000e+00  4.00000000e+00  2.00000000e+01  8.11110352e-03
#    3.26554656e-04]
#  [ 8.00000000e+00  6.00000000e+00  4.50000000e+01  1.77703882e-03
#    2.33919682e-04]
#  [ 8.00000000e+00  4.00000000e+00  1.70000000e+01  1.07166904e-02
#    3.61379410e-04]
#  [ 8.00000000e+00  8.00000000e+00  6.80000000e+01  8.21812964e-04
#    2.24048479e-04]]

# %%
# Extract unique bT values
unique_bT = np.unique(bLbT[:, 1])

# Create the plot
plt.figure(figsize=(10, 6))

for i, bT in enumerate(unique_bT):
    #if bT<1 :
    #    continue
    # Filter data for the current bT value
    mask = bLbT[:, 1] == bT
    bL_values = bLbT[mask, 0]
    A2B_values = A2B[mask]
    A2B_errors = A2Berr[mask]

    # Plot with error bars
    plt.errorbar(
        bL_values,
        A2B_values,
        yerr=A2B_errors,
        fmt='o',
        label=f"$b_T$ = {int(bT)}",
        capsize=4
    )
# Add labels, legend, and grid
plt.xlabel("$b_{L}$", fontsize=14)
plt.ylabel("$A_{2B}$", fontsize=14)
plt.title("Plot of $A_{2B}$ vs $P_L$ for Different $b_T$ Values", fontsize=16)
plt.legend(fontsize=10)
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Extract unique bT values
unique_bL = np.unique(bLbT[:, 0])

# Create the plot
plt.figure(figsize=(10, 6))

for i, bL in enumerate(unique_bL):
    #if bT<1 :
    #    continue
    # Filter data for the current bT value
    mask = bLbT[:, 0] == bL
    bT_values = bLbT[mask, 1]
    A2B_values = A2B[mask]
    A2B_errors = A2Berr[mask]

    # Plot with error bars
    plt.errorbar(
        bT_values,
        A2B_values,
        yerr=A2B_errors,
        fmt='o',
        label=f"$b_L$ = {bL}",
        capsize=4
    )
# Add labels, legend, and grid
plt.xlabel("$b_T$", fontsize=14)
plt.ylabel("$A_{2B}$", fontsize=14)
plt.title("Plot of $A_{2B}$ vs $b_T$ for Different $b_L$ Values", fontsize=16)
plt.legend(fontsize=10)
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# By default, we will set up 30 populations of expressions (which evolve independently except for migrations), use 4 threads, and use `"best"` for our model selection strategy:

# %%
default_pysr_params = dict(
    populations=30,
    model_selection="best",
)

# %%
from sympy import exp, sech, symbols, Function

custom_loss_function = """
using Symbolics

function eval_loss(tree, dataset::Dataset{T,L}, options)::L where {T,L}
    prediction, flag = eval_tree_array(tree, dataset.X, options)
    if !flag
        return L(Inf)
    end
    
    wmse = sum((prediction .- dataset.y).^2 .* dataset.weights) / (dataset.n - 3)
    return wmse
end
"""

extra_sympy_mappings = {
    "PowerLaw": lambda x, y: 1 / (y + x**1)
}



modelold = PySRRegressor(
    niterations=50,
    unary_operators=["exp", "sech"],
    binary_operators=["*", "PowerLaw(x, y) = 1/(y + x^1)", "^"],
    extra_sympy_mappings=extra_sympy_mappings,  # Include the custom mappings
    loss_function=custom_loss_function,  # Use the custom loss function
    nested_constraints = { "PowerLaw": {"PowerLaw": 0}},
    constraints={'^': (-1, 1), 'PowerLaw': (-1, 1)}

)

model = PySRRegressor(
    niterations=50,
    maxsize = 30,
    #unary_operators=["exp", "sin", "cos"],
    binary_operators=["*", "+", "-", "/", "^"],
    #extra_sympy_mappings=extra_sympy_mappings,  # Include the custom mappings
    loss_function=custom_loss_function,  # Use the custom loss function
    #nested_constraints = { "^": {"^": 0, "+": 0},  "/": {"^": 0, "+": 0}},
    constraints={'^': (-1, 1)}

)


model.fit(bLbT, A2B, weights=A2Bweight, variable_names=['bL', 'bT'])
# Out:
# /opt/homebrew/anaconda3/lib/python3.11/site-packages/pysr/sr.py:2811: UserWarning: Note: it looks like you are running in Jupyter. The progress bar will be turned off.
#   warnings.warn(
# [ Info: Started!
# [ Info: Final population:
# [ Info: Results saved to:
# PySRRegressor.equations_ = [
# 	    pick     score                                           equation  \
# 	0         0.000000                                        0.010525331
# 	1         0.397550                                     0.4399223 ^ bT
# 	2         0.908134                     0.27910525 / (bT + 0.40755898)
# 	3         1.762889          (1.084779 / (bT + 1.4375178)) ^ 1.6418976
# 	4         0.013962  0.9449937 / (((bT + 1.0386342) ^ 1.583457) - -...
# 	5         0.004912  (0.908128 / (((bT + 0.99127483) ^ 1.5648537) -...
# 	6         0.694302  0.9695905 / (((bL * -0.54775846) * bL) + ((bT ...
# 	7         0.441626  (1.510899 / ((((bT ^ 1.321321) * 3.3109457) + ...
# 	8         0.000575  (0.70925516 / ((1.129389 - ((bL * bL) * 0.4744...
# 	9         0.000002  (0.70925534 / ((((bT ^ 1.3210654) * 1.5561787)...
# 	10  >>>>  0.142729  (1.0668213 / ((1.696325 - (((bL * bL) / 1.4715...
# 	11        0.059295  (0.83929884 / ((1.3324897 - ((bL * bL) / (((1....
#
# 	           loss  complexity
# 	0   5929.489700           1
# 	1   2677.380400           3
# 	2    435.426150           5
# 	3     12.814111           7
# 	4     12.461228           9
# 	5     12.339399          11
# 	6      3.077731          13
# 	7      1.272445          15
# 	8      1.270983          17
# 	9      1.270979          19
# 	10     0.955357          21
# 	11     0.669355          27
# ]
# Error in callback _flush_stdio (for post_execute):
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# File ~/.julia/packages/PythonCall/WMWY0/src/JlWrap/any.jl:262, in __call__(self, *args, **kwargs)
#     260     return ValueBase.__dir__(self) + self._jl_callmethod($(pyjl_methodnum(pyjlany_dir)))
#     261 def __call__(self, *args, **kwargs):
# --> 262     return self._jl_callmethod($(pyjl_methodnum(pyjlany_call)), args, kwargs)
#     263 def __bool__(self):
#     264     return True
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xe2 in position 4095: unexpected end of data

# %%
pick = 10
model.sympy(pick)
# Out:
# -0.00072031654 + 1.0668213/(bT**1.4449407*1.4751341 - (bL*bL/1.4715356 + bT*(-0.90589094)) + 1.696325)
# Error in callback _flush_stdio (for post_execute):
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# File ~/.julia/packages/PythonCall/WMWY0/src/JlWrap/any.jl:262, in __call__(self, *args, **kwargs)
#     260     return ValueBase.__dir__(self) + self._jl_callmethod($(pyjl_methodnum(pyjlany_dir)))
#     261 def __call__(self, *args, **kwargs):
# --> 262     return self._jl_callmethod($(pyjl_methodnum(pyjlany_call)), args, kwargs)
#     263 def __bool__(self):
#     264     return True
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xe2 in position 4095: unexpected end of data

# %%
#model.latex(pick)

model.predict([[-1,-4]], pick)
# Out:
# array([0.0102412])

# %% [markdown]
# We can also view the SymPy of any other expression in the list, using the index of it in `model.equations_`.

# %%
bL_plot = np.linspace(-8,8, 100)
plt.figure(figsize=(10, 6))

for bT in unique_bT:
    bLbT_plot = np.array([[bL, bT] for bL in bL_plot])
    predictions = model.predict(bLbT_plot, pick)
    plt.plot(bLbT_plot, predictions)
for i, bT in enumerate(unique_bT):
    #if bT<1 :
    #    continue
    # Filter data for the current bT value
    mask = bLbT[:, 1] == bT
    bL_values = bLbT[mask, 0]
    A2B_values = A2B[mask]
    A2B_errors = A2Berr[mask]

    # Plot with error bars
    plt.errorbar(
        bL_values,
        A2B_values,
        yerr=A2B_errors,
        fmt='o',
        label=f"$b_T$ = {int(bT)}",
        capsize=4
    )
# Add labels, legend, and grid
plt.xlabel("$b_{L}$", fontsize=14)
plt.ylabel("$A_{2B}$", fontsize=14)
plt.title("Plot of $A_{2B}$ vs $P_L$ for Different $b_T$ Values", fontsize=16)
plt.legend(fontsize=10)
plt.grid(True)
plt.tight_layout()
plt.show()


model.sympy(pick)
# Out:
# -0.00072031654 + 1.0668213/(bT**1.4449407*1.4751341 - (bL*bL/1.4715356 + bT*(-0.90589094)) + 1.696325)
# Error in callback _flush_stdio (for post_execute):
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# File ~/.julia/packages/PythonCall/WMWY0/src/JlWrap/any.jl:262, in __call__(self, *args, **kwargs)
#     260     return ValueBase.__dir__(self) + self._jl_callmethod($(pyjl_methodnum(pyjlany_dir)))
#     261 def __call__(self, *args, **kwargs):
# --> 262     return self._jl_callmethod($(pyjl_methodnum(pyjlany_call)), args, kwargs)
#     263 def __bool__(self):
#     264     return True
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xe2 in position 4095: unexpected end of data

# %%
bT_plot = np.linspace(-7,7, 100)
plt.figure(figsize=(10, 6))

for bL in unique_bL:
    bLbT_plott = np.array([[bL, bT] for bT in bT_plot])
    predictions = model.predict(bLbT_plott, pick)
    plt.plot(bLbT_plott, predictions)

for i, bL in enumerate(unique_bL):
    #if bT<1 :
    #    continue
    # Filter data for the current bT value
    mask = bLbT[:, 0] == bL
    bT_values = bLbT[mask, 1]
    A2B_values = A2B[mask]
    A2B_errors = A2Berr[mask]

    # Plot with error bars
    plt.errorbar(
        bT_values,
        A2B_values,
        yerr=A2B_errors,
        fmt='o',
        label=f"$b_L$ = {bL}",
        capsize=4
    )
# Add labels, legend, and grid
plt.xlabel("$b_T$", fontsize=14)
plt.ylabel("$A_{2B}$", fontsize=14)
plt.title("Plot of $A_{2B}$ vs $b_T$ for Different $b_L$ Values", fontsize=16)
plt.legend(fontsize=10)
plt.grid(True)
plt.tight_layout()
plt.show()

model.sympy(pick)
# Out:
# <lambdifygenerated-136>:2: RuntimeWarning: invalid value encountered in power
#   return -0.00072031654 + 1.0668213/(1.4751341*bT**1.4449407 - (bL*bL/1.4715356 + (-0.90589094)*bT) + 1.696325)
# <lambdifygenerated-137>:2: RuntimeWarning: invalid value encountered in power
#   return -0.00072031654 + 1.0668213/(1.4751341*bT**1.4449407 - (bL*bL/1.4715356 + (-0.90589094)*bT) + 1.696325)
# <lambdifygenerated-138>:2: RuntimeWarning: invalid value encountered in power
#   return -0.00072031654 + 1.0668213/(1.4751341*bT**1.4449407 - (bL*bL/1.4715356 + (-0.90589094)*bT) + 1.696325)
# <lambdifygenerated-139>:2: RuntimeWarning: invalid value encountered in power
#   return -0.00072031654 + 1.0668213/(1.4751341*bT**1.4449407 - (bL*bL/1.4715356 + (-0.90589094)*bT) + 1.696325)
# <lambdifygenerated-140>:2: RuntimeWarning: invalid value encountered in power
#   return -0.00072031654 + 1.0668213/(1.4751341*bT**1.4449407 - (bL*bL/1.4715356 + (-0.90589094)*bT) + 1.696325)
# <lambdifygenerated-141>:2: RuntimeWarning: invalid value encountered in power
#   return -0.00072031654 + 1.0668213/(1.4751341*bT**1.4449407 - (bL*bL/1.4715356 + (-0.90589094)*bT) + 1.696325)
# <lambdifygenerated-142>:2: RuntimeWarning: invalid value encountered in power
#   return -0.00072031654 + 1.0668213/(1.4751341*bT**1.4449407 - (bL*bL/1.4715356 + (-0.90589094)*bT) + 1.696325)
# <lambdifygenerated-143>:2: RuntimeWarning: invalid value encountered in power
#   return -0.00072031654 + 1.0668213/(1.4751341*bT**1.4449407 - (bL*bL/1.4715356 + (-0.90589094)*bT) + 1.696325)
# <lambdifygenerated-144>:2: RuntimeWarning: invalid value encountered in power
#   return -0.00072031654 + 1.0668213/(1.4751341*bT**1.4449407 - (bL*bL/1.4715356 + (-0.90589094)*bT) + 1.696325)
# <lambdifygenerated-145>:2: RuntimeWarning: invalid value encountered in power
#   return -0.00072031654 + 1.0668213/(1.4751341*bT**1.4449407 - (bL*bL/1.4715356 + (-0.90589094)*bT) + 1.696325)
# <lambdifygenerated-146>:2: RuntimeWarning: invalid value encountered in power
#   return -0.00072031654 + 1.0668213/(1.4751341*bT**1.4449407 - (bL*bL/1.4715356 + (-0.90589094)*bT) + 1.696325)
# <lambdifygenerated-147>:2: RuntimeWarning: invalid value encountered in power
#   return -0.00072031654 + 1.0668213/(1.4751341*bT**1.4449407 - (bL*bL/1.4715356 + (-0.90589094)*bT) + 1.696325)
# <lambdifygenerated-148>:2: RuntimeWarning: invalid value encountered in power
#   return -0.00072031654 + 1.0668213/(1.4751341*bT**1.4449407 - (bL*bL/1.4715356 + (-0.90589094)*bT) + 1.696325)
# <lambdifygenerated-149>:2: RuntimeWarning: invalid value encountered in power
#   return -0.00072031654 + 1.0668213/(1.4751341*bT**1.4449407 - (bL*bL/1.4715356 + (-0.90589094)*bT) + 1.696325)
# <lambdifygenerated-150>:2: RuntimeWarning: invalid value encountered in power
#   return -0.00072031654 + 1.0668213/(1.4751341*bT**1.4449407 - (bL*bL/1.4715356 + (-0.90589094)*bT) + 1.696325)
# -0.00072031654 + 1.0668213/(bT**1.4449407*1.4751341 - (bL*bL/1.4715356 + bT*(-0.90589094)) + 1.696325)
# Error in callback _flush_stdio (for post_execute):
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# File ~/.julia/packages/PythonCall/WMWY0/src/JlWrap/any.jl:262, in __call__(self, *args, **kwargs)
#     260     return ValueBase.__dir__(self) + self._jl_callmethod($(pyjl_methodnum(pyjlany_dir)))
#     261 def __call__(self, *args, **kwargs):
# --> 262     return self._jl_callmethod($(pyjl_methodnum(pyjlany_call)), args, kwargs)
#     263 def __bool__(self):
#     264     return True
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xe2 in position 4095: unexpected end of data

# %%
model.equations_[["complexity", "loss", "equation"]]
# Out:
#     complexity         loss                                           equation
# 0            1  3496.224600                                        0.011494168
# 1            5  2694.088600                             (0.04454696 ^ bT) ^ bT
# 2            6  2561.390900                       sin((0.044563945 ^ bT) ^ bT)
# 3            7  2124.244400             0.051070243 / ((bT * bT) + 0.08197257)
# 4            9  2102.989500  0.048363578 / (((bT * bT) ^ 0.8272242) + 0.077...
# 5           10   847.203860            0.52314216 / ((bL * bL) + exp(bT * bT))
# 6           11   249.527570  0.28998753 / ((bL * bL) + ((bT * bT) + 0.41461...
# 7           12     7.171931  sin((((bL * bL) + (bT * bT)) + 1.2760693) ^ -1...
# 8           13     7.049274  (1.0949587 / ((bT * bT) + ((bL * bL) + 1.45352...
# 9           14     1.363645  sin(((bL * (bL * 0.87349325)) + ((bT * bT) + 1...
# 10          16     1.348112  sin((((bT * (bT + -0.0039355694)) + (bL * (bL ...
# 11          17     1.226558  sin(sin(0.8860384 / (((((bL * 0.86736226) * bL...
# 12          19     1.162087  sin(sin(0.85540193 / ((((bL * (bL * 0.86882377...
# 13          20     1.155500  sin(sin(sin((0.729443 / (((bT * bT) + (((bL * ...
# 14          21     0.697214  sin((1.2475692 / (((bT * bT) + ((bL * bL) + si...
# 15          23     0.637436  sin((1.2555306 / ((((bL * bL) ^ 0.9918435) + (...
# 16          24     0.500329  sin(sin((1.1691465 / ((sin((bT * bT) * 0.18012...
# 17          25     0.494509  sin(sin((1.1857629 / ((((bT * bT) + ((bL * bL)...
# 18          26     0.441194  sin(sin((1.1834966 / (((((bL * bL) ^ 0.9919624...
# 19          28     0.433441  sin(sin((1.1835847 / ((((bL * bL) ^ 0.992025) ...
# 20          30     0.423776  sin(sin((1.1835269 / (((((bL * bL) ^ 0.9921004...
