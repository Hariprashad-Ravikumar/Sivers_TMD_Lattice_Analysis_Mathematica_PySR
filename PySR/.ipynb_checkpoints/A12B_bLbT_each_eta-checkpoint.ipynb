# %% [markdown]
# # TMD A12B for specific eta

# %%
pip install -U pysr
# Out:
# Requirement already satisfied: pysr in /opt/homebrew/anaconda3/lib/python3.11/site-packages (1.3.1)
# Requirement already satisfied: sympy<2.0.0,>=1.0.0 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from pysr) (1.11.1)
# Requirement already satisfied: pandas<3.0.0,>=0.21.0 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from pysr) (2.0.3)
# Requirement already satisfied: numpy<3.0.0,>=1.13.0 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from pysr) (1.26.4)
# Requirement already satisfied: scikit_learn<2.0.0,>=1.0.0 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from pysr) (1.2.2)
# Requirement already satisfied: juliacall==0.9.23 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from pysr) (0.9.23)
# Requirement already satisfied: click<9.0.0,>=7.0.0 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from pysr) (8.0.4)
# Requirement already satisfied: setuptools>=50.0.0 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from pysr) (68.0.0)
# Requirement already satisfied: juliapkg~=0.1.8 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from juliacall==0.9.23->pysr) (0.1.15)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from pandas<3.0.0,>=0.21.0->pysr) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from pandas<3.0.0,>=0.21.0->pysr) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from pandas<3.0.0,>=0.21.0->pysr) (2023.3)
# Requirement already satisfied: scipy>=1.3.2 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from scikit_learn<2.0.0,>=1.0.0->pysr) (1.11.1)
# Requirement already satisfied: joblib>=1.1.1 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from scikit_learn<2.0.0,>=1.0.0->pysr) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from scikit_learn<2.0.0,>=1.0.0->pysr) (2.2.0)
# Requirement already satisfied: mpmath>=0.19 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from sympy<2.0.0,>=1.0.0->pysr) (1.3.0)
# Requirement already satisfied: semver~=3.0 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from juliapkg~=0.1.8->juliacall==0.9.23->pysr) (3.0.2)
# Requirement already satisfied: six>=1.5 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas<3.0.0,>=0.21.0->pysr) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Julia and Julia dependencies are installed at first import:

# %%
import pysr
# Out:
# Detected IPython. Loading juliacall extension. See https://juliapy.github.io/PythonCall.jl/stable/compat/#IPython

# %% [markdown]
# Now, let's import everything else as well as the PySRRegressor:

# %%
import sympy
import numpy as np
from matplotlib import pyplot as plt
from pysr import PySRRegressor
from sklearn.model_selection import train_test_split
import h5py

# %% [markdown]
# # PySR for A12B eta = 8:

# %%
file_path = "/Users/hariprashadravikumar/sivers_TMD_PhD_project/save_h5_A12B_A2B/eta_Pb_bsquare_A12B_err_AllMomentum.h5"
#with h5py.File(file_path, "r") as h5_file:
#    # Specify the dataset to extract
#    dataset_name = "Pl-2/eta_8_Pb_bsq_A12B_err"
#    data = np.array(h5_file[dataset_name])

data_list = []
with h5py.File(file_path, "r") as h5_file:
    for P in range(1, 5):
        dataset_name = f"Pl-{P}/eta_8_Pb_bsq_A12B_err"
        dataPl = np.array(h5_file[dataset_name])    
        data_list.append(dataPl)

data = np.vstack(data_list)
# Extract bLbT and A12B
Pbbsq = data[:, 1:3]  
A12B = data[:, 3]   
A12Berr = data[:, 4]
A12Bweight = [1/sigma**2 for sigma in A12Berr]


#print("bLbT =", bLbT)
#print("A12B =", A12B)
#print("A12Berr =", A12Berr)

# %%
# Extract unique bT values
unique_bsq = np.unique(Pbbsq[:, 1])

# Create the plot
plt.figure(figsize=(10, 6))

for i, bsq in enumerate(unique_bsq):
    #if bT<1 :
    #    continue
    # Filter data for the current bT value
    mask = Pbbsq[:, 1] == bsq
    Pb_values = Pbbsq[mask, 0]
    A12B_values = A12B[mask]
    A12B_errors = A12Berr[mask]

    # Plot with error bars
    plt.errorbar(
        Pb_values,
        A12B_values,
        yerr=A12B_errors,
        fmt='o',
        label=f"$b^2$ = {int(bsq)}",
        capsize=4
    )
# Add labels, legend, and grid
plt.xlabel("$P\cdot b$", fontsize=14)
plt.ylabel("$A_{12B}$", fontsize=14)
plt.title("Plot of $A_{12B}$ vs $P\cdot b$ for Different $b^2$ Values", fontsize=16)
plt.legend(fontsize=10)
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Extract unique bT values
unique_Pb = np.unique(Pbbsq[:, 0])

# Create the plot
plt.figure(figsize=(10, 6))

for i, Pb in enumerate(unique_Pb):
    #if bT<1 :
    #    continue
    # Filter data for the current bT value
    mask = Pbbsq[:, 0] == Pb
    Psq_values = Pbbsq[mask, 1]
    A12B_values = A12B[mask]
    A12B_errors = A12Berr[mask]

    # Plot with error bars
    plt.errorbar(
        Psq_values,
        A12B_values,
        yerr=A12B_errors,
        fmt='o',
        label=f"$P\cdot b$ = {Pb}",
        capsize=4
    )
# Add labels, legend, and grid
plt.xlabel("$b^2$", fontsize=14)
plt.ylabel("$A_{12B}$", fontsize=14)
plt.title("Plot of $A_{12B}$ vs $b^2$ for Different $P\cdot b$ Values", fontsize=16)
plt.legend(fontsize=10)
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# By default, we will set up 30 populations of expressions (which evolve independently except for migrations), use 4 threads, and use `"best"` for our model selection strategy:

# %%
default_pysr_params = dict(
    populations=50,
    model_selection="best",
)

# %%
# test try functions
x = np.linspace(-10, 10, 1000)
y = 1 / (np.sqrt(1+x**2))

#plt.plot(x, y)
#plt.show()

# %%
#working wmse
#from sympy import exp, symbols, Function

#custom_loss_function = """
#function eval_loss(tree, dataset::Dataset{T,L}, options)::L where {T,L}
#    prediction, flag = eval_tree_array(tree, dataset.X, options)
#    if !flag
#        return L(Inf)
#    end
#    wmse = sum(dataset.weights .* (prediction .- dataset.y) .^ 2) / (dataset.n .* sum(dataset.weights))
#    return wmse
#end
#"""

#extra_sympy_mappings = {
#    "f": lambda Pb: Pb,  # Define f(Pb) as an identity for now (can be more complex)
#    "g": lambda bsq: bsq,  # Define g(bsq) similarly
#    "Lorentzian": lambda x, y: 1 / (y + x**2),
#    "gaussian": lambda x: exp(-x**2),
#    "decay": lambda x: exp(-x)
#}

#model = PySRRegressor(
#    niterations=30,
#    binary_operators=["*", "Lorentzian(x, y) = 1/(y + x^2)"],
#    unary_operators=["gaussian(x) = exp(-x^2)", "decay(x) = exp(-x)"],
#    extra_sympy_mappings=extra_sympy_mappings,  # Include the custom mappings
#    loss_function=custom_loss_function  # Use the custom loss function
#)

#model.fit(Pbbsq, A12B, weights=A12Bweight, variable_names=['Pb', 'bsq'])

# %%
from sympy import exp, symbols, Function

custom_loss_function = """
using Symbolics
function eval_loss(tree, dataset::Dataset{T,L}, options)::L where {T,L}
    prediction, flag = eval_tree_array(tree, dataset.X, options)
    if !flag
        return L(Inf)  # If evaluation fails, return Inf
    end
    
    # Compute weighted MSE
    wmse = sum(dataset.weights .* (prediction .- dataset.y) .^ 2) / (dataset.n * sum(dataset.weights))
    
    # Convert tree to symbolic expression
    symbolic_expr = Meta.parse(string(tree))  # Convert tree to Julia expression
    
    # Check if it can be factorized into two independent functions
    if is_factorizable(symbolic_expr)
        return 0  # No loss if factorized correctly
    else
        return Inf  # Huge penalty for non-factorizable expressions
    end
end

function eval_loss(tree, dataset::Dataset{T,L}, options)::L where {T,L}
    prediction, flag = eval_tree_array(tree, dataset.X, options)
    if !flag
        return L(Inf)
    end
    wmse = sum(dataset.weights .* (prediction .- dataset.y) .^ 2) / (dataset.n .* sum(dataset.weights))
    return wmse
end
"""

extra_sympy_mappings = {
    "f": lambda Pb: Pb,  # Define f(Pb) as an identity for now (can be more complex)
    "g": lambda bsq: bsq,  # Define g(bsq) similarly
    "Lorentzian": lambda x, y: 1 / (y + x**2),
    "gaussian": lambda x: exp(-x**2),
    "decay": lambda x: exp(-x)
}

model = PySRRegressor(
    niterations=30,
    binary_operators=["*", "Lorentzian(x, y) = 1/(y + x^2)"],
    unary_operators=["gaussian(x) = exp(-x^2)", "decay(x) = exp(-x)"],
    extra_sympy_mappings=extra_sympy_mappings,  # Include the custom mappings
    loss_function=custom_loss_function  # Use the custom loss function
)

model.fit(Pbbsq, A12B, weights=A12Bweight, variable_names=['Pb', 'bsq'])
# Out:
# /opt/homebrew/anaconda3/lib/python3.11/site-packages/pysr/sr.py:2766: UserWarning: Note: it looks like you are running in Jupyter. The progress bar will be turned off.
#   warnings.warn(
# [ Info: Precompiling Symbolics [0c5d862f-8b57-4792-8d23-62f2024744c7] (cache misses: wrong dep version loaded (2))
# [ Info: Precompiling ForwardDiffStaticArraysExt [b74fd6d0-9da7-541f-a07d-1b6af30a262f] (cache misses: wrong dep version loaded (2))
# [ Info: Precompiling FiniteDiffStaticArraysExt [75e56524-3a34-51de-85ea-03aa6eac4b64] (cache misses: wrong dep version loaded (2))
# [ Info: Precompiling DifferentiationInterfaceStaticArraysExt [a583ad16-7f3e-50a1-a3ab-8640d85ec5ce] (cache misses: wrong dep version loaded (2))
# [ Info: Precompiling DynamicExpressionsSymbolicUtilsExt [b85ff9ab-f544-5eb2-8eaf-e219a5e7647d] (cache misses: wrong dep version loaded (2))
# [ Info: Precompiling SymbolicRegressionSymbolicUtilsExt [100afd77-a77b-5381-b1ec-69e200d58033] (cache misses: wrong dep version loaded (2))
# [ Info: Precompiling RecursiveArrayToolsForwardDiffExt [14203109-85fb-5f77-af23-1cb7d9032242] (cache misses: wrong dep version loaded (2))
# [ Info: Precompiling SciMLBasePythonCallExt [2797fd30-2078-5027-980c-4c2c8a19c528]
# [ Info: Precompiling DifferentiationInterfaceSymbolicsExt [e6c02559-e2b6-5021-bc6e-a9f025c2d0c8] (cache misses: wrong dep version loaded (2))
# [ Info: Precompiling SymbolicsForwardDiffExt [4a213a23-c09c-5cde-9712-b631ad2c72df] (cache misses: wrong dep version loaded (2))
# [ Info: Started!
# Expressions evaluated per second: 1.290e+05
# Progress: 823 / 930 total iterations (88.495%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           3.343e-09  1.594e+01  y = -0.00025343
# 4           1.944e-09  1.807e-01  y = decay(bsq) * -0.079726
# 5           2.942e-10  1.888e+00  y = Lorentzian(bsq, 8.2153) * -0.12428
# 7           1.929e-10  2.111e-01  y = Lorentzian(bsq, Lorentzian(Pb, 0.083319)) * -0.10808
# 9           1.924e-10  1.397e-03  y = Lorentzian(bsq * 0.99292, Lorentzian(Pb, 0.084298)) * ...
#                                       -0.10808
# 10          1.919e-10  2.434e-03  y = Lorentzian(bsq, Lorentzian(Pb, 0.084298 * gaussian(Pb)...
#                                       )) * -0.10808
# 11          1.760e-10  8.651e-02  y = Lorentzian(bsq, Lorentzian(Pb, 0.079571) * decay(gauss...
#                                       ian(bsq))) * -0.10808
# 12          1.587e-10  1.037e-01  y = Lorentzian(bsq, 1.218) * (decay(Lorentzian(Pb * bsq, 0...
#                                       .78497)) * -0.13213)
# 14          1.578e-10  2.658e-03  y = Lorentzian(bsq, 0.96484) * (decay(Lorentzian(Pb * bsq,...
#                                        0.69437) * 0.88448) * -0.11995)
# 16          1.547e-10  9.886e-03  y = (Lorentzian(bsq, 0.6104) * decay(Lorentzian((bsq * Lor...
#                                       entzian(Pb, 0.84029)) * Pb, 0.69437))) * -0.12423
# 17          1.547e-10  1.623e-04  y = decay(Lorentzian(Pb * (bsq * Lorentzian(Pb, 0.84029)),...
#                                        0.69437)) * (Lorentzian(bsq, decay(0.47692)) * -0.12423)
# 18          1.526e-10  1.373e-02  y = (Lorentzian(bsq, 0.68719) * -0.12234) * decay(Lorentzi...
#                                       an(Lorentzian(Pb * -0.77879, 0.84034) * (Pb * bsq), 0.6943...
#                                       1))
# 22          1.471e-10  9.104e-03  y = (Lorentzian(bsq, Lorentzian(Lorentzian(bsq, Lorentzian...
#                                       (-0.33024, Pb)), 1.5046)) * -0.12423) * decay(Lorentzian(L...
#                                       orentzian(Pb, 0.84029) * (Pb * bsq), 0.69437))
# 25          1.460e-10  2.623e-03  y = (decay(Lorentzian(Lorentzian(Pb, 0.84029) * (Pb * bsq)...
#                                       , 0.69437)) * Lorentzian(bsq, gaussian(Lorentzian(Lorentzi...
#                                       an(Lorentzian(bsq, Lorentzian(-0.33024, Pb)), 0.82264), 0....
#                                       44186)))) * -0.12423
# 27          1.446e-10  4.708e-03  y = (decay(Lorentzian(Lorentzian(Pb, 0.84029) * (Pb * bsq)...
#                                       , 0.70488)) * Lorentzian(bsq, gaussian(Lorentzian(Lorentzi...
#                                       an(0.82264, Lorentzian(Lorentzian(-0.9053, Pb), Lorentzian...
#                                       (-0.12423, Pb))), Pb)))) * -0.12423
# 29          1.443e-10  9.488e-04  y = (-0.12423 * decay(Lorentzian(Lorentzian(Pb, 0.84029) *...
#                                        (Pb * bsq), 0.70488))) * Lorentzian(bsq, gaussian(Lorentz...
#                                       ian(Lorentzian(0.82264, Lorentzian(Lorentzian(-0.9053, Pb)...
#                                       , Lorentzian(-0.33024, 0.75176 * Pb))), 0.44186)))
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           3.343e-09  1.594e+01  y = -0.00025343
# 4           1.944e-09  1.807e-01  y = decay(bsq) * -0.079726
# 5           2.942e-10  1.888e+00  y = Lorentzian(bsq, 8.2153) * -0.12428
# 7           1.929e-10  2.111e-01  y = Lorentzian(bsq, Lorentzian(Pb, 0.083319)) * -0.10808
# 9           1.924e-10  1.397e-03  y = Lorentzian(bsq * 0.99292, Lorentzian(Pb, 0.084298)) * ...
#                                       -0.10808
# 10          1.910e-10  7.344e-03  y = Lorentzian(bsq, Lorentzian(Pb, gaussian(Pb) * 0.079368...
#                                       )) * -0.11179
# 11          1.760e-10  8.160e-02  y = Lorentzian(bsq, Lorentzian(Pb, 0.079571) * decay(gauss...
#                                       ian(bsq))) * -0.10808
# 12          1.587e-10  1.037e-01  y = Lorentzian(bsq, 1.218) * (decay(Lorentzian(Pb * bsq, 0...
#                                       .78497)) * -0.13213)
# 14          1.578e-10  2.658e-03  y = Lorentzian(bsq, 0.96484) * (decay(Lorentzian(Pb * bsq,...
#                                        0.69437) * 0.88448) * -0.11995)
# 16          1.547e-10  9.957e-03  y = (Lorentzian(bsq, 0.63192) * decay(Lorentzian(Pb * (bsq...
#                                        * Lorentzian(Pb, 0.84029)), 0.69437))) * -0.12423
# 17          1.547e-10  2.152e-05  y = (decay(Lorentzian(Pb * (bsq * Lorentzian(Pb, 0.84029))...
#                                       , 0.69437)) * Lorentzian(bsq, decay(0.47692))) * -0.12423
# 18          1.526e-10  1.373e-02  y = (Lorentzian(bsq, 0.68719) * -0.12234) * decay(Lorentzi...
#                                       an(Lorentzian(Pb * -0.77879, 0.84034) * (Pb * bsq), 0.6943...
#                                       1))
# 22          1.471e-10  9.104e-03  y = (Lorentzian(bsq, Lorentzian(Lorentzian(bsq, Lorentzian...
#                                       (-0.33024, Pb)), 1.5046)) * -0.12423) * decay(Lorentzian(L...
#                                       orentzian(Pb, 0.84029) * (Pb * bsq), 0.69437))
# 25          1.433e-10  8.866e-03  y = Lorentzian(bsq * -0.81306, gaussian(Lorentzian(bsq, Lo...
#                                       rentzian(-0.29543, Pb)))) * (-0.083668 * decay(Lorentzian(...
#                                       Pb * bsq, Lorentzian(Pb * -0.96961, Lorentzian(Pb, 0.8388)...
#                                       ))))
# 28          1.425e-10  1.692e-03  y = -0.083668 * (decay(Lorentzian(bsq * Pb, Lorentzian(Pb,...
#                                        Lorentzian(Pb, gaussian(Lorentzian(Lorentzian(-0.29543, b...
#                                       sq), bsq)))))) * Lorentzian(bsq * -0.81306, decay(Lorentzi...
#                                       an(bsq, Lorentzian(-0.29543, Pb)))))
# 30          1.370e-10  1.998e-02  y = (-0.083668 * decay(Lorentzian(bsq * Pb, Lorentzian(Pb ...
#                                       * Pb, Lorentzian(Pb, gaussian(Lorentzian(Lorentzian(bsq, -...
#                                       0.29543), bsq))))))) * Lorentzian(bsq * -0.81306, gaussian...
#                                       (Lorentzian(bsq, Lorentzian(0.25195, Pb))))
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# [ Info: Final population:
# [ Info: Results saved to:
# PySRRegressor.equations_ = [
# 	    pick     score                                           equation  \
# 	0         0.000000                                      -0.0002534321
# 	1         0.180661                           decay(bsq) * -0.07972628
# 	2         1.888086             Lorentzian(bsq, 8.21527) * -0.12428056
# 	3   >>>>  0.211131  Lorentzian(bsq, Lorentzian(Pb, 0.08331926)) * ...
# 	4         0.001397  Lorentzian(bsq * 0.992919, Lorentzian(Pb, 0.08...
# 	5         0.007344  Lorentzian(bsq, Lorentzian(Pb, gaussian(Pb) * ...
# 	6         0.081596  Lorentzian(bsq, Lorentzian(Pb, 0.07957093) * d...
# 	7         0.103684  Lorentzian(bsq, 1.217992) * (decay(Lorentzian(...
# 	8         0.002658  Lorentzian(bsq, 0.96483797) * (decay(Lorentzia...
# 	9         0.009957  (Lorentzian(bsq, 0.6319174) * decay(Lorentzian...
# 	10        0.000022  (decay(Lorentzian(Pb * (bsq * Lorentzian(Pb, 0...
# 	11        0.013726  (Lorentzian(bsq, 0.6871928) * -0.12234144) * d...
# 	12        0.009104  (Lorentzian(bsq, Lorentzian(Lorentzian(bsq, Lo...
# 	13        0.008866  Lorentzian(bsq * -0.8130569, gaussian(Lorentzi...
# 	14        0.001692  -0.08366785 * (decay(Lorentzian(bsq * Pb, Lore...
# 	15        0.019980  (-0.08366785 * decay(Lorentzian(bsq * Pb, Lore...
#
# 	            loss  complexity
# 	0   3.342574e-09           1
# 	1   1.944018e-09           4
# 	2   2.942489e-10           5
# 	3   1.928986e-10           7
# 	4   1.923605e-10           9
# 	5   1.909528e-10          10
# 	6   1.759905e-10          11
# 	7   1.586572e-10          12
# 	8   1.578160e-10          14
# 	9   1.547044e-10          16
# 	10  1.547010e-10          17
# 	11  1.525920e-10          18
# 	12  1.471354e-10          22
# 	13  1.432736e-10          25
# 	14  1.425483e-10          28
# 	15  1.369644e-10          30
# ]
#   - outputs/20250203_163021_cftqFi/hall_of_fame.csv

# %%
model.sympy(7)
# Out:
# exp(-1/(Pb**2*bsq**2 + 0.78497267))*(-0.13212946)/(bsq**2 + 1.217992)

# %% [markdown]
# We can also view the SymPy of any other expression in the list, using the index of it in `model.equations_`.

# %%
pick = 3


Pb_plot = np.linspace(-7,7, 100)
plt.figure(figsize=(10, 6))

for bsq in unique_bsq:
    Pbbsq_plot = np.array([[Pb, bsq] for Pb in Pb_plot])
    predictions = model.predict(Pbbsq_plot, pick)
    plt.plot(Pb_plot, predictions)
for i, bsq in enumerate(unique_bsq):
    #if bT<1 :
    #    continue
    # Filter data for the current bT value
    mask = Pbbsq[:, 1] == bsq
    Pb_values = Pbbsq[mask, 0]
    A12B_values = A12B[mask]
    A12B_errors = A12Berr[mask]

    # Plot with error bars
    plt.errorbar(
        Pb_values,
        A12B_values,
        yerr=A12B_errors,
        fmt='o',
        capsize=4
    )
# Add labels, legend, and grid
plt.xlabel("Pb", fontsize=14)
plt.ylabel("$A_{12B}$", fontsize=14)
plt.title("Plot of $A_{12B}$ vs $P\cdot b$ for Different $b^2$ Values", fontsize=16)
plt.grid(True)
plt.tight_layout()
plt.show()



model.sympy(pick)
# Out:
# -0.108075420000000/(bsq**2 + 1/(Pb**2 + 0.08331926))

# %%
b2_plot = np.linspace(1,70, 100)
plt.figure(figsize=(10, 6))

for Pb in unique_Pb:
    Pbbsq_plott = np.array([[Pb, bsq] for bsq in b2_plot])
    predictions = model.predict(Pbbsq_plott, pick)
    plt.plot(b2_plot, predictions)

for i, Pb in enumerate(unique_Pb):
    #if bT<1 :
    #    continue
    # Filter data for the current bT value
    mask = Pbbsq[:, 0] == Pb
    Psq_values = Pbbsq[mask, 1]
    A12B_values = A12B[mask]
    A12B_errors = A12Berr[mask]

    # Plot with error bars
    plt.errorbar(
        Psq_values,
        A12B_values,
        yerr=A12B_errors,
        fmt='o',
        label=f"$P\cdot b$ = {Pb}",
        capsize=4
    )
# Add labels, legend, and grid
plt.xlabel("$b^2$", fontsize=14)
plt.ylabel("$A_{12B}$", fontsize=14)
plt.title("Plot of $A_{12B}$ vs $b^2$ for Different $P\cdot b$ Values", fontsize=16)
plt.legend(fontsize=10)
plt.grid(True)
plt.tight_layout()
plt.show()

model.sympy(pick)
# Out:
# -0.108075420000000/(bsq**2 + 1/(Pb**2 + 0.08331926))

# %%
model.equations_[["complexity", "loss", "equation"]]
# Out:
#     complexity          loss  \
# 0            1  8.401524e-07
# 1            4  5.106943e-07
# 2            5  1.644968e-07
# 3            7  1.447267e-07
# 4            8  1.447125e-07
# 5            9  1.412813e-07
# 6           10  1.299861e-07
# 7           11  1.206802e-07
# 8           12  1.098606e-07
# 9           14  9.798884e-08
# 10          16  9.721676e-08
# 11          17  9.359788e-08
# 12          18  7.608047e-08
# 13          22  7.598152e-08
# 14          25  7.518236e-08
# 15          26  7.470027e-08
# 16          27  7.293974e-08
#
#                                              equation
# 0                                      -0.00029350637
# 1                            decay(bsq) * -0.10510765
# 2            Lorentzian(bsq, 6.3245196) * -0.14444137
# 3     Lorentzian(bsq * 0.30466238, bsq) * -0.03146952
# 4   Lorentzian(decay(1.1871403) * bsq, bsq) * -0.0...
# 5   (decay(gaussian(Pb)) * Lorentzian(bsq, 3.87747...
# 6   Lorentzian(0.5232718, gaussian(Pb)) * (Lorentz...
# 7   decay(gaussian(Pb * Pb)) * (Lorentzian(bsq, bs...
# 8   (gaussian(decay(gaussian(Lorentzian(Pb, -0.375...
# 9   gaussian(gaussian(bsq * gaussian(Lorentzian(Pb...
# 10  (gaussian(gaussian(bsq * gaussian(Lorentzian(P...
# 11  (Lorentzian(bsq, gaussian(-0.17788343)) * gaus...
# 12  (decay(gaussian(gaussian(Lorentzian(0.82301074...
# 13  Lorentzian(gaussian(0.036619205) * bsq, decay(...
# 14  (Lorentzian(bsq, 1.4559265) * decay(gaussian(g...
# 15  gaussian((bsq * decay(bsq)) * bsq) * ((Lorentz...
# 16  (Lorentzian(bsq, gaussian(Pb)) * (decay(gaussi...
