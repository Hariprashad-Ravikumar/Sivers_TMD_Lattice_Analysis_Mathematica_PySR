# %% [markdown]
# # TMD A2B for all eta

# %%
# !pip install -U pysr
# !pip install plotly

# %%
#import os
#os.environ["PYTHON_JULIACALL_AUTOLOAD_IPYTHON_EXTENSION"] = "no"

# %% [markdown]
# Julia and Julia dependencies are installed at first import:

# %%
import pysr
# Out:
# Detected IPython. Loading juliacall extension. See https://juliapy.github.io/PythonCall.jl/stable/compat/#IPython

# %% [markdown]
# Now, let's import everything else as well as the PySRRegressor:

# %%
import sympy
import numpy as np
from matplotlib import pyplot as plt
from pysr import PySRRegressor
from sklearn.model_selection import train_test_split
import h5py

# %% [markdown]
# # PySR for A2B for eta:

# %%
file_path = "/Users/hariprashadravikumar/sivers_TMD_PhD_project/save_h5_A12B_A2B/allPL_eta_bL_bT_mean_err_forReImAmps.h5"
data_list = []

P1 = 2
with h5py.File(file_path, "r") as h5_file:
    for eta in range(7, 11):
        dataset_name = f"Pl-{P1}/eta_{eta}_bL_bT_ReA2B_err"
        data_list.append(np.array(h5_file[dataset_name]))
        
data_for_eta = np.vstack(data_list)


bsqmin = 3

# Remove rows where bL=0 and bT=0
#mask =  ~((data_for_eta[:, 1] == 0) & (data_for_eta[:, 2] == 0))
mask =  ~((np.sqrt(data_for_eta[:, 1]**2 + data_for_eta[:, 2]**2) <=bsqmin) )
#mask =  ~((data_for_eta[:, 2] ==0) )
data_for_eta = data_for_eta[mask]

#mask =  ~((np.sqrt(data_for_eta[:, 1]**2 + data_for_eta[:, 2]**2) >bsqmin) )
#data_for_eta = data_for_eta[mask]


# Extract bLbT and A12B
etabLbT = data_for_eta[:, 0:3]  
A2B = data_for_eta[:, 3]   
A2Berr = data_for_eta[:, 4]
epsilon = 1e-12
A2Bweight = [1.0 / max(sigma, epsilon)**2 for sigma in A2Berr]


#print("etabLbT =", etabLbT)
#print("A12B =", A12B)
#print("A12Berr =", A12Berr)

# %%
import plotly.graph_objects as go

# Extract unique values for bT
unique_bT = np.unique(etabLbT[:, 2])


fig = go.Figure()
for i, bT in enumerate(unique_bT):
    # Filter data
    mask = etabLbT[:, 2] == bT
    eta_values = etabLbT[mask, 0]
    bL_values = etabLbT[mask, 1]
    A2B_values = A2B[mask]
    A2B_errors = A2Berr[mask]

    # Add trace for each bT
    fig.add_trace(go.Scatter3d(
        x=eta_values , y=bL_values, z=A2B_values,
        mode="markers",
        error_z=dict(type="data", array=A2B_errors, visible=True),
        marker=dict(size=6),
        name=f"bT = {int(bT)}"
    ))

# Update layout
fig.update_layout(
    scene=dict(
        xaxis_title="eta",
        yaxis_title="bL",
        zaxis_title="A2B",
    ),
    title="Plot of A2B vs bL & eta for Different bT Values",
    margin=dict(l=0, r=0, b=0, t=40),
)

# Show interactive plot
fig.show()

# %% [markdown]
# By default, we will set up 30 populations of expressions (which evolve independently except for migrations), use 4 threads, and use `"best"` for our model selection strategy:

# %%
default_pysr_params = dict(
    populations=30,
    model_selection="best",
)

# %% [markdown]
# PySR can run for arbitrarily long, and continue to find more and more accurate expressions. You can set the total number of cycles of evolution with `niterations`, although there are also a [few more ways](https://github.com/MilesCranmer/PySR/pull/134) to stop execution.
#
# **This first execution will take a bit longer to startup, as the library is JIT-compiled. The next execution will be much faster.**

# %%
# Learn equations
from sympy import exp, symbols, Function

custom_loss_function = """
using Symbolics

function eval_loss(tree, dataset::Dataset{T,L}, options)::L where {T,L}
    prediction, flag = eval_tree_array(tree, dataset.X, options)
    if !flag
        return L(Inf)
    end
    
    wmse = sum((prediction .- dataset.y).^2 .* dataset.weights) / (dataset.n - 3)
    return wmse
end
"""

custom_loss_function_with_penalty = """
using Symbolics

function eval_loss(tree, dataset::Dataset{T,L}, options)::L where {T,L}
    prediction, flag = eval_tree_array(tree, dataset.X, options)
    if !flag
        return L(Inf)
    end

    wmse = sum((prediction .- dataset.y).^2 .* dataset.weights) / (dataset.n - 3)

    # ---------------------------
    # Enforce convergence for large bL, bT
    # ---------------------------

    # Define list of (n, bL, bT) points where model should behave well
    points = [
        [10.0, 50.0, 3.0],
        [10.0, 80.0, 3.0],
        [10.0, 100.0, 3.0],
        [8.0, 60.0, 2.5]
    ]

    penalty = 0.0
    for p in points
        Xp = reshape(p, :, 1)
        y_pred, ok = eval_tree_array(tree, Xp, options)
        if ok
            penalty += (y_pred[1])^2   # Penalize large output magnitude
        else
            penalty += 1e6  # Heavy penalty if model fails to evaluate
        end
    end

    return wmse + 0.01 * penalty  # Adjust 0.01 for penalty strength
end
"""




extra_sympy_mappings = {
    "gaussian": lambda x: exp(-x**2)
}

# Update the PySRRegressor call
model22 = PySRRegressor(
    niterations=50,
    maxsize = 30,
    binary_operators=["*", "^", "Lorentzian(x, y) = 1/(y+x^2)"],
    unary_operators=["expdecay(x) = exp(-x)", "gaussian(x) = exp(-x^2)"],
    loss_function=custom_loss_function_with_penalty,  # Use the custom loss function
    extra_sympy_mappings={"expdecay": lambda x: exp(-x), "gaussian": lambda x: exp(-x**2), "Lorentzian": lambda x, y: 1/(y+x**2)},
    constraints={'^': (-1, 1),'gaussian': (-1, 1), 'Lorentzian': (-1, 1)}
)

model = PySRRegressor(
    niterations=100,
    maxsize = 30,
    unary_operators=["gaussian(x) = exp(-x^2)", "exp"],
    binary_operators=["*", "^"],
    extra_sympy_mappings=extra_sympy_mappings,  # Include the custom mappings
    loss_function=custom_loss_function_with_penalty,  # Use the custom loss function
    nested_constraints = {"gaussian": {"gaussian": 0, "exp": 0}, "exp": {"exp": 0, "gaussian": 0}},
    constraints={'^': (-1, 1)}

)

model2 = PySRRegressor(
    niterations=100,
    maxsize = 30,
    unary_operators=["gaussian(x) = exp(-x^2)"],
    binary_operators=["*", "+","^"],
    extra_sympy_mappings=extra_sympy_mappings,  # Include the custom mappings
    loss_function=custom_loss_function_with_penalty,  # Use the custom loss function
    nested_constraints = {"gaussian": {"gaussian": 0},"^": {"^": 0, "+": 0}},
    constraints={'^': (-1, 1)}

)

model3 = PySRRegressor(
    niterations=50,
    maxsize = 30,
    binary_operators=["*", "+", "/", "^"],
    loss_function=custom_loss_function_with_penalty,  # Use the custom loss function
    extra_sympy_mappings={ "^": {"^": 0, "+": 0},  "/": {"^": 0, "+": 0}},
    constraints={'^': (-1, 1)}
    #constraints={'gaussian': (-1, 1), 'Lorentzian': (-1, 1)}
)


model.fit(etabLbT, A2B, weights = A2Bweight, variable_names = ['n','bL', 'bT'])
# Out:
# /opt/homebrew/anaconda3/lib/python3.11/site-packages/pysr/sr.py:2811: UserWarning:
#
# Note: it looks like you are running in Jupyter. The progress bar will be turned off.
#
# [ Info: Started!
# [ Info: Final population:
# [ Info: Results saved to:
# Expressions evaluated per second: 1.410e+05
# Progress: 753 / 3100 total iterations (24.290%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           2.748e+01  0.000e+00  y = 0.0022055
# 3           1.996e+01  1.598e-01  y = 0.47434 ^ n
# 4           1.972e+01  1.213e-02  y = gaussian(n ^ 0.4271)
# 5           1.971e+01  5.949e-04  y = (0.5459 ^ n) * 0.35063
# 7           1.971e+01  4.244e-05  y = (0.47889 ^ n) * (n * 0.12549)
# 8           1.971e+01  7.850e-05  y = gaussian((n ^ 0.68675) * 0.44933) * 0.093858
# ...

# %% [markdown]
# We can print the model, which will print out all the discovered expressions:

# %% [markdown]
# We can also view the SymPy format of the best expression:

# %%
pick =10
model.sympy(pick)
# Out:
# exp(-0.17412309913636*n**1.42091954)*(exp(-bL**2)*exp(-bT**2))**0.07404342*0.6855797
# Error in callback _flush_stdio (for post_execute):
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# File ~/.julia/packages/PythonCall/WMWY0/src/JlWrap/any.jl:262, in __call__(self, *args, **kwargs)
#     260     return ValueBase.__dir__(self) + self._jl_callmethod($(pyjl_methodnum(pyjlany_dir)))
#     261 def __call__(self, *args, **kwargs):
# --> 262     return self._jl_callmethod($(pyjl_methodnum(pyjlany_call)), args, kwargs)
#     263 def __bool__(self):
#     264     return True
#
# UnicodeDecodeError: 'utf-8' codec can't decode bytes in position 4094-4095: unexpected end of data

# %%
print(model.sympy(pick))
# Out:
# ((((exp(-bL**2)**0.23772913)**n*exp(-bT**2)*0.011789469/(bT*bT)**3.010302)**0.03194622)**n)**0.62392724*0.46055466

# %%
0.0676446961856836-(0.142561468497997*0.46243346)
# Out:
# 0.0017195030454738441

# %%
eta = 9



print(f"eta = {eta}")
print(f"P1 = {P1}")
from IPython.display import display, Math

display(Math(f"b^2_{{min}} = {bsqmin}"))




data_list_for_plt = []


with h5py.File(file_path, "r") as h5_file:
        dataset_name_for_plt = f"Pl-{P1}/eta_{eta}_bL_bT_ReA2B_err"
        data_list_for_plt.append(np.array(h5_file[dataset_name_for_plt]))
        
data_for_eta_for_plt = np.vstack(data_list_for_plt)

mask_for_plt =  ~((np.sqrt(data_for_eta_for_plt[:, 1]**2 + data_for_eta_for_plt[:, 2]**2) <3) )
data_for_eta_for_plt = data_for_eta_for_plt[mask_for_plt]

# Extract bLbT and A12B
bLbT_for_plt = data_for_eta_for_plt[:, 1:3]  
A12B_for_plt = data_for_eta_for_plt[:, 3]   
A12Berr_for_plt = data_for_eta_for_plt[:, 4]
A12Bweight_for_plt = [1/sigma**2 for sigma in A12Berr_for_plt]

bL_plot = np.linspace(-8, 8, 100)



plt.figure(figsize=(10, 6))
unique_bT = np.unique(bLbT_for_plt[:, 1])
colors = plt.cm.prism(np.linspace(0, 1, len(unique_bT)))
for i, bT in enumerate(unique_bT):
    color = colors[i]
    bLbT_plot = np.array([[eta, bL, bT] for bL in bL_plot])
    predictions = model.predict(bLbT_plot, pick)  # No extra argument
    plt.plot(bLbT_plot[:, 1], predictions, color=color)#, label=f"$b_T$ = {int(bT)}")  
    mask = bLbT_for_plt[:, 1] == bT
    bL_values = bLbT_for_plt[mask, 0]
    A12B_values = A12B_for_plt[mask]
    A12B_errors = A12Berr_for_plt[mask]

    # Plot with error bars
    plt.errorbar(
        bL_values,
        A12B_values,
        yerr=A12B_errors,
        fmt='o',
        label=f"$b_T$ = {int(bT)}",
        capsize=4, color=color
    )


    
# Labels, legend, and grid
plt.xlabel("$b_{L}$", fontsize=14)
plt.ylabel("$A_{2B}$", fontsize=14)
plt.title("Plot of $A_{2B}$ vs $b_L$ for Different $b_T$ Values", fontsize=16)
plt.legend(fontsize=10)
plt.grid(True)
plt.tight_layout()
plt.show()

print("\npick",model.equations_[["loss"]].iloc[[pick]])
model.sympy(pick)
# Out:
# eta = 9
# P1 = 2
# $\displaystyle b^2_{min} = 3$
# pick        loss
# 9  1.302914
# exp(-0.06370737537024*bL**2)*exp(-0.0669909241586025*bT**2)*2.3788466*exp(n*(-0.5973205))

# %%
model.equations_[["loss"]].iloc[[pick]]
# Out:
#         loss
# 10  0.492874
