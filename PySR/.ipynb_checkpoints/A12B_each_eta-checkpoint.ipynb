# %% [markdown]
# # TMD A12B for specific eta

# %%
pip install -U pysr
# Out:
# Requirement already satisfied: pysr in /opt/homebrew/anaconda3/lib/python3.11/site-packages (1.3.1)
# Collecting pysr
#   Obtaining dependency information for pysr from https://files.pythonhosted.org/packages/08/17/035efeb6288184bc02e9d3deca20211a66a683cd17c1991dd5ffe4cc0cfe/pysr-1.5.1-py3-none-any.whl.metadata
#   Downloading pysr-1.5.1-py3-none-any.whl.metadata (54 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.6/54.6 kB 850.7 kB/s eta 0:00:00 0:00:01
# Requirement already satisfied: sympy<2.0.0,>=1.0.0 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from pysr) (1.11.1)
# Requirement already satisfied: pandas<3.0.0,>=0.21.0 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from pysr) (2.0.3)
# Requirement already satisfied: numpy<3.0.0,>=1.13.0 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from pysr) (1.26.4)
# Requirement already satisfied: scikit_learn<2.0.0,>=1.0.0 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from pysr) (1.2.2)
# Collecting juliacall==0.9.24 (from pysr)
#   Obtaining dependency information for juliacall==0.9.24 from https://files.pythonhosted.org/packages/2b/88/bc544390a0bbf1eb425540b2ba2abe0d478c31d3002a703fdb640f4abc2a/juliacall-0.9.24-py3-none-any.whl.metadata
#   Downloading juliacall-0.9.24-py3-none-any.whl.metadata (4.5 kB)
# Requirement already satisfied: click<9.0.0,>=7.0.0 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from pysr) (8.0.4)
# Requirement already satisfied: setuptools>=50.0.0 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from pysr) (68.0.0)
# Requirement already satisfied: juliapkg~=0.1.8 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from juliacall==0.9.24->pysr) (0.1.15)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from pandas<3.0.0,>=0.21.0->pysr) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from pandas<3.0.0,>=0.21.0->pysr) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from pandas<3.0.0,>=0.21.0->pysr) (2023.3)
# Requirement already satisfied: scipy>=1.3.2 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from scikit_learn<2.0.0,>=1.0.0->pysr) (1.11.1)
# Requirement already satisfied: joblib>=1.1.1 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from scikit_learn<2.0.0,>=1.0.0->pysr) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from scikit_learn<2.0.0,>=1.0.0->pysr) (2.2.0)
# Requirement already satisfied: mpmath>=0.19 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from sympy<2.0.0,>=1.0.0->pysr) (1.3.0)
# Requirement already satisfied: semver~=3.0 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from juliapkg~=0.1.8->juliacall==0.9.24->pysr) (3.0.2)
# Requirement already satisfied: six>=1.5 in /opt/homebrew/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas<3.0.0,>=0.21.0->pysr) (1.16.0)
# Downloading pysr-1.5.1-py3-none-any.whl (93 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.9/93.9 kB 2.8 MB/s eta 0:00:00
# Downloading juliacall-0.9.24-py3-none-any.whl (11 kB)
# Installing collected packages: juliacall, pysr
#   Attempting uninstall: juliacall
#     Found existing installation: juliacall 0.9.23
#     Uninstalling juliacall-0.9.23:
#       Successfully uninstalled juliacall-0.9.23
#   Attempting uninstall: pysr
#     Found existing installation: pysr 1.3.1
#     Uninstalling pysr-1.3.1:
#       Successfully uninstalled pysr-1.3.1
# Successfully installed juliacall-0.9.24 pysr-1.5.1
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Julia and Julia dependencies are installed at first import:

# %%
import pysr

# %% [markdown]
# Now, let's import everything else as well as the PySRRegressor:

# %%
import sympy
import numpy as np
from matplotlib import pyplot as plt
from pysr import PySRRegressor
from sklearn.model_selection import train_test_split
import h5py

# %% [markdown]
# # PySR for A12B eta = 8:

# %%
file_path = "/Users/hariprashadravikumar/sivers_TMD_PhD_project/save_h5_A12B_A2B/eta_Pb_bsquare_Amp_err_forallPL.h5"
#with h5py.File(file_path, "r") as h5_file:
#    # Specify the dataset to extract
#    dataset_name = "Pl-2/eta_8_Pb_bsq_A12B_err"
#    data = np.array(h5_file[dataset_name])

P1 = 1
data_list = []
with h5py.File(file_path, "r") as h5_file:
    dataset_name = f"Pl-{P1}/eta_8_Pb_bsq_A12B_err"
    dataPl = np.array(h5_file[dataset_name])    
    data_list.append(dataPl)

data = np.vstack(data_list)
# Extract bLbT and A12B
Pbbsq = data[:, 1:3]  
A12B = data[:, 3]   
A12Berr = data[:, 4]
A12Bweight = [1/sigma**2 for sigma in A12Berr]


#print("bLbT =", bLbT)
#print("A12B =", A12B)
#print("A12Berr =", A12Berr)

# %%
# Extract unique bT values
unique_bsq = np.unique(Pbbsq[:, 1])

# Create the plot
plt.figure(figsize=(10, 6))

for i, bsq in enumerate(unique_bsq):
    #if bT<1 :
    #    continue
    # Filter data for the current bT value
    mask = Pbbsq[:, 1] == bsq
    Pb_values = Pbbsq[mask, 0]
    A12B_values = A12B[mask]
    A12B_errors = A12Berr[mask]

    # Plot with error bars
    plt.errorbar(
        Pb_values,
        A12B_values,
        yerr=A12B_errors,
        fmt='o',
        label=f"$b^2$ = {int(bsq)}",
        capsize=4
    )
# Add labels, legend, and grid
plt.xlabel("$P\cdot b$", fontsize=14)
plt.ylabel("$A_{12B}$", fontsize=14)
plt.title("Plot of $A_{12B}$ vs $P\cdot b$ for Different $b^2$ Values", fontsize=16)
plt.legend(fontsize=10)
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Extract unique bT values
unique_Pb = np.unique(Pbbsq[:, 0])

# Create the plot
plt.figure(figsize=(10, 6))

for i, Pb in enumerate(unique_Pb):
    #if bT<1 :
    #    continue
    # Filter data for the current bT value
    mask = Pbbsq[:, 0] == Pb
    Psq_values = Pbbsq[mask, 1]
    A12B_values = A12B[mask]
    A12B_errors = A12Berr[mask]

    # Plot with error bars
    plt.errorbar(
        Psq_values,
        A12B_values,
        yerr=A12B_errors,
        fmt='o',
        label=f"$P\cdot b$ = {Pb}",
        capsize=4
    )
# Add labels, legend, and grid
plt.xlabel("$b^2$", fontsize=14)
plt.ylabel("$A_{12B}$", fontsize=14)
plt.title("Plot of $A_{12B}$ vs $b^2$ for Different $P\cdot b$ Values", fontsize=16)
plt.legend(fontsize=10)
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# By default, we will set up 30 populations of expressions (which evolve independently except for migrations), use 4 threads, and use `"best"` for our model selection strategy:

# %%
default_pysr_params = dict(
    populations=50,
    model_selection="best",
)

# %%
# test try functions
x = np.linspace(-10, 10, 1000)
y = 1 / (np.sqrt(1+x**2))

#plt.plot(x, y)
#plt.show()

# %%
from sympy import exp, symbols, Function

custom_loss_function = """
using Symbolics

function eval_loss(tree, dataset::Dataset{T,L}, options)::L where {T,L}
    prediction, flag = eval_tree_array(tree, dataset.X, options)
    if !flag
        return L(Inf)
    end
    
    wmse = sum(dataset.weights .* (prediction .- dataset.y) .^ 2) / (dataset.n * sum(dataset.weights))
    return wmse
end
"""

extra_sympy_mappings = {
    "Lorentzian": lambda x, y: 1 / (y + x**2),
    "gaussian": lambda x: exp(-x**2),
    "decay": lambda x: exp(-x)
}

model = PySRRegressor(
    niterations=30,
    binary_operators=["*", "Lorentzian(x, y) = 1/(y + x^2)"],
    unary_operators=["decay(x) = exp(-x)", "gaussian(x) = exp(-x^2)"],
    extra_sympy_mappings=extra_sympy_mappings,  # Include the custom mappings
    loss_function=custom_loss_function,  # Use the custom loss function
    nested_constraints = { "gaussian": {"gaussian": 0, "Lorentzian": 0, "decay": 0},"Lorentzian": {"Lorentzian": 0, "decay": 0, "gaussian": 0}, "decay": {"gaussian": 0, "Lorentzian": 0, "decay": 0} },
    constraints={'decay': (1, 1), 'gaussian': (-1, 1), 'Lorentzian': (-1, 1)}

)

model.fit(Pbbsq, A12B, weights=A12Bweight, variable_names=['Pb', 'bsq'])
# Out:
# /opt/homebrew/anaconda3/lib/python3.11/site-packages/pysr/sr.py:2766: UserWarning: Note: it looks like you are running in Jupyter. The progress bar will be turned off.
#   )
# Compiling Julia backend...
# [ Info: Started!
# Expressions evaluated per second: 1.340e+05
# Progress: 910 / 930 total iterations (97.849%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.687e-07  1.594e+01  y = 0.0013935
# 3           2.358e-08  9.839e-01  y = Lorentzian(bsq, 38.35)
# 5           1.461e-08  2.396e-01  y = Lorentzian(Pb, bsq) * 0.054877
# 7           5.462e-09  4.918e-01  y = Lorentzian(bsq * 0.15265, bsq) * 0.067895
# 9           5.329e-09  1.237e-02  y = Lorentzian((bsq * Pb) * 0.24385, bsq) * 0.062354
# 11          4.446e-09  9.062e-02  y = Lorentzian(Pb, 1.2206) * (Lorentzian(bsq * -0.09517, b...
#                                       sq) * 0.081583)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.687e-07  1.594e+01  y = 0.0013935
# 3           2.358e-08  9.839e-01  y = Lorentzian(bsq, 38.35)
# 5           1.461e-08  2.396e-01  y = Lorentzian(Pb, bsq) * 0.054877
# 7           5.462e-09  4.918e-01  y = Lorentzian(bsq * 0.15265, bsq) * 0.067895
# 9           5.329e-09  1.237e-02  y = Lorentzian((bsq * Pb) * 0.24385, bsq) * 0.062354
# 11          4.446e-09  9.062e-02  y = Lorentzian(Pb, 1.2206) * (Lorentzian(bsq * -0.09517, b...
#                                       sq) * 0.081583)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# [ Info: Final population:
# [ Info: Results saved to:
# PySRRegressor.equations_ = [
# 	   pick     score                                           equation  \
# 	0        0.000000                                       0.0013935453
# 	1        0.983852                         Lorentzian(bsq, 38.350487)
# 	2        0.239553                  Lorentzian(Pb, bsq) * 0.054876667
# 	3  >>>>  0.491751     Lorentzian(bsq * 0.15264834, bsq) * 0.06789455
# 	4        0.012369  Lorentzian((bsq * Pb) * 0.24384554, bsq) * 0.0...
# 	5        0.090616  Lorentzian(Pb, 1.2206117) * (Lorentzian(bsq * ...
#
# 	           loss  complexity
# 	0  1.687147e-07           1
# 	1  2.358251e-08           3
# 	2  1.460552e-08           5
# 	3  5.462445e-09           7
# 	4  5.328976e-09           9
# 	5  4.445659e-09          11
# ]
#   - outputs/20250303_140951_o0th8r/hall_of_fame.csv

# %%
model.sympy(5)
# Out:
# 0.08158308/((Pb**2 + 1.2206117)*(0.0090572432472025*bsq**2 + bsq))

# %% [markdown]
# We can also view the SymPy of any other expression in the list, using the index of it in `model.equations_`.

# %%
pick = 5


Pb_plot = np.linspace(-max(unique_Pb),max(unique_Pb), 100)
plt.figure(figsize=(10, 6))

for bsq in unique_bsq:
    Pbbsq_plot = np.array([[Pb, bsq] for Pb in Pb_plot])
    predictions = model.predict(Pbbsq_plot, pick)
    plt.plot(Pb_plot, predictions)
for i, bsq in enumerate(unique_bsq):
    #if bT<1 :
    #    continue
    # Filter data for the current bT value
    mask = Pbbsq[:, 1] == bsq
    Pb_values = Pbbsq[mask, 0]
    A12B_values = A12B[mask]
    A12B_errors = A12Berr[mask]

    # Plot with error bars
    plt.errorbar(
        Pb_values,
        A12B_values,
        yerr=A12B_errors,
        fmt='o',
        capsize=4
    )
# Add labels, legend, and grid
plt.xlabel("Pb", fontsize=14)
plt.ylabel("$A_{12B}$", fontsize=14)
plt.title("Plot of $A_{12B}$ vs $P\cdot b$ for Different $b^2$ Values", fontsize=16)
plt.grid(True)
plt.tight_layout()
plt.show()



model.sympy(pick)
# Out:
# 0.08158308/((Pb**2 + 1.2206117)*(0.0090572432472025*bsq**2 + bsq))

# %%
b2_plot = np.linspace(1,max(unique_bsq), 100)
plt.figure(figsize=(10, 6))

for Pb in unique_Pb:
    Pbbsq_plott = np.array([[Pb, bsq] for bsq in b2_plot])
    predictions = model.predict(Pbbsq_plott, pick)
    plt.plot(b2_plot, predictions)

for i, Pb in enumerate(unique_Pb):
    #if bT<1 :
    #    continue
    # Filter data for the current bT value
    mask = Pbbsq[:, 0] == Pb
    Psq_values = Pbbsq[mask, 1]
    A12B_values = A12B[mask]
    A12B_errors = A12Berr[mask]

    # Plot with error bars
    plt.errorbar(
        Psq_values,
        A12B_values,
        yerr=A12B_errors,
        fmt='o',
        label=f"$P\cdot b$ = {Pb}",
        capsize=4
    )
# Add labels, legend, and grid
plt.xlabel("$b^2$", fontsize=14)
plt.ylabel("$A_{12B}$", fontsize=14)
plt.title("Plot of $A_{12B}$ vs $b^2$ for Different $P\cdot b$ Values", fontsize=16)
plt.legend(fontsize=10)
plt.grid(True)
plt.tight_layout()
plt.show()

model.sympy(pick)
# Out:
# 0.08158308/((Pb**2 + 1.2206117)*(0.0090572432472025*bsq**2 + bsq))

# %%
model.equations_[["complexity", "loss", "equation"]]
